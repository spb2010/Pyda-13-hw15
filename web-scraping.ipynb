# %% [markdown]
# # Библиотека requests

# %%
import requests

# %%
# метод get
res = requests.get('https://yandex.ru')
res
# res.status_code
# Out:
# <Response [200]>

# %%
# браузер отрисовал бы страницу на основе данного текста
res.text
# Out:
# '<!DOCTYPE html><html class="i-ua_js_no i-ua_css_standart i-ua_browser_unknown i-ua_browser-engine_unknown i-ua_browser_desktop i-ua_platform_other" lang="ru"><head xmlns:og="http://ogp.me/ns#"><meta http-equiv=Content-Type content="text/html;charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><title>Яндекс</title><link rel="shortcut icon" href="//yastatic.net/iconostasis/_/8lFaTHLDzmsEZz-5XaQg9iTWZGE.png"><link rel="apple-touch-icon" href="//yastatic.net/iconostasis/_/5mdPq4V7ghRgzBvMkCaTzd2fjYg.png" sizes="76x76"><link rel="apple-touch-icon" href="//yastatic.net/iconostasis/_/s-hGoCQMUosTziuARBks08IUxmc.png" sizes="120x120"><link rel="apple-touch-icon" href="//yastatic.net/iconostasis/_/KnU823iWwj_vrPra7x9aQ-4yjRw.png" sizes="152x152"><link rel="apple-touch-icon" href="//yastatic.net/iconostasis/_/wT9gfGZZ80sP0VsoR6dgDyXJf2Y.png" sizes="180x180"><link rel="alternate" type="application/rss+xml" title="Новости Яндекса" href="https://yandex.ru/company/press_releases/news.rss"><link rel="alternate" type="application/rss+xml" title="Блог Яндекса" href="https://yandex.ru/blog/company/rss"><link rel="search" href="//yandex.ru/opensearch.xml" title="Яндекс" type="application/opensearchdescription+xml"><link rel="preload" href="//yastatic.net/jquery/2.1.4/jquery.min.js" as="script" crossorigin="anonymous"><link rel="preload" href="//yastatic.net/s3/home-static/_/H/W/SAynuJxe0uMX6y9KcRBsJr6jk.js" as="script" crossorigin="anonymous"><meta property="fb:app_id" content="1524984910954255"><meta name="yamm" content="p"><meta name="referrer" content="origin"><meta property="og:title" content="Яндекс"><meta property="og:image" content="https://yastatic.net/s3/home/logos/share/share-logo_ru.png"><meta property="og:description" content="Найдётся всё"><meta property="og:url" content="https://yandex.ru"><meta property="og:type" content="website"><meta property="og:site_name" content="Яндекс"><meta property="og:locale" content="ru_RU"><meta property="og:locale:alternate" content="ru_RU"><meta property="og:locale:alternate" content="be_BY"><meta property="og:locale:alternate" content="kk_KZ"><meta property="og:locale:alternate" content="tt_RU"><meta property="og:locale:alternate" content="uk_UA"><script>(function(window) { var home = window.home = window.home || {}, delta = +new Date() - 1601656450 * 1000; home.now = function() { return new Date(+new Date() - delta); }; })(window);</script><script>window.home=window.home||{},home.loadManager=function(){var n={},o={};return{subscribe:function(t,e){var i=0,r=function(){++i===t.length&&setTimeout((function(){e()}),0)};"object"!=typeof t&&(t=[t]),t.forEach((function(t){o[t]?r():(n[t]||(n[t]=[]),n[t].push(r))}))},trigger:function(t){if(!o[t]&&(o[t]=!0,n[t])){for(var e=0,i=n[t].length;e<i;e++)n[t][e]();n[t]=[]}}}}();</script><script>!function(i,t){if(i.Ya=i.Ya||{},Ya.Rum)throw new Error("Rum: interface is already defined");var n=i.performance,e=n&&n.timing&&n.timing.navigationStart||Ya.startPageLoad||+new Date,s=i.requestAnimationFrame;Ya.Rum={enabled:!!n,vsStart:document.visibilityState,vsChanged:!1,_defTimes:[],_defRes:[],_deltaMarks:{},_markListeners:{},_settings:{},_vars:{},init:function(i,t){this._settings=i,this._vars=t},getTime:n&&n.now?function(){return n.now()}:Date.now?function(){return Date.now()-e}:function(){return new Date-e},time:function(i){this._deltaMarks[i]=[this.getTime()]},timeEnd:function(i,t){var n=this._deltaMarks[i];n&&0!==n.length&&n.push(this.getTime(),t)},sendTimeMark:function(i,t,n,e){void 0===t&&(t=this.getTime()),this._defTimes.push([i,t,e]),this.mark(i,t)},sendResTiming:function(i,t){this._defRes.push([i,t])},sendRaf:function(i){var t=this.getSetting("forceFirstPaintTimeSending");if(s&&(t||!this.isVisibilityChanged())){var n=this,e="2616."+i;s((function(){!t&&n.isVisibilityChanged()||(n.sendTimeMark(e+".205"),s((function(){!t&&n.isVisibilityChanged()||n.sendTimeMark(e+".1928")})))}))}},isVisibilityChanged:function(){return this.vsStart&&("visible"!==this.v ...

# %%
# посмотрим куки
res.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='i', value='ldkbi7kZhX5snVlOxtBYzcvuTNXU7lDooxi8JcuVy8lojjWbxrkBs+J7qD1DQZuNFnaM2SS0vOQRcHf0PkxyxAqzALA=', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1664728449, discard=False, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='is_gdpr', value='0', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1664728449, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='is_gdpr_b', value='CNnvZBC7BCgC', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1664728449, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='mda', value='0', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1612024449, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='yandex_gid', value='2', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1604248450, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='yandexuid', value='5303774671601656449', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1917016450, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='yp', value='1604248450.ygu.1', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1917016450, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False)]>

# %%
# получаем плохой статус
bad_request = requests.get('https://yandex.ru/secret')
bad_request
# Out:
# <Response [404]>

# %%
bad_request.text

# %%
# попроуем сделать post запрос
post_req = requests.post('https://yandex.ru')
post_req

# %%
# cформируем поисковый запрос, обратите внимание на его формат
URL = 'https://yandex.ru/search/?text=python&lr=54'

# %%
req = requests.get(URL)
req

# %%
req.text

# %%
# в request можно передать параметры запроса и заголовки (headers) в виде словарей. 
# сегодня не будем рассматривать примеры с необхожимостью передачи заголовка, 
# но в практике вам это точно понадобится
URL = 'https://yandex.ru/search/'
params = {
    'text': 'python',
    'lr': 54
}
headers = {}
req = requests.get(URL, params)
req = requests.post(URL, json={}, headers = headers)
req.text
# Out:
# '<!DOCTYPE html><html class=i-ua_js_no lang=ru><meta charset=utf-8><meta http-equiv=X-UA-Compatible content="IE=edge"><title>Яндекс</title><script nonce=2499>document.documentElement.className="i-ua_js_yes i-ua_svg_yes"+((screen.deviceXDPI&&screen.logicalXDPI&&screen.deviceXDPI/screen.logicalXDPI||window.devicePixelRatio)>1?" i-ua_retina_yes":"");</script><link rel=search title="Яндекс" type="application/opensearchdescription+xml" href="/search/opensearch.xml"><meta name=referrer content=always><style nonce=2499 data-role=css data-stylesheet=header>body{margin:0}.b-page__body{margin:0;color:#000;background:#fff;height:100%;padding:0;font-family:Arial,Helvetica,sans-serif;font-size:13px;line-height:1.154}.i-ua_platform_ios.b-page__body{-webkit-tap-highlight-color:rgba(0,0,0,0);cursor:auto}html{height:100%}.b-page.b-page_js_inited.b-page_overflow_hidden,.b-page_initial-scroll_yes.b-page_js_inited.b-page_overflow_yes{overflow:hidden}.b-page_offset_top{padding-top:32px}.b-page_change_yes{will-change:padding-top;transition:padding-top .3s .1s ease-in-out}.b-page_initial-scroll_yes{overflow-y:scroll}.b-page_initial-scroll_yes.b-page_js_inited{overflow-y:auto}.a11y-fast-nav{position:absolute;top:-9999px;left:-9999px}.serp-header{position:relative;font-family:Arial,sans-serif;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none}.serp-header__main{display:table;-moz-box-sizing:border-box;box-sizing:border-box;width:100%;table-layout:fixed;box-shadow:none!important}.serp-header__under{position:relative}.serp-header__logo,.serp-header__nav,.serp-header__search2{display:table-cell;height:39px;vertical-align:top}.serp-header__nav{padding-left:20px;text-align:right;white-space:nowrap}.serp-header__logo .logo.logo_name_ys-en-87x35{background-position:0 3px}.serp-header_head-auth_yes .serp-header__search2{width:100%}.serp-header .serp-user_enter_yes,.serp-header .serp-user_type_enter{margin-top:3px;padding-left:7px;vertical-align:top}.serp-header{height:55px}.serp-header__main{padding:14px 16px 0}.serp-header_head-auth_yes .serp-header__main{min-width:500px;table-layout:auto}.serp-header__wrapper{position:fixed;width:100%;height:55px;background:#fff;-webkit-transform:translateZ(0);transform:translateZ(0)}.serp-header__search2{position:relative;z-index:1;width:638px;padding-top:1px}.serp-header__nav{position:relative;z-index:2}.serp-header .notifier{display:inline-block;margin-right:18px}.serp-header .notifier__icon{margin-top:1px}.serp-header__logo{width:100px;min-width:100px}@media (max-width:1060px){.yaplus_available_yes .link__inner{display:none}}@media (max-width:960px){.serp-header__logo{width:auto;min-width:auto}.logo[class][class]{width:18px;height:35px;margin-right:9px;background-position:0 4px}.serp-header .logo.logo_name_ys-ru-86x35{background-image:url("//yastatic.net/s3/web4static/_/v2/SSIxUPEp7tr5cbP0cCIM-2_62g8.svg")}.serp-header .logo.logo_name_ys-en-87x35{background-image:url("//yastatic.net/s3/web4static/_/v2/DTIqAt1p7IWGR0nbQsniMk5jPJg.svg")}}@media (max-width:722px){.header-favorites-button[class],.input__settings[class],.input__voice-search[class][class],.notifier[class][class],.yaplus[class]{display:none}}.serp-header__back-button-container{display:none}.serp-header{min-width:600px}.serp-header[class]{z-index:10005}.logo{display:inline-block;background-repeat:no-repeat;background-position:center;background-size:contain}@media print{.logo{-webkit-print-color-adjust:exact}}.logo_name_ys-ru-86x35{width:86px;height:35px;background-image:url("//yastatic.net/islands/_/RQWGFypkIRAzEbaERs_Sq8zKRzY.svg")}.logo_name_ys-en-87x35{width:87px;height:35px;background-image:url("//yastatic.net/islands/_/W5E8s3ZxddTVAc2-tL5VvgPy6ZY.svg")}.logo_type_link{overflow:hidden;white-space:nowrap;text-indent:100%;outline:0}.z-index-group_level_0{z-index:1000}.z-index-group_level_1{z-index:2000}.z-index-group_level_2{z-index:3000}.z-index-group_level_3{z-index:4000}.z-index-group_level_4{z-index:5000}.z-index-group_le ...

# %%
# очень часто сайты могут ограничивать частые запросы к себе, 
# поэтому нужно задерживать исполнение
import time
time.sleep(0.2)

# %% [markdown]
# # Beautiful Soup

# %%
# как разбирать всю эту разметку? Поможет BeautifulSoup.
from bs4 import BeautifulSoup

# %% [markdown]
# ## Практика 1. Напишем скрипт, который будет отбирать посты из нужных хабов на habr.com

# %%
# определяем список хабов, которые нам интересны
DESIRED_HUBS = ['python', 'bigdata']

# %%
# получаем страницу с самыми свежими постами
req = requests.get('https://habr.com/ru/all/')
soup = BeautifulSoup(req.text, 'html.parser')

# %%
# извлекаем посты
posts = soup.find_all('article', class_='post')
posts

# %%
for post in posts:
    post_id = post.parent.attrs.get('id')
   # если идентификатор не найден, это что-то странное, пропускаем
    if not post_id:
        continue
    post_id = int(post_id.split('_')[-1])
    print('post', post_id)
    hubs = post.find_all('a', class_='hub-link')

# %%
# добавляем извлечение хабов из постов, чтобы отбирать только нужные
for post in posts:
    post_id = post.parent.attrs.get('id')
   # если идентификатор не найден, это что-то странное, пропускаем
    if not post_id:
        continue
    post_id = int(post_id.split('_')[-1])
    hubs = post.find_all('a', class_='hub-link')
    for hub in hubs:
            hub_lower = hub.text.lower()
           # ищем вхождение хотя бы одного желаемого хаба
            if any([hub_lower in desired for desired in DESIRED_HUBS]):
               # пост нам интересен - делаем с ним все что захотим:
               # можно отправит в телеграм уведомление, можно на почту и т.п.
                title_element = post.find('a', class_='post__title_link')
                print(title_element.text, title_element.attrs.get('href'))
               # так как пост уже нам подошел - дальше нет смысла проверять хабы
                break

# %% [markdown]
# ## Практика 2. Напишем скрипт, который будет собирать новости с сайта Коммерсанта

# %%
URL = 'https://www.kommersant.ru/search/results'
params = {
    'search_query': 'python'
}

# %%
res = requests.get(URL, params)

# %%
res.text
# Out:
# '\r\n<!DOCTYPE html>\r\n<html class="no-js" lang="ru"  >\r\n<head>\r\n<title>Коммерсантъ: последние новости России и мира</title>\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge, chrome=1" />\r\n<meta charset="utf-8"/>\r\n\r\n<script>document.write(document.cookie.indexOf(\'IsNonMobileViewport\') >= 0 ? \'<meta name="viewport" content="width=1200">\' : \'<meta name="viewport" content="width=device-width, initial-scale=1.0">\')</script>\r\n\r\n<meta name="format-detection" content="telephone=no" />\r\n<meta name="title" content="Коммерсантъ: последние новости России и мира" />\r\n\r\n<meta name="description" content="Актуальные новости, объективный анализ и эксклюзивные комментарии о важнейших событиях и трендах" />\r\n\r\n<meta name="keywords" content="Новости,Политика,Экономика,Бизнес,Финансы,Дело,Биржа,Рынок,Акции,Прогнозы,Критика,Интервью,Рейтинги,Документы,Деньги,Власть,Автопилот,Тематические страницы,Первые лица,Деловые новости,Мировая практика,Культура,Спорт,Weekend,Астрологический прогноз,Погода мира,Курсы валют ЦБ РФ" />\r\n\r\n\r\n\r\n\r\n<link rel="apple-touch-icon" sizes="57x57" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-57x57.png">\r\n<link rel="apple-touch-icon" sizes="60x60" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-60x60.png">\r\n<link rel="apple-touch-icon" sizes="72x72" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-72x72.png">\r\n<link rel="apple-touch-icon" sizes="76x76" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-76x76.png">\r\n<link rel="apple-touch-icon" sizes="114x114" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-114x114.png">\r\n<link rel="apple-touch-icon" sizes="120x120" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-120x120.png">\r\n<link rel="apple-touch-icon" sizes="144x144" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-144x144.png">\r\n<link rel="apple-touch-icon" sizes="152x152" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-152x152.png">\r\n<link rel="apple-touch-icon" sizes="180x180" href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-180x180.png">\r\n<link rel="icon" type="image/png" href="https://im.kommersant.ru/ContentFlex/images/favicons/favicon-32x32.png" sizes="32x32">\r\n<link rel="icon" type="image/png" href="https://im.kommersant.ru/ContentFlex/images/favicons/android-chrome-192x192.png" sizes="192x192">\r\n<link rel="icon" type="image/png" href="https://im.kommersant.ru/ContentFlex/images/favicons/favicon-16x16.png" sizes="16x16">\r\n<link rel="manifest" href="/manifest.json">\r\n<link rel="mask-icon" href="https://im.kommersant.ru/ContentFlex/images/favicons/safari-pinned-tab.svg" color="#5bbad5">\r\n<meta name="msapplication-TileColor" content="#2d89ef">\r\n<meta name="msapplication-TileImage" content="https://im.kommersant.ru/ContentFlex/images/favicons/mstile-144x144.png">\r\n<meta name="theme-color" content="#ffffff">\r\n\r\n<link rel="stylesheet" href="https://im.kommersant.ru/ContentFlex/css/kommersant.css?2009071933320000" charset="utf-8" />\r\n<link rel="stylesheet" href="/ContentFlex/modules/dist/main.css?2009221334306328"/>\r\n\r\n\r\n\r\n\t<link rel="stylesheet" href="https://im.kommersant.ru/ContentFlex/css/search.css?2004101325128136" charset="utf-8" />\r\n\t<link rel="stylesheet" href="https://im.kommersant.ru/ContentFlex/css/nano.css?1805180023023693" charset="utf-8" />\r\n\t<link rel="stylesheet" href="https://im.kommersant.ru/ContentFlex/css/datepicker.css?2006291815442276" charset="utf-8" />\r\n\r\n\r\n<script>\r\n\twindow.puids = {\r\n\t\t\'puid1\': \'0\',\r\n\t\t\'puid2\': \'\',\r\n\t\t\'puid3\': \'\',\r\n\t\t\'puid4\': \'i0\',\r\n\t\t\'puid5\': \'999\'\r\n\t};\r\n</script>\r\n\r\n<!--[if lt IE 10]>\r\n<script src="https://im.kommersant.ru/ContentFlex/js/html5.js?1602191901594361"></script> ...

# %%
soup = BeautifulSoup(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="ru">
# <head>
# <title>Коммерсантъ: последние новости России и мира</title>
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <script>document.write(document.cookie.indexOf('IsNonMobileViewport') >= 0 ? '<meta name="viewport" content="width=1200">' : '<meta name="viewport" content="width=device-width, initial-scale=1.0">')</script>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="Коммерсантъ: последние новости России и мира" name="title"/>
# <meta content="Актуальные новости, объективный анализ и эксклюзивные комментарии о важнейших событиях и трендах" name="description"/>
# <meta content="Новости,Политика,Экономика,Бизнес,Финансы,Дело,Биржа,Рынок,Акции,Прогнозы,Критика,Интервью,Рейтинги,Документы,Деньги,Власть,Автопилот,Тематические страницы,Первые лица,Деловые новости,Мировая практика,Культура,Спорт,Weekend,Астрологический прогноз,Погода мира,Курсы валют ЦБ РФ" name="keywords"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://im.kommersant.ru/ContentFlex/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="https://im.kommersant.ru/ContentFlex/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#2d89ef" name="msapplication-TileColor"/>
# <meta content="https://im.kommersant.ru/ContentFlex/images/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <link charset="utf-8" href="https://im.kommersant.ru/ContentFlex/css/kommersant.css?2009071933320000" rel="stylesheet">
# <link href="/ContentFlex/modules/dist/main.css?2009221334306328" rel="stylesheet">
# <link charset="utf-8" href="https://im.kommersant.ru/ContentFlex/css/search.css?2004101325128136" rel="stylesheet">
# <link charset="utf-8" href="https://im.kommersant.ru/ContentFlex/css/nano.css?1805180023023693" rel="stylesheet">
# <link charset="utf-8" href="https://im.kommersant.ru/ContentFlex/css/datepicker.css?2006291815442276" rel="stylesheet">
# <script>
# 	window.puids = {
# 		'puid1': '0',
# 		'puid2': '',
# 		'puid3': '',
# 		'puid4': 'i0',
# 		'puid5': '999'
# 	};
# </script>
# <!--[if lt IE 10]>
# <script src="https://im.kommersant.ru/ContentFlex/js/html5.js?1602191901594361"></script>
# <![endif]-->
# <script src="https://im.kommersant.ru/ContentFlex/js/jquery.js?1909251636130903"></script>
# <script src="https://im.kommersant.ru/ContentFlex/js/jquery.slider.js?2001161735525013"></script>
# <script src="https://im.kommersant.ru/ContentFlex/js/thirdparty.js?1903131721122656"></script>
# <script src="https://im.kommersant.ru/ContentFlex/js/kommersant.js?2009141607034883"></script>
# <script>
# 	kommersant.antiCache.cssComments = 'https://im.kommersant.ru/contentflex/css/comments.css?1907031808048203';
# 	kommersant.antiCache.cssGallery = 'https://im.kommersant.ru/contentflex/css/gallery.css?2004122240126776';
# 	kommersant.antiCache.ajaxCommentsTemplates = 'https://im.kommersant.ru/contentflex/ajax/comments/templates.html?1907081648178126';
# 	kommersant.antiCache.ajaxTemplates = 'https://im.kommersant.ru/contentflex/ajax/templates.html?1912101905288906';
# 	kommersant.antiCache.jsComments = 'https://im.kommersant.ru/contentflex/js/jquery.comments.js?2004081939216300';
# 	kommersant.antiCache.jsMark = 'https://im.kommersant.ru/contentflex/js/jquery.mark.min.js?1709081838214160';
# 	kommersant.antiCache.jsJqueryValidate = 'https://im.kommersant.ru/contentflex/js/jquery.validate.min.js?1709141923191971';
# 	kommersant.antiCache.jsMaillist = 'https://im.kommersant.ru/contentflex/js/maillist.js?1904101922353593';
# 	kommersant.antiCache.jsFmCommon = 'https://im.kommersant.ru/contentflex/js/fm_common3.js?1811132002129980';
# 	kommersant.antiCache.jsNanoScroller = 'https://im.kommersant.ru/contentflex/js/jquery.nanoscroller.min.js?1607262006591093';
# 	kommersant.antiCache.jsScrollMagic = 'https://im.kommersant.ru/contentflex/js/scrollmagic/ScrollMagic.min.js?1602191902421794';
# 	kommersant.antiCache.jsHighmapsCisDisputed = 'https://im.kommersant.ru/contentflex/js/highmaps/cis-disputed.js?1902041433508578';
# 	kommersant.antiCache.jsCharts = 'https://im.kommersant.ru/contentflex/js/charts.js?2009021735035215';
# 	kommersant.antiCache.jsWidgets = 'https://im.kommersant.ru/contentflex/js/widgets.js?2009041958182170';
# 	kommersant.antiCache.jsHighmapsWorldDisputed = 'https://im.kommersant.ru/contentflex/js/highmaps/world-disputed.js?1903011850417031';
# 	kommersant.antiCache.viconsComments = 'https://im.kommersant.ru/contentflex/ajax/vicons/comments.html?1907031809599085';
# 	kommersant.vicons.add('https://im.kommersant.ru/contentflex/ajax/vicons/common.html?2008241546221862', {cache: true});
# </script>
# <link crossorigin="" href="https://ads.betweendigital.com" rel="preconnect"/>
# <script async="" src="https://yastatic.net/pcode/adfox/header-bidding.js"></script>
# <script src="https://im.kommersant.ru/banners/hb2020/hb.js?2004241351319180"></script>
# <script crossorigin="anonymous" src="https://yastatic.net/pcode/adfox/loader.js"></script>
# <script>
# (function() {
# var hm = document.createElement('script'); hm.type ='text/javascript'; hm.async = true;
# hm.src = ('++u-heatmap-it+log-js').replace(/[+]/g,'/').replace(/-/g,'.');
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(hm, s);
# })();
# </script>
# <script type="text/javascript">
# kommersant.user.subscriptionTypes = [{"Id":1,"Name":"Подписка на срочные новости","Title":"Срочные новости в течение дня в рассылке «Коммерсантъ»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":["news.yandex.ru","news.yandex.kz","news.yandex.by","news.yandex.ua","news-clck.yandex.ru"],"Publishing":null,"Region":null},"Priority":1,"LogoHtml":"","ClassSubscriptionPopupContent":""},{"Id":2,"Name":"Подписка на Weekend","Title":"Подпишитесь на&nbsp;рассылку<br> «Свежий номер Коммерсантъ Weekend»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":14,"Region":null},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupContent":"weekend"},{"Id":3,"Name":"Подписка на Деньги","Title":"Подпишитесь на&nbsp;рассылку<br> материалов «Коммерсантъ Деньги»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":3,"Region":null},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupContent":"money"},{"Id":4,"Name":"Подписка на Огонёк","Title":"Подпишитесь на&nbsp;рассылку<br> «Свежий номер Огонёк»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":84,"Region":null},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupContent":"ogonek"},{"Id":5,"Name":"Подписка на Власть","Title":"Подпишитесь на&nbsp;рассылку<br> материалов «Коммерсантъ Власть»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":2,"Region":null},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupContent":"vlast"},{"Id":6,"Name":"Подписка на газету","Title":"Подпишитесь на&nbsp;рассылку","SubTitle":"Свежий номер газеты<br><strong>Коммерсантъ</strong>","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":1,"Region":null},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupContent":"newspaper"},{"Id":7,"Name":"Подписка на дайджест новостей региона Пермь","Title":"Подпишитесь на&nbsp;дайджест<br> новостей в рассылке «Коммерсантъ Пермь»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":null,"Region":59},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupContent":"region"},{"Id":8,"Name":"Подписка на дайджест новостей региона Самара","Title":"Подпишитесь на&nbsp;дайджест<br> новостей в рассылке «Коммерсантъ Самара»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":null,"Region":63},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupContent":"region"},{"Id":9,"Name":"Подписка на дайджест новостей региона Волгоград","Title":"Подпишитесь на&nbsp;дайджест<br> новостей в рассылке «Коммерсантъ Волгоград»","SubTitle":"","ShowInterval":1440,"SubscribingInterval":10080,"SubscribingIntervalRejected":43200,"SubscribingIntervalAnotherWindow":60,"SubscribingIntervalAfterSubscribe":43200,"Conditions":{"Referrers":null,"Publishing":null,"Region":34},"Priority":2,"LogoHtml":"","ClassSubscriptionPopupCon ...
# </script>
# <script>window.last_time_update = 1601669090;</script>
# <script charset="utf-8" src="https://im.kommersant.ru/ContentFlex/js/jquery.nanoscroller.min.js?1607262006591093"></script>
# <script charset="utf-8" src="https://im.kommersant.ru/ContentFlex/js/jquery.datepicker.min.js?1706281831581406"></script>
# </link></link></link></link></link></head>
# <body class="">
# <div id="counters-top" style="position: absolute; visibility: hidden">
# <script>
# (function () {
# 	window.kommersantAnalytics = {
# 		adblock: '',
# 		rubrics: '',
# 		publishing: '',
# 		themes: '',
# 		themegroups: '',
# 		authors: '',
# 		audio: 'No',
# 		liveinternet: ''
# 	};
# 	var advad = new Image();
# 	advad.onload = function () {
# 		window.kommersantAnalytics.adblock = 'No';
# 	};
# 	advad.onerror = function () {
# 		window.kommersantAnalytics.adblock = 'Yes';
# 	};
# 	advad.src = 'https://im.kommersant.ru/ContentFlex/images/adv.gif';
# })();
# </script>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-K37VX3" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>
# 	(function (w, d, s, l, i) {
# 		w[l] = w[l] || []; w[l].push({ 'gtm.start':
# new Date().getTime(), event: 'gtm.js'
# 		}); var f = d.getElementsByTagName(s)[0],
# j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
# '//www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-K37VX3');
# </script>
# <!-- End Google Tag Manager -->
# <!-- Kommersant -->
# <script>
# function counterKommersant() {
# //new Image().src = '//www.kommersant.ru/headerfooter/counterA?p=0&ref=' + escape(document.referrer) + '&rnd=' + Math.floor(Math.random() * 1000000000);
# }
# function counterKommersantRead() {
#
# }
# counterKommersant();
# counterKommersantRead();
# </script>
# <noscript>
# </noscript>
# <!-- /Kommersant -->
# <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "84394", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
# if (d.getElementById(id)) return;
# var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
# ts.src = (d.location.protocol == "https:" ? "https:" : "http:") + "//top-fwz1.mail.ru/js/code.js";
# var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
# if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img alt="" src="//top-fwz1.mail.ru/counter?id=84394;js=na" style="border:0;position:absolute;left:-9999px;"/>
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
# <!--LiveInternet counter-->
# <script>
# function counterLiveInternet() {
# 	new Image().src = "//counter.yadro.ru/hit" + (window.kommersantAnalytics.liveinternet ? ";" + window.kommersantAnalytics.liveinternet : "") + "?r" + escape(document.referrer) + ((typeof (screen) == "undefined") ? "" : ";s" + screen.width + "*" + screen.height + "*" + (screen.colorDepth ? screen.colorDepth : screen.pixelDepth)) + ";u" + escape(document.URL) + ";h" + escape(document.title.substring(0, 80)) + ";" + Math.random();
# }
# counterLiveInternet();
# </script>
# <noscript>
# <img alt="" height="1" src="//counter.yadro.ru/hit" width="1"/>
# </noscript>
# <!--/LiveInternet-->
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
# 	var yaParams = {
#
# };
# </script>
# <script type="text/javascript">
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
# ym(153166, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash: true,
# 	params: yaParams
# });
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/153166" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <img id="advad" src="https://im.kommersant.ru/ContentFlex/images/adv.gif" style="display: none"/>
# <script>
# (function (i, s, o, g, r, a, m) {
# i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
# (i[r].q = i[r].q || []).push(arguments)
# }, i[r].l = 1 * new Date(); a = s.createElement(o),
# m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
# })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
# ga('create', 'UA-875277-5', 'kommersant.ru');
#
# ga('set', 'dimension6', 'No');
# if (window.kommersantAnalytics.adblock) {
# 	ga('set', 'dimension3', window.kommersantAnalytics.adblock || null);
# }
# ga('send', 'pageview');
# </script>
# <!-- tns-counter.ru -->
# <script>
# function counterTns() {
# new Image().src = '//www.tns-counter.ru/V13a***R>' + document.referrer.replace(/\*/g, '%2a') + '*kommersant_ru/ru/CP1251/tmsec=komm_online/' + Math.floor(Math.random() * 900000000 + 100000000);
# }
# counterTns();
# </script>
# <noscript>
# <img alt="" height="1" src="//www.tns-counter.ru/V13a****kommersant_ru/ru/CP1251/tmsec=komm_online/" width="1"/>
# </noscript>
# <!--/tns-counter.ru -->
# <!-- ttsmi2 -->
# <script>
# var ttsmi2_data = {siteid: 40723, count: "site"};
# (function() {
# var sc = document.createElement("script");
# sc.type = "text/javascript";
# sc.async = true;
# sc.src = "//target.smi2.net/client/target.js";
# var s = document.getElementsByTagName("script")[0];
# s.parentNode.insertBefore(sc, s);
# }());
# </script>
# <!--/ttsmi2 -->
# </div>
# <script>
# function countersUpdate() {
# 	counterKommersant();
# 	counterKommersantRead();
#
# 	try {
# 		_tmr.push({id: '84394', type: 'pageView', url: document.URL, start: (new Date()).getTime()});
# 	} catch (ignore) {}
#
# 	counterLiveInternet();
#
# 	(function () {
# 		var yaParams = {};
# 		window.kommersantAnalytics.rubrics && (yaParams.rubric = window.kommersantAnalytics.rubrics);
# 		window.kommersantAnalytics.publishing && (yaParams.publication = window.kommersantAnalytics.publishing);
# 		window.kommersantAnalytics.themes && (yaParams.theme = window.kommersantAnalytics.themes);
# 		window.kommersantAnalytics.themegroups && (yaParams.maintheme = window.kommersantAnalytics.themegroups);
# 		try {
# 			ym(153166, 'params', yaParams);
# 			ym(153166, 'hit', window.location.pathname + window.location.search + window.location.hash, {
# 				params: yaParams
# 			});
# 		} catch (ignore) {}
# 	})();
#
# 	(function () {
# 		try {
# 			ga('set', 'page', window.location.pathname + window.location.search + window.location.hash);
# 			ga('set', 'dimension1', window.kommersantAnalytics.rubrics || null);
# 			ga('set', 'dimension2', window.kommersantAnalytics.publishing || null);
# 			ga('set', 'dimension4', window.kommersantAnalytics.themes || null);
# 			ga('set', 'dimension5', window.kommersantAnalytics.themegroups || null);
# 			ga('set', 'dimension8', window.kommersantAnalytics.authors || null);
# 			ga('set', 'dimension6', window.kommersantAnalytics.audio || null);
# 			ga('set', 'dimension3', window.kommersantAnalytics.adblock || null);
# 			ga('send', 'pageview');
# 		} catch (ignore) {}
# 	})();
#
# 	counterTns();
#
# 	try {
# 		smi2Tracker.track(ttsmi2_data);
# 	} catch (ignore) {}
#
# 	try {
# 		counterIo();
# 	} catch (ignore) { }
# }
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / 0Десктоп / BackGround test-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: BackGround-->
# <div id="adfox_153864371043563488"></div>
# <script>
#
# window.Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_153864371043563488',
#         params: Object.assign({
#             p1: 'cbuhy',
#             p2: 'gbom',
#           }, window.puids || {}),
#          onRender: function () {$('.adfox-banner-background').after('<style>.adv3-2_140pxx1200px {display: none;}@media only screen and (min-width: 1200px) {body {padding-top: 240px;}.main_nav {max-width: 1180px;width: 100%;margin-left: auto;margin-right: auto;}.bg_cover {position: absolute;top: 240px;right: 0;left: 0;bottom: 0;background-color: #fff;width: 1180px;margin: 0 auto;}}</style><div class="bg_cover"></div>')}
#
#        }, ['desktop'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#             }
#     );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: kommersant_tracking / Web / Tracking_all_formats-->
# <!--Категория: <не задана>-->
# <!--Баннер: tracking_Fullscreen-->
# <!--Тип баннера: 1x1_промерочный-->
# <div id="adfox_1489746795378030"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1489746795378030',
#         params: Object.assign({
#             p1: 'bwuyh',
#             p2: 'foqm',
#             pfc: 'blogx',
#             pfb: 'ekubo'
#         }, window.puids || {})
#     }, ['desktop'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#    );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Сквозное размещение / Fullscreen-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: Fullscreen_redesign_test-->
# <div id="adfox_1486107712951600"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_1486107712951600',
#         params: Object.assign({
#             p1: 'blnry',
#             p2: 'eurl'
#         }, window.puids || {})
#     }, ['desktop'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: kommersant_tracking / Tablet / Tracking_all_formats-->
# <!--Категория: <не задана>-->
# <!--Баннер: tracking_Tablet_FullScreen Tablet-->
# <!--Тип баннера: 1x1_промерочный-->
# <div id="adfox_1489757566528014"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1489757566528014',
#         params: Object.assign({
#             p1: 'bwvch',
#             p2: 'foqm',
#             pfc: 'blogx',
#             pfb: 'ekuxl',
#         }, window.puids || {})
#  }, ['tablet'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#     );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Планшет / FullScreen Tablet-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: Fullscreen_redesign_test-->
# <div id="adfox_1486107887739357"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_1486107887739357',
#         params: Object.assign({
#             p1: 'buggw',
#             p2: 'eurl'
#         }, window.puids || {})
#     }, ['tablet'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: kommersant_tracking / mobile / Tracking_all_formats-->
# <!--Категория: <не задана>-->
# <!--Баннер: tracking_Mobile_Full Screen Mobile-->
# <!--Тип баннера: 1x1_промерочный-->
# <div id="adfox_1489754877765270"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_1489754877765270',
#         params: Object.assign({
#             p1: 'bwvcg',
#             p2: 'foqm',
#             pfc: 'blogx',
#             pfb: 'ekusj'
#         }, window.puids || {})
#     }, ['phone'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#     );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Мобильный / Full Screen Mobile-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: Fullscreen_redesign_test-->
# <div id="adfox_1486107930501960"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_1486107930501960',
#         params: Object.assign({
#             p1: 'buggv',
#             p2: 'eurl'
#         }, window.puids || {})
#     }, ['phone'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# <div class="adv3-1_910pxx110px hide1 hide2">
# </div>
# <header class="main_header">
# <nav class="navmenu hide1 hide2">
# <div class="main_nav">
# <div class="layout main_header__inner">
# <div class="main_header__content">
# <div class="main_header__auth_nest">
# </div>
# </div>
# <div class="main_header__aside">
# <ul class="main_nav__list">
# <li class="main_nav__item">
# <a href="/daily?from=header_gazeta">Газета</a>
# </li>
# <li class="main_nav__item">
# <a href="/apps?from=header_prilozheniya">Приложения</a>
# </li>
# <li class="main_nav__item">
# <a href="/ogoniok?from=header_ogoniok">Огонёк</a>
# </li>
# <li class="main_nav__item">
# <a href="/weekend?from=header_weekend">Weekend</a>
# </li>
# <li class="main_nav__item">
# <a class="navmenu-toggle" data-navmenu-id="top-regions" href="/regions?from=header_regions">Регионы</a>
# </li>
# <li class="main_nav__item">
# <a href="/autopilot?from=header_autopilot">Автопилот</a>
# </li>
# <li class="main_nav__item">
# <a href="/nauka?from=header_nauka">Наука</a>
# </li>
# <li class="main_nav__item">
# <a href="http://www.kommersant.uk" target="_blank">UK</a>
# </li>
# <li class="main_nav__item">
# <a class="main_nav_menu__item-name" href="/fm?from=header_fm">
# <img alt="fm radio" class="main_nav_menu__item_logo" src="https://im.kommersant.ru/ContentFlex/images/logos/ico_fm_l.svg"/>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="main_nav_menu navmenu-item" id="navmenu-top-regions">
# <div class="layout">
# <ul class="main_nav_menu__list">
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/78">Санкт-Петербург</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/36">Воронеж</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/66">Екатеринбург</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/18">Ижевск</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/16">Казань</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/23">Краснодар</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/24">Красноярск</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/52">Нижний Новгород</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/54">Новосибирск</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/59">Пермь</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/61">Ростов-на-Дону</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/63">Самара</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/64">Саратов</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/2">Уфа</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/74">Челябинск</a>
# </li>
# <li class="main_nav_menu__item main_nav_menu__item">
# <a class="main_nav_menu__item-name" href="/regions/76">Ярославль</a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="main_header__data_bar hide1 hide2">
# <div class="layout main_header__inner">
# <div class="main_header__content">
# <div class="main_header__auth_nest">
# <div class="b-auth_panel resize js-auth" data-resize-places=".main_header__auth_nest">
# <ul class="b-auth_panel-menu b-auth_panel__login">
# <li class="b-auth_panel-menu__item">
# <a class="b-auth_panel__link user-login" href="#">ВОЙТИ</a>
# </li>
# <li class="b-auth_panel-menu__item">
# <a class="user-register" href="#">Регистрация</a>
# </li>
# </ul>
# <ul class="b-auth_panel-menu b-auth_panel__exit">
# <li class="b-auth_panel-menu__item">
# <a href="/lk/profile?from=header_profil">ПРОФИЛЬ</a>
# </li>
# <li class="b-auth_panel-menu__item">
# <a class="user-logout" href="#">ВЫХОД</a>
# </li>
# </ul>
# <ul class="b-auth_panel-menu b-auth_panel__notification">
# <li class="b-auth_panel-menu__item">
# <a href="/LK/Subscriptions" title="Новые материалы по вашим подпискам">
# <span class="vicon vicon--notification">
# <svg class="vicon__body"><use xlink:href="#vicon-notification" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# </a>
# <a href="/LK/Subscriptions">
# <span class="b-auth_panel-menu__notifications_count js-auth-notifications hide"></span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_header__data">
# <span>02 октября, пятница</span>
# </div>
# </div>
# <div class="main_header__aside">
# <div class="main_header__special_rubric_nest hide3">
# </div>
# <ul class="main_nav__list hide1 hide2">
# <li class="main_nav__item main_nav__item--alt">
# <a href="https://www.kartoteka.ru/" target="_blank">Картотека</a>
# </li>
# <li class="main_nav__item main_nav__item--alt">
# <a href="https://bankruptcy.kommersant.ru" target="_blank">Банкротства</a>
# </li>
# <li class="main_nav__item main_nav__item--alt">
# <a href="/conference?from=header_konferencii">Конференции</a>
# </li>
# <li class="main_nav__item main_nav__item--alt">
# <a href="/subscription?from=header_podpiska">Подписка</a>
# </li>
# <li class="main_nav__item main_nav__item--alt">
# <a href="/photo?from=header_photo">Фотоагентство</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="main_header__logo_bar hide1 hide2">
# <div class="layout main_header__inner">
# <div class="main_header__content">
# <div class="main_header__logo">
# <a class="kbd_button" href="/?from=logo" tabindex="0">
# <div class="kbd_button__body" tabindex="-1">
# <svg aria-label="Kommersant.ru" class="main_header__main_logo"><use xlink:href="#vicon-main_logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </div>
# </a>
# </div>
# </div>
# <div class="main_header__aside">
# <div class="fm_announce__nest">
# </div>
# </div>
# </div>
# </div>
# <nav class="layout main_header__special hide1 hide2">
# <div class="main_header__inner">
# <div class="main_header__content">
# <ul class="main_nav__list">
# <li class="main_nav__item main_nav__item--special">
# <a href="/rubric/47">Страна</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/rubric/5">Мир</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/rubric/3">Экономика</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/rubric/4">Бизнес</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/finance">Финансы</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/realty">Недвижимость</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/rubric/8">Культура</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/rubric/9">Спорт</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/hitech">Hi-Tech</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/auto">Авто</a>
# </li>
# <li class="main_nav__item main_nav__item--special">
# <a href="/style">Стиль</a>
# </li>
# <li class="main_nav__item main_nav__item--search place-search">
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="adv3-1_910pxx110px hide1 hide2" style="margin-bottom: 10px">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: kommersant_tracking / Web / Tracking_all_formats-->
# <!--Категория: <не задана>-->
# <!--Баннер: tracking_100%x240 Перетяжка-->
# <!--Тип баннера: 1x1_промерочный-->
# <div id="adfox_1489746521107767"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_1489746521107767',
#         params: Object.assign({
#             p1: 'bwuyh',
#             p2: 'foqm',
#             pfc: 'blogx',
#             pfb: 'ekueg'
#         }, window.puids || {})
#     }, ['desktop'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#     );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Сквозное размещение / 100%x240 Перетяжка-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: 100%x240_redesign_test-->
# <div id="adfox_148610809667296"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 1092,
#         containerId: 'adfox_148610809667296',
#         params: Object.assign({
#             p1: 'blnrl',
#             p2: 'eurc',
#             pk: 'пожар торговом центре Кемерово Кемеровский зимняя вишня',
#             pke: '1'
#         }, window.puids || {})
#     }, ['desktop'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# </div>
# <div class="mobile_header hide3">
# <!-- верхняя часть шапки -->
# <div class="mobile_header__menu">
# <button class="kbd_button mobile_header__button mobile_header__burger popup_menu__toggle" tabindex="0" title="Меню">
# <div class="kbd_button__body" tabindex="-1">
# <span class="vicon vicon--burger">
# <svg class="vicon__body">
# <use xlink:href="#vicon-burger" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </div>
# </button>
# <div class="mobile_header__middle">
# <a class="kbd_button mobile_header__logo" href="/?from=mobile_logo" tabindex="0">
# <div class="kbd_button__body" tabindex="-1">
# <svg class="mobile_header__logo_image">
# <use xlink:href="#vicon-main_logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </div>
# </a>
# </div>
# <div class="place-search mobile_header__button mobile_header__search">
# <div class="search_window resize" data-resize-places=".place-search" id="navsearch">
# <form action="/search/results" id="navsearch-form" method="get">
# <input name="places" type="hidden" value=""/>
# <input name="categories" type="hidden" value=""/>
# <input name="datestart" type="hidden" value="02.10.2019"/>
# <input name="dateend" type="hidden" value="02.10.2020"/>
# <input name="sort_type" type="hidden" value="1"/>
# <input name="regions" type="hidden" value=""/>
# <input name="results_count" type="hidden" value=""/>
# <input name="page" type="hidden" value="1"/>
# <div class="search__input_wrapper">
# <input class="search__input" id="navsearch-query" name="search_query" placeholder="Поиск по сайту" type="search"/>
# </div>
# <button class="kbd_button search__button mobile_header__button" id="navsearch-submit" tabindex="0" title="Поиск" type="submit">
# <div class="kbd_button__body" tabindex="-1">
# <span class="vicon vicon-search_empty">
# <svg class="vicon__body">
# <use xlink:href="#vicon-search_empty" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# </div>
# </button>
# </form>
# </div>
# </div>
# </div>
# <div class="mobile_header__lk">
# <div class="mobile_header__button mobile_header__enter js-auth is_active">
# <button class="kbd_button mobile_header__button mobile_header__door user-login" tabindex="0" title="Войти" type="button">
# <div class="kbd_button__body" tabindex="-1">
# <span class="vicon vicon--enter">
# <svg class="vicon__body">
# <use xlink:href="#vicon-enter" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# </div>
# </button>
# <a class="kbd_button mobile_header__button mobile_header__user" href="/lk/profile?from=mobile_profil" tabindex="0" title="Профиль">
# <div class="kbd_button__body" tabindex="-1">
# <span class="vicon vicon--user">
# <svg class="vicon__body">
# <use xlink:href="#vicon-user" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# <span class="mobile_header__user_text">Войти в профиль</span>
# <span aria-hidden="true" class="mobile_header__enter_notification js-auth-notifications hide"></span>
# </div>
# </a>
# </div>
# <div class="mobile_header__info">
# <time class="mobile_header__info_text">02 октября, пятница</time>
# </div>
# <div class="fm_announce__nest">
# <button class="kbd_button fm_announce resize" data-resize-places=".fm_announce__nest" tabindex="0" title="Слушать радио">
# <div class="kbd_button__body" tabindex="-1">
# <span class="fm_announce__text">Слушать радио</span>
# <div class="mobile_header__button hide3">
# <span class="vicon vicon--fm_mobile_play">
# <svg class="vicon__body"><use xlink:href="#fm_mobile_play" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# <span class="vicon vicon--fm_mobile_pause">
# <svg class="vicon__body"><use xlink:href="#fm_mobile_pause" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# </div>
# <span class="fm_announce__icon hide1 hide2"></span>
# </div>
# </button>
# </div>
# </div>
# </div>
# <div class="main_header__footer_line"></div>
# <div class="adv1-header_100p hide3">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: kommersant_tracking / mobile / Tracking_all_formats-->
# <!--Категория: <не задана>-->
# <!--Баннер: tracking_Mobile_1000х600 сверху-->
# <!--Тип баннера: 1x1_промерочный-->
# <div id="adfox_1489755438758"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1489755438758',
#         params: Object.assign({
#             p1: 'bwvcg',
#             p2: 'foqm',
#             pfc: 'blogx',
#             pfb: 'ekusk'
#         }, window.puids || {})
#        }, ['phone','tablet'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#     );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Мобильный / 1000х600 сверху-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: 1000х600 сверху-->
# <div id="adfox_1488194504651863"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1488194504651863',
#         params: Object.assign({
#             p1: 'bukwz',
#              p2: 'fibq',
#             pk: 'пожар торговом центре Кемерово Кемеровский зимняя вишня',
#             pke: '1'
#         }, window.puids || {})
#     }, ['phone','tablet'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# </div>
# </header>
# <div class="layout">
# <div class="grid grid--main">
# <div class="grid_cell grid_cell_small grid_cell_nogap hide1 hide2">
# <!-- Коротко (новости) -->
# <div class="place-newsline">
# <section class="b-newsline resize" data-resize-places=".place-newsline">
# <h3 class="title title-indent hide1 hide2"><a href="/news">Коротко</a></h3>
# <h3 class="title_light hide3"><a href="/news">Новости</a></h3>
# <ul class="b-newsline__list">
# <li class="b-newsline__item b-newsline__item--news-of-the-day">
# <article>
# <a href="/doc/4518686?from=hotnews" title="Новость часа">
# <span class="vicon vicon--hot_news">
# <svg class="vicon__body"><use xlink:href="#vicon-hot_news" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# </a>
# <time class="time" pubdate="2020-10-02T17:22:41+03:00">17:22</time>
# <a class="b-newsline__item--news-of-the-day_icon" href="/doc/4518686?from=hotnews" title="Новость часа"></a>
# <div class="photo">
# <a href="/doc/4518686?from=hotnews">
# <picture class="js-lazyimage">
# <source class="js-lazyimage-source" data-lazyimage-srcset="..., https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t241_193951.webp 1200w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t240_193951.webp 1035w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t239_193951.webp 990w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t250_193951.webp 870w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t238_193951.webp 690w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t237_193951.webp 660w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t236_193951.webp 600w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t235_193951.webp 580w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t234_193951.webp 550w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t233_193951.webp 480w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t232_193951.webp 370w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t231_193951.webp 360w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t230_193951.webp 300w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t229_193951.webp 250w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t228_193951.webp 240w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t227_193951.webp 180w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t226_193951.webp 160w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t225_193951.webp 143w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t224_193951.webp 120w" sizes="(min-width: 980px) 143px, 0px" srcset="..." type="image/webp"/>
# <source class="js-lazyimage-source" data-lazyimage-srcset="..., https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t241_193951.jpg 1200w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t240_193951.jpg 1035w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t239_193951.jpg 990w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t250_193951.jpg 870w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t238_193951.jpg 690w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t237_193951.jpg 660w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t236_193951.jpg 600w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t235_193951.jpg 580w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t234_193951.jpg 550w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t233_193951.jpg 480w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t232_193951.jpg 370w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t231_193951.jpg 360w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t230_193951.jpg 300w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t229_193951.jpg 250w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t228_193951.jpg 240w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t227_193951.jpg 180w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t226_193951.jpg 160w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t225_193951.jpg 143w, https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t224_193951.jpg 120w" sizes="(min-width: 980px) 143px, 0px" srcset="..."/>
# <img alt="" class="js-lazyimage-source js-lazyimage-trigger" data-lazyimage-src="https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t219_193951.jpg" src="...">
# </img></picture>
# <noscript>
# <img alt="" class="fallback_image" src="https://im.kommersant.ru/Issues.photo/NEWS/2020/10/02/KNN_006027_00057_1_t219_193951.jpg">
# </img></noscript>
# </a>
# </div>
# <h3 class="article_subheader"><a href="/doc/4518686?from=hotnews">Главред нижегородского издания покончила с собой у здания МВД</a></h3>
# </article>
# </li>
# <li class="b-newsline__item b-newsline__item--news-of-the-day">
# <article>
# <time class="time" pubdate="2020-10-02T19:20:33+03:00">19:20</time>
# <h3 class="article_subheader"><a href="/doc/4518752?from=hotnews">Росстат сообщил о смерти 3222 человек от коронавируса в августе</a></h3>
# </article>
# </li>
# <li class="b-newsline__item b-newsline__item--news-of-the-day">
# <article>
# <time class="time" pubdate="2020-10-02T19:11:04+03:00">19:11</time>
# <h3 class="article_subheader"><a href="/doc/4518746?from=hotnews">США ввели санкции против восьми белорусских чиновников</a></h3>
# </article>
# </li>
# </ul>
# <div class="adv3-6_240pxx400px hide1 hide2">
# </div>
# <ul class="b-newsline__list b-newsline__list--m_main_short">
# <li class="b-newsline__item">
# <article>
# <time class="time" datetime="2020-10-02T19:55:13+03:00">19:55</time>
# <h3 class="article_subheader"><a href="/doc/4518766">Нагорный Карабах заявил об обстреле Степанакерта войсками Азербайджана</a></h3>
# </article>
# </li>
# <li class="b-newsline__item">
# <article>
# <time class="time" datetime="2020-10-02T19:49:42+03:00">19:49</time>
# <h3 class="article_subheader"><a href="/doc/4518764">Байден сдал отрицательный тест на коронавирус</a></h3>
# </article>
# </li>
# <li class="b-newsline__item">
# <article>
# <time class="time" datetime="2020-10-02T19:06:12+03:00">19:06</time>
# <h3 class="article_subheader"><a href="/doc/4518729">Пандемия сказалась на качестве сна людей</a></h3>
# </article>
# </li>
# <li class="b-newsline__item">
# <article>
# <time class="time" datetime="2020-10-02T19:05:36+03:00">19:05</time>
# <h3 class="article_subheader"><a href="/doc/4518741">Умер обвиняемый в бандитизме бывший сити-менеджер Миасса</a></h3>
# </article>
# </li>
# <li class="b-newsline__item">
# <article>
# <time class="time" datetime="2020-10-02T19:00:54+03:00">19:00</time>
# <h3 class="article_subheader"><a href="/doc/4518732">Белорусские санкции против ЕС будут действовать в России</a></h3>
# </article>
# </li>
# <li class="b-newsline__item">
# <article>
# <time class="time" datetime="2020-10-02T18:54:09+03:00">18:54</time>
# <h3 class="article_subheader"><a href="/doc/4518711">США продлили санкции против «Рособоронэкспорта»</a></h3>
# </article>
# </li>
# <li class="b-newsline__item">
# <article>
# <time class="time" datetime="2020-10-02T18:50:23+03:00">18:50</time>
# <h3 class="article_subheader"><a href="/doc/4518723">Ефремов подал новую жалобу на приговор</a></h3>
# </article>
# </li>
# <li class="b-newsline__item hide1 hide2 hide3">
# <article>
# <time class="time" datetime="2020-10-02T18:39:43+03:00">18:39</time>
# <h3 class="article_subheader"><a href="/doc/4518720">Представитель ВОЗ посоветовала не вводить всероссийский локдаун</a></h3>
# </article>
# </li>
# <li class="b-newsline__item hide1 hide2 hide3">
# <article>
# <time class="time" datetime="2020-10-02T18:25:26+03:00">18:25</time>
# <h3 class="article_subheader"><a href="/doc/4518710">Патрушев впервые встретился с помощником Трампа по нацбезопасности</a></h3>
# </article>
# </li>
# <li class="b-newsline__item hide1 hide2 hide3">
# <article>
# <time class="time" datetime="2020-10-02T18:13:48+03:00">18:13</time>
# <h3 class="article_subheader"><a href="/doc/4518648">Экс-начальник ГУ ФСИН Ростовской области получил два года колонии</a></h3>
# </article>
# </li>
# <li class="b-newsline__item hide1 hide2 hide3">
# <article>
# <time class="time" datetime="2020-10-02T18:07:07+03:00">18:07</time>
# <h3 class="article_subheader"><a href="/doc/4518681">Белоруссия предложила Польше и Литве сократить число своих дипломатов</a></h3>
# </article>
# </li>
# <li class="b-newsline__item hide1 hide2 hide3">
# <article>
# <time class="time" datetime="2020-10-02T17:58:05+03:00">17:58</time>
# <h3 class="article_subheader"><a href="/doc/4518694">Апелляционный суд оставил в силе приговор Януковичу</a></h3>
# </article>
# </li>
# </ul>
# <div class="b-newsline__menu">
# <button class="b-newsline__menu_item b-newsline__menu_item__more ui_button ui_button--solid" type="button">
# 			ещё
# 			<span class="vicon vicon--gull_down">
# <svg class="vicon__body"><use xlink:href="#vicon-small_up_arrow" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# </button>
# <a class="b-newsline__menu_item ui_button ui_button--solid" href="/archive/news?from=news">все новости</a>
# </div>
# </section>
# </div>
# <div class="hide1 hide2 place-voting">
# <section class="b-voting resize poll lazyloading" data-resize-places=".place-voting">
# <input type="hidden" value="/poll/last/1721">
# </input></section>
# </div>
# <div class="b-tgb_chain">
# <div class="b-tgb_chain__uho">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Сквозное размещение / ТГБ вертикальный 1-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: ТГБ вертикальный-->
# <div id="adfox_1486108290292353"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1486108290292353',
#         params: Object.assign({
#             p1: 'btfzf',
#             p2: 'ffyl'
#         }, window.puids || {})
#     }, ['desktop'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# </div>
# <div class="b-tgb_chain__uho">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Сквозное размещение / ТГБ вертикальный 2-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: ТГБ вертикальный-->
# <div id="adfox_1486108415839874"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1486108415839874',
#         params: Object.assign({
#             p1: 'btgny',
#             p2: 'ffyl'
#         }, window.puids || {})
#     }, ['desktop'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# </div>
# <div class="b-tgb_chain__uho">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Сквозное размещение / ТГБ вертикальный 3-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: ТГБ вертикальный-->
# ...
# </picture>
# <noscript>
# <img alt="" class="fallback_image" src="https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t218_150836.jpg"/>
# </noscript>
# </a>
# </div>
# </div>
# <div class="text">
# <div class="search_results_stat">
# <span class="vicon vicon--article vicon--small">
# <svg class="vicon__body">
# <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <a href="/archive/online/161" target="_blank">
# <span class="search_results_number">009</span>
# <span class="search_results_source">Ъ-Юг России-Online от 09.04.2020</span>
# </a>
# </div>
# <h2 class="article_name">
# <a href="/doc/4317759?query=python" target="_blank">В Ростове стартовал прием заявок в бесплатные школы цифровых навыков.</a>
# </h2>
# <div class="article_intro">
# <a href="/doc/4317759?query=python" target="_blank">
# 									 ...  числе программирование на <mark>Python</mark> и основы микроэлектроники ...
# 								</a>
# </div>
# </div>
# </div>
# <div class="search_results_item">
# <div class="text">
# <div class="search_results_stat">
# <span class="vicon vicon--article vicon--small">
# <svg class="vicon__body">
# <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# <a href="/archive/online/206" target="_blank">
# <span class="search_results_number">010</span>
# <span class="search_results_source">Ъ-Башкортостан-Online от 06.03.2020</span>
# </a>
# </div>
# <h2 class="article_name">
# <a href="/doc/4282410?query=python" target="_blank">АО «БЭСК» приняло участие в открытии бесплатных школ цифровых навыков для детей «Лифт в будущее»</a>
# </h2>
# <div class="article_intro">
# <a href="/doc/4282410?query=python" target="_blank">
# 									 ...  момент язык программирования — <mark>Python</mark> и получат базовые ...
# 								</a>
# </div>
# </div>
# </div>
# <ul class="search_pager">
# <li class="search_pager__previous_page"><span class="vicon vicon--small"><svg class="vicon__body"><use xlink:href="#vicon-gull_down" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></span></li>
# <li class="search_pager__page search_pager__current_page">1</li>
# <li class="search_pager__page"><a href="/search/results?search_query=python&amp;page=2">2</a></li>
# <li class="search_pager__next_page active"><a href="/search/results?search_query=python&amp;page=2"><span class="vicon vicon--small"><svg class="vicon__body"><use xlink:href="#vicon-gull_down" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></span></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="adv3-14_910pxx110px hide1 hide2">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: kommersant_tracking / Web / Tracking_all_formats-->
# <!--Категория: <не задана>-->
# <!--Баннер: <tracking_100%х240 footer>-->
# <!--Тип баннера: 1x1_промерочный-->
# <div id="adfox_1489746313272902"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1489746313272902',
#         params: Object.assign({
#             p1: 'bwuyh',
#             p2: 'foqm',
#             pfc: 'blogx',
#             pfb: 'ekisb'
#     }, window.puids || {})
#     }, ['desktop'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#    );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Сквозное размещение / 100%х240 footer-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: 100%x240_redesign_test_footer-->
# <div id="adfox_1486973896119987"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1486973896119987',
#         params: Object.assign({
#             p1: 'bwfpj',
#             p2: 'fmox',
#             pct: 'c',
#             pp: 'g'
#         }, window.puids || {})
#     }, ['desktop'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#     );
# </script>
# </div>
# <div class="adv3-2_140pxx1200px hide1 hide2">
# </div>
# <div class="grid hide3">
# <div class="grid_cell">
# <div class="place-voting"></div>
# <div class="place-company_news"></div>
# <div class="adv1-250x50 adv2-250x50 hide3" style="background-color: #ececee; margin-left: -15px; margin-right: -15px;">
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: kommersant_tracking / mobile / Tracking_all_formats-->
# <!--Категория: <не задана>-->
# <!--Баннер: tracking_Mobile_250/50 footer-->
# <!--Тип баннера: 1x1_промерочный-->
# <div id="adfox_1489754354727209"></div>
# <script>
#     window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_1489754354727209',
#         params: Object.assign({
#             p1: 'bwvcg',
#             p2: 'foqm',
#             pfc: 'blogx',
#             pfb: 'ekusg'
#         }, window.puids || {})
#      }, ['phone','tablet'], {
#             tabletWidth: 979.999,
#             phoneWidth: 479.999,
#         }
#     );
# </script>
# <!--AdFox START-->
# <!--kommersant-->
# <!--Площадка: Kommersant_redesign_test / Мобильный / footer-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: 100xAuto_mob-->
# <div id="adfox_150781180893298319"></div>
# <script>
#      window.Ya.adfoxCode.createScroll({
#         ownerId: 1092,
#         containerId: 'adfox_150781180893298319',
#         params: Object.assign({
#             p1: 'bwgav',
#             p2: 'evil',
#            }, window.puids || {})
#        }, ['phone','tablet'], {
#         tabletWidth: 979.999,
#         phoneWidth: 479.999,
#         isAutoReloads: false
#     });
# </script>
# </div>
# </div>
# </div>
# </div>
# <div class="layout">
# <footer class="main_footer" id="footer">
# <div class="main_footer_newspaper">
# <ul class="main_footer_control">
# <li class="main_footer_control__item">
# <a href="/LK/Feedback">Обратная связь</a>
# </li>
# <li class="main_footer_control__item" id="push-subscription-trigger"></li>
# <li class="main_footer_control__item fullversion hide1 hide2 hide">
# <a class="fullversion-link-off" href="#">Мобильная версия</a>
# </li>
# <li class="main_footer_control__item fullversion hide3">
# <a class="fullversion-link-on" href="#">Полная версия сайта</a>
# </li>
# </ul>
# <nav class="main_footer_nav_box">
# <ul class="main_footer_nav">
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link" href="/archive">Архив</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link" href="/authors">Авторы</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link" href="/themes">Темы</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link" href="/doc/3688126">Справочники</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link" href="/specials">Мультимедиа</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link" href="/interactive/tests">Тесты</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link" href="/lk/notification">Email-рассылки</a>
# </li>
# <li class="main_footer_nav__item main_footer_nav__item--br">
# <a class="main_footer_nav__link_info" href="/about">О «Коммерсанте»</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link_info" href="/redaction">Редакция</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link_info" href="/contacts">Контакты</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link_info" href="/digital">iOs&amp;Android</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link_info" href="/vacancies">Вакансии</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link_info" href="/copyright">Правовая информация</a>
# </li>
# <li class="main_footer_nav__item">
# <a class="main_footer_nav__link_adv" href="/ad">Реклама</a>
# </li>
# </ul>
# </nav>
# <div class="main_footer_hand_history">
# <a href="/doc/3882478">
# <picture class="js-lazyimage">
# <img alt="" class="js-lazyimage-source js-lazyimage-trigger" data-lazyimage-src="https://im.kommersant.ru/CorpImages/Custom/new_footer/hand_4x.png" src="..."/>
# </picture>
# <noscript>
# <img alt="" class="fallback_image" src="https://im.kommersant.ru/CorpImages/Custom/new_footer/hand_4x.png"/>
# </noscript>
# </a>
# </div>
# </div>
# <div class="main_footer_commerce">
# <div class="main_footer_commerce__item adv_warn">
# <div class="adv_marker adv_warn__body">
# 				Материалы с такой меткой, партнерские проекты и новости компаний опубликованы на коммерческой основе
# 			</div>
# </div>
# <ul class="main_footer_commerce__item main_footer_icons network">
# <li class="main_footer_icons__item">
# <a href="https://www.facebook.com/kommersant.ru" target="_blank">
# <span class="vicon vicon--fb vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-fb_solid" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="https://vk.com/kommersant_ru" target="_blank">
# <span class="vicon vicon--vk vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-vk_solid" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="https://www.instagram.com/kommersant_online/" target="_blank">
# <span class="vicon vicon--ig vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-ig_solid" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="https://twitter.com/#!/kommersant" target="_blank">
# <span class="vicon vicon--tw vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-tw_solid" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="https://ok.ru/group/53942273310836" target="_blank">
# <span class="vicon vicon--ok vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-ok_solid" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="https://t.me/kommersant" target="_blank">
# <span class="vicon vicon--tg vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-tg_solid" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="https://invite.viber.com/?g2=AQASKm3nkHYfLUfAeChUPQpUmuFiN6WagC%2B%2FFdwldgMHhadaBSbY6LiIYBwfMnfV" target="_blank">
# <span class="vicon vicon--vb vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-vb_solid" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="https://flipboard.com/@Kommersant" target="_blank">
# <span class="vicon vicon--flipboard vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-flipboard" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item">
# <a href="http://subscribe.ru/author/24276108/list" target="_blank">
# <span class="vicon vicon--subscribe_service vicon--circled">
# <svg class="vicon__body">
# <use xlink:href="#vicon-subscribe-service" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="main_footer_icons__item main_footer_icons__item_years">16+</li>
# </ul>
# <ul class="main_footer_commerce__item main_footer_counters hide1 hide2">
# <li class="main_footer_counters__item">
# <!-- Rating@Mail.ru logo -->
# <a href="http://top.mail.ru/jump?from=84394" target="_blank">
# <img alt="Рейтинг@Mail.ru" height="31" src="//top-fwz1.mail.ru/counter?id=84394;t=487;l=1" style="border: 0;" width="88"/>
# </a>
# <!-- //Rating@Mail.ru logo -->
# </li>
# <li class="main_footer_counters__item">
# <!--LiveInternet logo-->
# <a href="http://www.liveinternet.ru/click" target="_blank">
# <img alt="" height="31" src="//counter.yadro.ru/logo?14.1" style="border: 0;" title="LiveInternet: показано число просмотров за 24 часа, посетителей за 24 часа и за сегодня" width="88"/>
# </a>
# <!--/LiveInternet-->
# </li>
# </ul>
# </div>
# <div class="main_footer_copyright">© 1991–2020 АО «Коммерсантъ»<span class="main_footer_copyright__add hide1 hide2">. All rights reserved</span></div>
# </footer>
# </div>
# <div class="popup_menu">
# <div class="popup_menu__inner">
# <button class="kbd_button popup_menu__close" tabindex="0">
# <div class="kbd_button__body" tabindex="-1">
# <span class="vicon vicon--small vicon--close">
# <svg class="vicon__body"><use xlink:href="#vicon-close" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </span>
# </div>
# </button>
# <ul class="popup_menu__list popup_menu__list--main">
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/rubric/47?from=menu_strana">Страна</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/rubric/5?from=menu_mir">Мир</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/rubric/3?from=menu_ekonomika">Экономика</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/rubric/4?from=menu_biznes">Бизнес</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/finance?from=menu_finansi">Финансы</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/realty?from=menu_nedvizimost">Недвижимость</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/rubric/8?from=menu_kultura">Культура</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/rubric/9?from=menu_sport">Спорт</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/hitech?from=menu_hitech">Hi-tech</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/auto?from=menu_auto">Авто</a>
# </li>
# <li class="popup_menu__item popup_menu__item--section">
# <a href="/style?from=menu_style">Стиль</a>
# </li>
# </ul>
# <ul class="popup_menu__list popup_menu__list--issues">
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="/daily?from=menu_gazeta">Газета</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="/apps?from=menu_prilozheniya">Приложения</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="/Ogoniok?from=menu_ogoniok">Огонёк</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="/weekend?from=menu_weekend">Weekend</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="/regions?from=menu_regions">Регионы</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="/autopilot?from=menu_autopilot">Автопилот</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="/nauka?from=menu_nauka">Наука</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue">
# <a href="http://www.kommersant.uk/?from=menu_uk" target="_blank">UK</a>
# </li>
# <li class="popup_menu__item popup_menu__item--issue_other">
# <a href="/fm?from=menu_fm">FM93.6</a>
# </li>
# </ul>
# <ul class="popup_menu__list">
# <li class="popup_menu__item">
# <a href="https://www.kartoteka.ru/?from=menu_kartoteka" target="_blank">Картотека</a>
# </li>
# <li class="popup_menu__item">
# <a href="https://bankruptcy.kommersant.ru/?from=menu_bankrotstva" target="_blank">Банкротства</a>
# </li>
# <li class="popup_menu__item">
# <a href="/Conf?from=menu_konferencii">Конференции</a>
# </li>
# <li class="popup_menu__item">
# <a href="/subscription?from=menu_podpiska">Подписка</a>
# </li>
# <li class="popup_menu__item">
# <a href="/photo?from=menu_photo">Фотоагентство</a>
# </li>
# <li class="popup_menu__item">
# <a href="/academy?from=menu_academy">Академия</a>
# </li>
# </ul>
# </div>
# </div>
# <script src="https://im.kommersant.ru/JScripts/NewWindow.js?1910141750220468"></script>
# <script src="https://im.kommersant.ru/Scripts/poll_new.js?1910141746402031"></script>
# <script async="" charset="utf-8" data-uid="159f1b125b1d2605ef3759146fd44686" id="my-widget-script" src="https://likemore-go.imgsmail.ru/widget.js"></script>
# <script src="https://www.gstatic.com/firebasejs/7.9.1/firebase-app.js" type="text/javascript"></script>
# <script src="https://www.gstatic.com/firebasejs/7.9.1/firebase-messaging.js" type="text/javascript"></script>
# <script src="/ContentFlex/modules/dist/bundle.js?2009221334306328"></script>
# </body>
# </html>

# %%
# добираемся до блоков с новостями
news_blocks = soup.find_all('div', class_='search_results_item')
news_blocks
# Out:
# [<div class="search_results_item search_results_item--media">
#  <div class="search_results_media">
#  <div class="photo">
#  <a href="/doc/4492730?query=python" target="_blank">
#  <picture class="js-lazyimage">
#  <source class="js-lazyimage-source" data-lazyimage-srcset="https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t241_170848.webp 1200w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t240_170848.webp 1035w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t239_170848.webp 990w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t250_170848.webp 870w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t238_170848.webp 690w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t237_170848.webp 660w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t236_170848.webp 600w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t235_170848.webp 580w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t234_170848.webp 550w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t233_170848.webp 480w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t232_170848.webp 370w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t231_170848.webp 360w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t230_170848.webp 300w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t229_170848.webp 250w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t228_170848.webp 240w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t227_170848.webp 180w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t226_170848.webp 160w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t225_170848.webp 143w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t224_170848.webp 120w" sizes="(min-width: 1200px) 180px, (min-width: 980px) 160px, (min-width: 630px) 600px, calc(100vw - 30px)" srcset="..." type="image/webp"/>
#  <source class="js-lazyimage-source" data-lazyimage-srcset="https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t241_170848.jpg 1200w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t240_170848.jpg 1035w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t239_170848.jpg 990w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t250_170848.jpg 870w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t238_170848.jpg 690w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t237_170848.jpg 660w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t236_170848.jpg 600w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t235_170848.jpg 580w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t234_170848.jpg 550w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t233_170848.jpg 480w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t232_170848.jpg 370w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t231_170848.jpg 360w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t230_170848.jpg 300w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t229_170848.jpg 250w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t228_170848.jpg 240w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t227_170848.jpg 180w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t226_170848.jpg 160w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t225_170848.jpg 143w, https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t224_170848.jpg 120w" sizes="(min-width: 1200px) 180px, (min-width: 980px) 160px, (min-width: 630px) 600px, calc(100vw - 30px)" srcset="..."/>
#  <img alt="" class="js-lazyimage-source js-lazyimage-trigger" data-lazyimage-src="https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t218_170848.jpg" src="..."/>
#  </picture>
#  <noscript>
#  <img alt="" class="fallback_image" src="https://im.kommersant.ru/Issues.photo/NAUKA_Online/2020/09/15/KMO_118156_00001_1_t218_170848.jpg"/>
#  </noscript>
#  </a>
#  </div>
#  </div>
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/nauka" target="_blank">
#  <span class="search_results_number">001</span>
#  <span class="search_results_source">Наука от 17.09.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4492730?query=python" target="_blank">SuSMoST — мощный молекулярный инструмент</a>
#  </h2>
#  <h1 class="article_subheader">
#  <a href="/doc/4492730?query=python" target="_blank">
#  									Создан программный комплекс для моделирования самосборки молекулярных слоев
#  								</a>
#  </h1>
#  <div class="article_intro">
#  <a href="/doc/4492730?query=python" target="_blank">
#  									 ...  и простого кода <mark>Python</mark>. Мы надеемся, что ...
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item search_results_item--media">
#  <div class="search_results_media">
#  <div class="photo">
#  <a href="/doc/4450879?query=python" target="_blank">
#  <picture class="js-lazyimage">
#  <source class="js-lazyimage-source" data-lazyimage-srcset="https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t241_225517.webp 1200w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t240_225517.webp 1035w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t239_225517.webp 990w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t250_225517.webp 870w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t238_225517.webp 690w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t237_225517.webp 660w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t236_225517.webp 600w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t235_225517.webp 580w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t234_225517.webp 550w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t233_225517.webp 480w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t232_225517.webp 370w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t231_225517.webp 360w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t230_225517.webp 300w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t229_225517.webp 250w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t228_225517.webp 240w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t227_225517.webp 180w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t226_225517.webp 160w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t225_225517.webp 143w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t224_225517.webp 120w" sizes="(min-width: 1200px) 180px, (min-width: 980px) 160px, (min-width: 630px) 600px, calc(100vw - 30px)" srcset="..." type="image/webp"/>
#  <source class="js-lazyimage-source" data-lazyimage-srcset="https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t241_225517.jpg 1200w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t240_225517.jpg 1035w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t239_225517.jpg 990w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t250_225517.jpg 870w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t238_225517.jpg 690w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t237_225517.jpg 660w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t236_225517.jpg 600w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t235_225517.jpg 580w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t234_225517.jpg 550w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t233_225517.jpg 480w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t232_225517.jpg 370w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t231_225517.jpg 360w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t230_225517.jpg 300w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t229_225517.jpg 250w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t228_225517.jpg 240w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t227_225517.jpg 180w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t226_225517.jpg 160w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t225_225517.jpg 143w, https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t224_225517.jpg 120w" sizes="(min-width: 1200px) 180px, (min-width: 980px) 160px, (min-width: 630px) 600px, calc(100vw - 30px)" srcset="..."/>
#  <img alt="" class="js-lazyimage-source js-lazyimage-trigger" data-lazyimage-src="https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t218_225517.jpg" src="..."/>
#  </picture>
#  <noscript>
#  <img alt="" class="fallback_image" src="https://im.kommersant.ru/Issues.photo/OGONIOK/2020/032/KMO_156501_00044_1_t218_225517.jpg"/>
#  </noscript>
#  </a>
#  </div>
#  </div>
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/ogoniok/125082" target="_blank">
#  <span class="search_results_number">002</span>
#  <span class="search_results_source">Журнал "Огонёк" №32 от 17.08.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4450879?query=python" target="_blank">Отстали на поколение</a>
#  </h2>
#  <h1 class="article_subheader">
#  <a href="/doc/4450879?query=python" target="_blank">
#  									Мнение
#  								</a>
#  </h1>
#  <div class="article_intro">
#  <a href="/doc/4450879?query=python" target="_blank">
#  									 ...  рубежом,— С++, С #, <mark>Python</mark>… В России большие ...
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item">
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/archive/online/163" target="_blank">
#  <span class="search_results_number">003</span>
#  <span class="search_results_source">Ъ-Волга-Урал-Online от 11.08.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4450177?query=python" target="_blank">Питерские и казанские программисты стали победителями хакатона DIGITALSUPERHERO</a>
#  </h2>
#  <div class="article_intro">
#  <a href="/doc/4450177?query=python" target="_blank">
#  									 ...  и методологии, применяя <mark>Python</mark>-разработку, технологии машинного ...
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item search_results_item--media">
#  <div class="search_results_media">
#  <div class="photo">
#  <a href="/doc/4434580?query=python" target="_blank">
#  <picture class="js-lazyimage">
#  <source class="js-lazyimage-source" data-lazyimage-srcset="https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t241_191044.webp 1200w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t240_191044.webp 1035w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t239_191044.webp 990w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t250_191044.webp 870w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t238_191044.webp 690w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t237_191044.webp 660w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t236_191044.webp 600w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t235_191044.webp 580w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t234_191044.webp 550w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t233_191044.webp 480w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t232_191044.webp 370w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t231_191044.webp 360w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t230_191044.webp 300w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t229_191044.webp 250w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t228_191044.webp 240w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t227_191044.webp 180w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t226_191044.webp 160w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t225_191044.webp 143w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t224_191044.webp 120w" sizes="(min-width: 1200px) 180px, (min-width: 980px) 160px, (min-width: 630px) 600px, calc(100vw - 30px)" srcset="..." type="image/webp"/>
#  <source class="js-lazyimage-source" data-lazyimage-srcset="https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t241_191044.jpg 1200w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t240_191044.jpg 1035w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t239_191044.jpg 990w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t250_191044.jpg 870w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t238_191044.jpg 690w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t237_191044.jpg 660w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t236_191044.jpg 600w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t235_191044.jpg 580w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t234_191044.jpg 550w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t233_191044.jpg 480w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t232_191044.jpg 370w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t231_191044.jpg 360w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t230_191044.jpg 300w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t229_191044.jpg 250w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t228_191044.jpg 240w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t227_191044.jpg 180w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t226_191044.jpg 160w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t225_191044.jpg 143w, https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t224_191044.jpg 120w" sizes="(min-width: 1200px) 180px, (min-width: 980px) 160px, (min-width: 630px) 600px, calc(100vw - 30px)" srcset="..."/>
#  <img alt="" class="js-lazyimage-source js-lazyimage-trigger" data-lazyimage-src="https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t218_191044.jpg" src="..."/>
#  </picture>
#  <noscript>
#  <img alt="" class="fallback_image" src="https://im.kommersant.ru/Issues.photo/REGIONS/YAROSLAVL_News/2020/07/29/KYA_000040_00392_1_t218_191044.jpg"/>
#  </noscript>
#  </a>
#  </div>
#  </div>
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/archive/news/76" target="_blank">
#  <span class="search_results_number">004</span>
#  <span class="search_results_source">Лента новостей (Ярославль) от 29.07.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4434580?query=python" target="_blank">В Тутаеве появится центр цифрового образования детей «IT-куб»</a>
#  </h2>
#  <div class="article_intro">
#  <a href="/doc/4434580?query=python" target="_blank">
#  									 ... , как «Программирование на <mark>Python</mark>», «Мобильная разработка», «Разработка ...
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item">
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/archive/online/163" target="_blank">
#  <span class="search_results_number">005</span>
#  <span class="search_results_source">Ъ-Волга-Урал-Online от 07.07.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4407208?query=python" target="_blank">Инновации на рынке Fintech и кибербезопасности: хакатон DIGITAL SUPERHERO приглашает выйти за рамки привычных подходов</a>
#  </h2>
#  <div class="article_intro">
#  <a href="/doc/4407208?query=python" target="_blank">
#  									 ...  и методологии, применяя <mark>Python</mark>-разработку, технологии машинного ...
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item">
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/archive/news/76" target="_blank">
#  <span class="search_results_number">006</span>
#  <span class="search_results_source">Лента новостей (Ярославль) от 02.07.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4399817?query=python" target="_blank">В Тутаеве откроют центр цифрового образования для детей «IT-куб»</a>
#  </h2>
#  <div class="article_intro">
#  <a href="/doc/4399817?query=python" target="_blank">
#  									 ... , как «Программирование на <mark>Python</mark>», «Мобильная разработка», «Разработка ...
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item search_results_item--media">
#  <div class="search_results_media">
#  <div class="photo">
#  <a href="/doc/4377181?query=python" target="_blank">
#  <picture class="js-lazyimage">
#  <source class="js-lazyimage-source" data-lazyimage-srcset="https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t241_104500.webp 1200w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t240_104500.webp 1035w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t239_104500.webp 990w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t250_104500.webp 870w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t238_104500.webp 690w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t237_104500.webp 660w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t236_104500.webp 600w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t235_104500.webp 580w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t234_104500.webp 550w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t233_104500.webp 480w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t232_104500.webp 370w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t231_104500.webp 360w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t230_104500.webp 300w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t229_104500.webp 250w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t228_104500.webp 240w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t227_104500.webp 180w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t226_104500.webp 160w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t225_104500.webp 143w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t224_104500.webp 120w" sizes="(min-width: 1200px) 180px, (min-width: 980px) 160px, (min-width: 630px) 600px, calc(100vw - 30px)" srcset="..." type="image/webp"/>
#  <source class="js-lazyimage-source" data-lazyimage-srcset="https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t241_104500.jpg 1200w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t240_104500.jpg 1035w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t239_104500.jpg 990w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t250_104500.jpg 870w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t238_104500.jpg 690w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t237_104500.jpg 660w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t236_104500.jpg 600w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t235_104500.jpg 580w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t234_104500.jpg 550w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t233_104500.jpg 480w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t232_104500.jpg 370w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t231_104500.jpg 360w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t230_104500.jpg 300w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t229_104500.jpg 250w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t228_104500.jpg 240w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t227_104500.jpg 180w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t226_104500.jpg 160w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t225_104500.jpg 143w, https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t224_104500.jpg 120w" sizes="(min-width: 1200px) 180px, (min-width: 980px) 160px, (min-width: 630px) 600px, calc(100vw - 30px)" srcset="..."/>
#  <img alt="" class="js-lazyimage-source js-lazyimage-trigger" data-lazyimage-src="https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t218_104500.jpg" src="..."/>
#  </picture>
#  <noscript>
#  <img alt="" class="fallback_image" src="https://im.kommersant.ru/Issues.photo/TEMA2/2020/017/KMO_176137_00027_1_t218_104500.jpg"/>
#  </noscript>
#  </a>
#  </div>
#  </div>
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/apps/126451" target="_blank">
#  <span class="search_results_number">007</span>
#  <span class="search_results_source">Приложение к газете "Коммерсантъ" №17 от 30.06.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4377181?query=python" target="_blank">Инвестиции в себя</a>
#  </h2>
#  <h1 class="article_subheader">
#  <a href="/doc/4377181?query=python" target="_blank">
#  									Сколько стоят онлайн-курсы этим летом
#  								</a>
#  </h1>
#  <div class="article_intro">
#  <a href="/doc/4377181?query=python" target="_blank">
#  									 ...  сколько обойдется изучение <mark>Python</mark>, курсы по маркетингу ...  популярных сегодня языков <mark>Python</mark> в «Нетологии» стоило ...
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item">
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/archive/online/293" target="_blank">
#  <span class="search_results_number">008</span>
#  <span class="search_results_source">Ъ-Кубань-Online от 20.05.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4349643?query=python" target="_blank">«МТС» сообщает об увеличении набора специалистов для развития цифровых продуктов компании</a>
#  </h2>
#  <div class="article_intro">
#  <a href="/doc/4349643?query=python" target="_blank">
#  									 ...  (Java, .net, JS, <mark>Python</mark> и других), DevOps ...
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item search_results_item--media">
#  <div class="search_results_media">
#  <div class="photo">
#  <a href="/doc/4317759?query=python" target="_blank">
#  <picture class="js-lazyimage">
#  <source class="js-lazyimage-source" data-lazyimage-srcset="https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t241_150836.webp 1200w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t240_150836.webp 1035w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t239_150836.webp 990w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t250_150836.webp 870w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t238_150836.webp 690w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t237_150836.webp 660w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t236_150836.webp 600w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t235_150836.webp 580w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t234_150836.webp 550w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t233_150836.webp 480w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t232_150836.webp 370w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t231_150836.webp 360w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t230_150836.webp 300w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t229_150836.webp 250w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t228_150836.webp 240w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t227_150836.webp 180w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t226_150836.webp 160w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t225_150836.webp 143w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t224_150836.webp 120w" sizes="(min-width: 1200px) 180px, (min-width: 980px) 160px, (min-width: 630px) 600px, calc(100vw - 30px)" srcset="..." type="image/webp"/>
#  <source class="js-lazyimage-source" data-lazyimage-srcset="https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t241_150836.jpg 1200w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t240_150836.jpg 1035w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t239_150836.jpg 990w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t250_150836.jpg 870w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t238_150836.jpg 690w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t237_150836.jpg 660w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t236_150836.jpg 600w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t235_150836.jpg 580w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t234_150836.jpg 550w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t233_150836.jpg 480w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t232_150836.jpg 370w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t231_150836.jpg 360w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t230_150836.jpg 300w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t229_150836.jpg 250w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t228_150836.jpg 240w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t227_150836.jpg 180w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t226_150836.jpg 160w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t225_150836.jpg 143w, https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t224_150836.jpg 120w" sizes="(min-width: 1200px) 180px, (min-width: 980px) 160px, (min-width: 630px) 600px, calc(100vw - 30px)" srcset="..."/>
#  <img alt="" class="js-lazyimage-source js-lazyimage-trigger" data-lazyimage-src="https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t218_150836.jpg" src="..."/>
#  </picture>
#  <noscript>
#  <img alt="" class="fallback_image" src="https://im.kommersant.ru/Issues.photo/REGIONS/ROSTOV_Online/2020/04/09/KRD_001497_06446_1_t218_150836.jpg"/>
#  </noscript>
#  </a>
#  </div>
#  </div>
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/archive/online/161" target="_blank">
#  <span class="search_results_number">009</span>
#  <span class="search_results_source">Ъ-Юг России-Online от 09.04.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4317759?query=python" target="_blank">В Ростове стартовал прием заявок в бесплатные школы цифровых навыков.</a>
#  </h2>
#  <div class="article_intro">
#  <a href="/doc/4317759?query=python" target="_blank">
#  									 ...  числе программирование на <mark>Python</mark> и основы микроэлектроники ...
#  								</a>
#  </div>
#  </div>
#  </div>,
#  <div class="search_results_item">
#  <div class="text">
#  <div class="search_results_stat">
#  <span class="vicon vicon--article vicon--small">
#  <svg class="vicon__body">
#  <use xlink:href="#vicon-article" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  </span>
#  <a href="/archive/online/206" target="_blank">
#  <span class="search_results_number">010</span>
#  <span class="search_results_source">Ъ-Башкортостан-Online от 06.03.2020</span>
#  </a>
#  </div>
#  <h2 class="article_name">
#  <a href="/doc/4282410?query=python" target="_blank">АО «БЭСК» приняло участие в открытии бесплатных школ цифровых навыков для детей «Лифт в будущее»</a>
#  </h2>
#  <div class="article_intro">
#  <a href="/doc/4282410?query=python" target="_blank">
#  									 ...  момент язык программирования — <mark>Python</mark> и получат базовые ...
#  								</a>
#  </div>
#  </div>
#  </div>]

# %%
# добираемся до текста со ссылкой
articles_intro = list(map(lambda x: x.find('div', class_='article_intro'), news_blocks))
articles_intro
# Out:
# [<div class="article_intro">
#  <a href="/doc/4492730?query=python" target="_blank">
#  									 ...  и простого кода <mark>Python</mark>. Мы надеемся, что ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4450879?query=python" target="_blank">
#  									 ...  рубежом,— С++, С #, <mark>Python</mark>… В России большие ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4450177?query=python" target="_blank">
#  									 ...  и методологии, применяя <mark>Python</mark>-разработку, технологии машинного ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4434580?query=python" target="_blank">
#  									 ... , как «Программирование на <mark>Python</mark>», «Мобильная разработка», «Разработка ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4407208?query=python" target="_blank">
#  									 ...  и методологии, применяя <mark>Python</mark>-разработку, технологии машинного ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4399817?query=python" target="_blank">
#  									 ... , как «Программирование на <mark>Python</mark>», «Мобильная разработка», «Разработка ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4377181?query=python" target="_blank">
#  									 ...  сколько обойдется изучение <mark>Python</mark>, курсы по маркетингу ...  популярных сегодня языков <mark>Python</mark> в «Нетологии» стоило ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4349643?query=python" target="_blank">
#  									 ...  (Java, .net, JS, <mark>Python</mark> и других), DevOps ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4317759?query=python" target="_blank">
#  									 ...  числе программирование на <mark>Python</mark> и основы микроэлектроники ...
#  								</a>
#  </div>,
#  <div class="article_intro">
#  <a href="/doc/4282410?query=python" target="_blank">
#  									 ...  момент язык программирования — <mark>Python</mark> и получат базовые ...
#  								</a>
#  </div>]

# %%
# добираемся до ссылок
a_list = list(map(lambda x: x.find('a').get('href'), articles_intro))
a_list

# %%
# формируем полноценные ссылки
all_refs = list(map(lambda x: 'https://www.kommersant.ru/' + x, a_list))
all_refs

# %%
# объединим все в одну функцию
def get_all_links(url, query):
    all_refs = []
    params = {
        'search_query': query,
    }
    res = requests.get(URL, params)
    time.sleep(0.3)
    soup = BeautifulSoup(res.text, 'html.parser')
    news_blocks = soup.find_all('div', class_='search_results_item')
    articles_intro = list(map(lambda x: x.find('div', class_='article_intro'), news_blocks))
    a_list = list(map(lambda x: x.find('a').get('href'), articles_intro))
    all_refs = list(map(lambda x: 'https://www.kommersant.ru/' + x, a_list))

    return all_refs

all_links = get_all_links(URL, 'python')
all_links

# %%
# но мы же собрали только одну страницу? Хотим ВСЕ новости
def get_all_links(url, query, pages):
    all_refs = []
    params = {
        'search_query': query
    }
    for i in range(pages):
        params['page'] = i + 1
        res = requests.get(URL, params)
        time.sleep(0.3)
        soup = BeautifulSoup(res.text, 'html.parser')
        news_blocks = soup.find_all('div', class_='search_results_item')
        articles_intro = list(map(lambda x: x.find('div', class_='article_intro'), news_blocks))
        a_list = list(map(lambda x: x.find('a').get('href'), articles_intro))
        all_refs += list(map(lambda x: 'https://www.kommersant.ru/' + x, a_list))
    return all_refs

all_links = get_all_links(URL, 'python', 3)
all_links

# %%
import pandas as pd

# %%
# собираем даты, заголовки и тексты новостей
# получаем ошибочку. Значит не у всех получаемых страниц одинаковая разметка
for link in all_links:
    soup = BeautifulSoup(requests.get(link).text, 'html.parser')
    time.sleep(0.3)
    date = pd.to_datetime(soup.find('time', class_='title__cake').get('datetime'), dayfirst=True).date()
    print(date)
    title = soup.find('h1', class_='article_name').text
    print(title)
    text = soup.find('div', class_='article_text_wrapper').text
    print(text)

# %%
# получаем ошибочку. Значит не у всех получаемых страниц одинаковая разметка
for link in all_links:
    soup = BeautifulSoup(requests.get(link).text, 'html.parser')
    if soup.find('div', class_='b-article__publish_date'):
        date = pd.to_datetime(soup.find('div', class_='b-article__publish_date').find('time').get('datetime'), dayfirst=True).date()
    elif soup.find('time', class_='title__cake'):
        date = pd.to_datetime(soup.find('time', class_='title__cake').get('datetime'), dayfirst=True).date()
    print(date)
    if soup.find('h2', class_='article_name'): 
        title = soup.find('h2', class_='article_name').text
    else: 
        title = soup.find('h1', class_='article_name').text    
    print(title)
    text = soup.find('div', class_='article_text_wrapper').text
    print(text)

# %%
# запишем данные в датафрейм
kom_news = pd.DataFrame()
for link in all_links:
    soup = BeautifulSoup(requests.get(link).text, 'html.parser')
    time.sleep(0.3)
    if soup.find('div', class_='b-article__publish_date'):
        date = pd.to_datetime(soup.find('div', class_='b-article__publish_date').find('time').get('datetime'), dayfirst=True).date()
    elif soup.find('time', class_='title__cake'):
        date = pd.to_datetime(soup.find('time', class_='title__cake').get('datetime'), dayfirst=True).date()
    if soup.find('h2', class_='article_name'): 
        title = soup.find('h2', class_='article_name').text
    else: 
        title = soup.find('h1', class_='article_name').text    
    text = soup.find('div', class_='article_text_wrapper').text
    row = {'date': date, 'title': title, 'text': text}
    kom_news = pd.concat([kom_news, pd.DataFrame([row])])  
kom_news

# %%
# обернем в функцию 
def get_kom_news(links):
    kom_news = pd.DataFrame()
    for link in all_links:
        soup = BeautifulSoup(requests.get(link).text, 'html.parser')
        if soup.find('div', class_='b-article__publish_date'):
            date = pd.to_datetime(soup.find('div', class_='b-article__publish_date').find('time').get('datetime'), dayfirst=True).date()
        elif soup.find('time', class_='title__cake'):
            date = pd.to_datetime(soup.find('time', class_='title__cake').get('datetime'), dayfirst=True).date()
        if soup.find('h2', class_='article_name'): 
            title = soup.find('h2', class_='article_name').text
        else: 
            title = soup.find('h1', class_='article_name').text    
        text = soup.find('div', class_='article_text_wrapper').text
        row = {'date': date, 'title': title, 'text': text}
        kom_news = pd.concat([kom_news, pd.DataFrame([row])])  
    return kom_news

# %%
kom_news = get_kom_news(all_links)
kom_news

# %% [markdown]
# # API

# %% [markdown]
# ## Практика 3. Получим данные о песнях исполнителя при помощи  [API ITunes](https://developer.apple.com/library/archive/documentation/AudioVideo/Conceptual/iTuneSearchAPI/index.html)

# %%
# https://developer.apple.com/library/archive/documentation/AudioVideo/Conceptual/iTuneSearchAPI/UnderstandingSearchResults.html#//apple_ref/doc/uid/TP40017632-CH8-SW1
URL = 'https://itunes.apple.com/search?term=jack+johnson'

# %%
res = requests.get(URL)

# %%
res.text

# %%
res.json()

# %%
params = {
    'term': 'шнуров',
    'limit': 200,
#     'offset': 2
}

# %%
# pd.set_option('display.max_columns', 100)
res = requests.get(URL, params)
# res.json()

pd.DataFrame(res.json()['results'])

# %%
params = {
    'term': 'лазарев',
    'limit': 60,
    'attribute': 'allArtistTerm',
    'country': 'ru'
}

# %%
res = requests.get(URL, params)
res.json()

pd.DataFrame(res.json()['results'])

# %% [markdown]
# ## Практика 4. Соберем сообщения из новостной ленты ВК по нужному запросу

# %%
# https://vk.com/dev/manuals
# https://vk.com/dev/newsfeed.search
NEWSFEED_REQUEST = 'https://api.vk.com/method/newsfeed.search?'
TOKEN = '9df7991c9df7991c9df7991c329d86910d99df79df7991cc363a27748dcf7ad91284ef6'
VERSION = '5.103'
SLEEP = 0.33

# %%
# обращаем внимание, что максимальное количество постов, 
# которые можно вытащить за раз, ограничено
params = {
    'access_token': TOKEN,
    'v': VERSION,
    'q': 'короновирус',
    'count': 200
}

# %%
res = requests.get(NEWSFEED_REQUEST, params)
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '{"response":{"items":[{"id":136506,"date":1601653502,"owner_id":-13984605,"from_id":-13984605,"post_type":"post","text":"🚩Почему так резко выросло число заразившихся короновирусом? Кто заменит учителей в возрасте на их посту во время пандемии? Зачем МЧС будет проводить гражданские учения? Во сколько обойдется информбезопасность России? Эти темы в подкасте \\"Слышали новость?\\". \\n\\nСвоим мнением поделился журналист, специальный корреспондент Аркадий Мамонтов. \\n\\n– В интернете сейчас слишком много мнений и информации о коронавирусе, из-за этого происходит неразбериха, люди запуганы. Нужно доверять только официальной информации.","marked_as_ads":0,"attachments":[{"type":"podcast","podcast":{"artist":"Радио Sputnik","id":456239939,"owner_id":-13984605,"title":"Аркадий Мамонтов: пандемия - это война","duration":1525,"is_explicit":false,"is_focus_track":false,"track_code":"e076f1fce668o4u0BneLyvZK2b4hQmaG","url":"https:\\/\\/cs9-12v4.vkuseraudio.net\\/p5\\/b8a5ca7b964708.mp3?extra=Yniu9-KTmeKVIc6G7Cj-Y9FQTbcT_hiVx3C2ym-Txc9m_mPGp_F6Hsj-AP9RHN5iVK0fIhQmgQOpuYUBQ-61jMlboLQVRuxrms0uEoi4W1Ia2-Sd40A4Blr_dVKstkIhzjF-7wXBQHX6Tek&long_chunk=1","date":1601653415,"lyrics_id":449858001,"no_search":1,"podcast_info":{"cover":{"sizes":[{"height":640,"url":"https:\\/\\/sun9-51.userapi.com\\/P1eqEqRmG5iY1xsIWjGxc2eVV6dEeChll7GSVw\\/9QibAQowIRw.jpg","type":"a","width":640},{"height":320,"url":"https:\\/\\/sun9-62.userapi.com\\/2g1tN9Kh5zABu36GBLmryG-GfgB9otWGQYgrfA\\/OK-ZeaL5w0E.jpg","type":"c","width":320},{"height":160,"url":"https:\\/\\/sun9-71.userapi.com\\/Z-rL-zoAehdLgfyTdIl34sGcEgDG1ciHHR8gVQ\\/4UhABUHGxTI.jpg","type":"e","width":160},{"height":240,"url":"https:\\/\\/sun9-76.userapi.com\\/ppUVn-di3Xi6w10z6p1slR8H8qsnLfUZUccRgQ\\/kPg2W6gmuPg.jpg","type":"b","width":240},{"height":120,"url":"https:\\/\\/sun9-72.userapi.com\\/6kaCk7ONotWg8ptxtAzV18eGLx1axY9IKESXCA\\/KkISwuXWOmI.jpg","type":"d","width":120},{"height":100,"url":"https:\\/\\/sun9-18.userapi.com\\/fb3d-APaWR6YxFh2GCr2RfRRB7kQpo-v1ZfSgA\\/CMs6aybfyCA.jpg","type":"f","width":100},{"height":50,"url":"https:\\/\\/sun9-3.userapi.com\\/4GdGvZon7fW2uZSgXK-yEc-vHwvQhVqRqxKUmw\\/U-ejEFo1xTE.jpg","type":"h","width":50},{"height":1400,"url":"https:\\/\\/sun9-19.userapi.com\\/HQwrPtG0Ym1f0xj-OYQj50kzVSePLW5UQ4k2ZQ\\/AGRGvmxwlFc.jpg","type":"x","width":1400}]},"description":"Почему так резко выросло число заразившихся короновирусом? Кто заменит учителей в возрасте на их посту во время пандемии? Зачем МЧС будет проводить гражданские учения? Во сколько обойдется информбезопасность России? Эти темы в подкасте \\"Слышали новость?\\".\\nСвоим мнением поделился журналист, специальный корреспондент Аркадий Мамонтов.\\n– В интернете сейчас слишком много мнений и информации о коронавирусе, из-за этого происходит неразбериха, люди запуганы. Нужно доверять только официальной информации.","is_favorite":false,"plays":11},"short_videos_allowed":false,"stories_allowed":false,"stories_cover_allowed":false}}],"comments":{"count":4},"likes":{"count":8},"reposts":{"count":3},"views":{"count":313}},{"id":31792,"date":1601642160,"owner_id":-80790060,"from_id":-80790060,"post_type":"post","text":"АОКА залида Коронавирусга қарши курашиш штаби аъзоси Барно Абдусаматова аҳолидан тушган айрим саволларга жавоб берди. - Хазонрезги мавсумининг бошланиши, ҳаво ҳарорати совиб бориши билан айрим касалликлар юзага чиқади. Ушбу даврда организм иммунитетини қандай ошириш мумкин? - Инсон иммунитети кўп омилларга боғлиқ. Авваламбор бу — инсоннинг жисмоний ва руҳий саломатлиги, яшаш тарзи, яшаётган муҳитига ҳам боғлиқ. Хусусан, иммунитетнинг сусайишига: интоксикация, турли заҳарланишлар, ҳаддан ташқари чарчаш, оч қолиш, нотўғри овқатланиш, стресс ҳолатлари, касал юқишидан хавотирга тушиш ва қўрқиш, аввалдан кўп ва тез-тез турли касалликларга чалиниш, зарарли одатлар олиб келиши мумкин. Қондаги оқ таначалар ёки лимфоцитларнинг кескин камайиб кетиши — инсон иммун тизимининг сусайганини кўрсатади. Иммунитетни кўтариш учун соғло ...

# %%
res.json()
# Out:
# {'response': {'items': [{'id': 136506,
#     'date': 1601653502,
#     'owner_id': -13984605,
#     'from_id': -13984605,
#     'post_type': 'post',
#     'text': '🚩Почему так резко выросло число заразившихся короновирусом? Кто заменит учителей в возрасте на их посту во время пандемии? Зачем МЧС будет проводить гражданские учения? Во сколько обойдется информбезопасность России? Эти темы в подкасте "Слышали новость?". \n\nСвоим мнением поделился журналист, специальный корреспондент Аркадий Мамонтов. \n\n– В интернете сейчас слишком много мнений и информации о коронавирусе, из-за этого происходит неразбериха, люди запуганы. Нужно доверять только официальной информации.',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'podcast',
#       'podcast': {'artist': 'Радио Sputnik',
#        'id': 456239939,
#        'owner_id': -13984605,
#        'title': 'Аркадий Мамонтов: пандемия - это война',
#        'duration': 1525,
#        'is_explicit': False,
#        'is_focus_track': False,
#        'track_code': 'e076f1fce668o4u0BneLyvZK2b4hQmaG',
#        'url': 'https://cs9-12v4.vkuseraudio.net/p5/b8a5ca7b964708.mp3?extra=Yniu9-KTmeKVIc6G7Cj-Y9FQTbcT_hiVx3C2ym-Txc9m_mPGp_F6Hsj-AP9RHN5iVK0fIhQmgQOpuYUBQ-61jMlboLQVRuxrms0uEoi4W1Ia2-Sd40A4Blr_dVKstkIhzjF-7wXBQHX6Tek&long_chunk=1',
#        'date': 1601653415,
#        'lyrics_id': 449858001,
#        'no_search': 1,
#        'podcast_info': {'cover': {'sizes': [{'height': 640,
#            'url': 'https://sun9-51.userapi.com/P1eqEqRmG5iY1xsIWjGxc2eVV6dEeChll7GSVw/9QibAQowIRw.jpg',
#            'type': 'a',
#            'width': 640},
#           {'height': 320,
#            'url': 'https://sun9-62.userapi.com/2g1tN9Kh5zABu36GBLmryG-GfgB9otWGQYgrfA/OK-ZeaL5w0E.jpg',
#            'type': 'c',
#            'width': 320},
#           {'height': 160,
#            'url': 'https://sun9-71.userapi.com/Z-rL-zoAehdLgfyTdIl34sGcEgDG1ciHHR8gVQ/4UhABUHGxTI.jpg',
#            'type': 'e',
#            'width': 160},
#           {'height': 240,
#            'url': 'https://sun9-76.userapi.com/ppUVn-di3Xi6w10z6p1slR8H8qsnLfUZUccRgQ/kPg2W6gmuPg.jpg',
#            'type': 'b',
#            'width': 240},
#           {'height': 120,
#            'url': 'https://sun9-72.userapi.com/6kaCk7ONotWg8ptxtAzV18eGLx1axY9IKESXCA/KkISwuXWOmI.jpg',
#            'type': 'd',
#            'width': 120},
#           {'height': 100,
#            'url': 'https://sun9-18.userapi.com/fb3d-APaWR6YxFh2GCr2RfRRB7kQpo-v1ZfSgA/CMs6aybfyCA.jpg',
#            'type': 'f',
#            'width': 100},
#           {'height': 50,
#            'url': 'https://sun9-3.userapi.com/4GdGvZon7fW2uZSgXK-yEc-vHwvQhVqRqxKUmw/U-ejEFo1xTE.jpg',
#            'type': 'h',
#            'width': 50},
#           {'height': 1400,
#            'url': 'https://sun9-19.userapi.com/HQwrPtG0Ym1f0xj-OYQj50kzVSePLW5UQ4k2ZQ/AGRGvmxwlFc.jpg',
#            'type': 'x',
#            'width': 1400}]},
#         'description': 'Почему так резко выросло число заразившихся короновирусом? Кто заменит учителей в возрасте на их посту во время пандемии? Зачем МЧС будет проводить гражданские учения? Во сколько обойдется информбезопасность России? Эти темы в подкасте "Слышали новость?".\nСвоим мнением поделился журналист, специальный корреспондент Аркадий Мамонтов.\n– В интернете сейчас слишком много мнений и информации о коронавирусе, из-за этого происходит неразбериха, люди запуганы. Нужно доверять только официальной информации.',
#         'is_favorite': False,
#         'plays': 11},
#        'short_videos_allowed': False,
#        'stories_allowed': False,
#        'stories_cover_allowed': False}}],
#     'comments': {'count': 4},
#     'likes': {'count': 8},
#     'reposts': {'count': 3},
#     'views': {'count': 313}},
#    {'id': 31792,
#     'date': 1601642160,
#     'owner_id': -80790060,
#     'from_id': -80790060,
#     'post_type': 'post',
#     'text': 'АОКА залида Коронавирусга қарши курашиш штаби аъзоси Барно Абдусаматова аҳолидан тушган айрим саволларга жавоб берди. - Хазонрезги мавсумининг бошланиши, ҳаво ҳарорати совиб бориши билан айрим касалликлар юзага чиқади. Ушбу даврда организм иммунитетини қандай ошириш мумкин? - Инсон иммунитети кўп омилларга боғлиқ. Авваламбор бу — инсоннинг жисмоний ва руҳий саломатлиги, яшаш тарзи, яшаётган муҳитига ҳам боғлиқ. Хусусан, иммунитетнинг сусайишига: интоксикация, турли заҳарланишлар, ҳаддан ташқари чарчаш, оч қолиш, нотўғри овқатланиш, стресс ҳолатлари, касал юқишидан хавотирга тушиш ва қўрқиш, аввалдан кўп ва тез-тез турли касалликларга чалиниш, зарарли одатлар олиб келиши мумкин. Қондаги оқ таначалар ёки лимфоцитларнинг кескин камайиб кетиши — инсон иммун тизимининг сусайганини кўрсатади. Иммунитетни кўтариш учун соғлом турмуш тарзига риоя қилиш, зарарли одатлардан воз кечиш, ўз вақтида ва тўғри овқатланиш, маҳсулотлар орасида етарли даражада оқсил, углевод, витамин ва минералларнинг бўлиши муҳим. - Турмуш ўртоғим короновирус билан касалланиб, шифокор назорати остида уйда даволанмоқда. Коронавирусга чалинган беморлар қандай озиқ-овқат маҳсулотларини истеъмол қилиши керак? - COVID-19 билан касалланганлар учун таомлар енгил ҳазм бўладиган, витамин, микроэлемент ва оқсилга бой бўлиши керак. Таомларни кичик ҳажмда барра салат ва кўкатлар билан бирга истеъмол қилиш тавсия этилади. Булар — қайнатма шўрвалар, қийма гўштларидан тайёрланган котлетлар, тефтеллар, фрикаделкалар, балиқ гўшти, творог, сувда қайнатиб чала пиширилган тухум, дуккаклилардан тайёрланган суюқ таомлар, арпа бўтқалари. Шунингдек, кўп миқдорда суюқлик ичилиши мақсадга мувофиқ. Турли мева шарбатлари, компотлар, кўк чой, лимон, смородина, занжабил, асал ва малина чойлари шулар жумласидан. - Коронавирусни юқтириб олган инсонлар жисмоний фаоллик билан шуғулланишлари тавсия этиладими ёки кўпроқ дам олишлари керакми? - Ҳаммаси меъёрида бўлиши керак. Касаллиги аломатсиз ёки енгил шаклда кечаётган беморлар нафас тизими функционал ҳолатини ва жисмоний фаолликни унутмасликлари керак, яъни ҳар кунги эрталабги қиздирувчи 10-15 минутлик бадантарбия машқлари жуда муҳим. Нафас гимнастикаларини кун давомида 3 марта, имкон қадар 5-10 минутдан амалга ошириш керак. Чуқур нафас олиш 6 секунд давомида ва секин нафас чиқариш 4-5 мартагача. Бу машқлар вируснинг ўпка тўқимасига мойиллиги борлиги учун ҳам яхши шамоллатилган хонада бажарилиши керак. Нафас гимнастикасининг жуда хилма-хил турлари мавжуд: Бурденко усули, Йога, Тибет усуллари. Сиз ўз шифокорингиз билан бу усуллар хақида маслаҳатлашишингиз мумкин ёки уларни ҳар бир киши мустақил равишда ижтимоий тармоқлардан топиб, ҳар ким ўзи учун мосини танлаб, ўзлаштириши мумкин.',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://m.vk.com/@zaminuz-rss-1728873584-84088496',
#        'title': 'Хазонрезги мавсумидаги касалликларга қарши иммунитетни қандай ошириш мумкин? — Бизга қўшилинг: 👉 https://t.me/joinchat/AAAAADwt0NGCRoONT4f1_Q',
#        'caption': 'm.vk.com',
#        'description': 'Article',
#        'photo': {'album_id': 235125454,
#         'date': 1513935113,
#         'id': 456239031,
#         'owner_id': -127435785,
#         'has_tags': False,
#         'sizes': [{'height': 87,
#           'url': 'https://sun9-30.userapi.com/c841427/v841427299/49e55/USKUtzVeLqk.jpg',
#           'type': 'm',
#           'width': 130},
#          {'height': 87,
#           'url': 'https://sun9-60.userapi.com/c841427/v841427299/49e5a/l0Nhn9YSCJA.jpg',
#           'type': 'o',
#           'width': 130},
#          {'height': 133,
#           'url': 'https://sun9-13.userapi.com/c841427/v841427299/49e5b/58tmE5x4N54.jpg',
#           'type': 'p',
#           'width': 200},
#          {'height': 213,
#           'url': 'https://sun9-55.userapi.com/c841427/v841427299/49e5c/tKZlTDmDA1k.jpg',
#           'type': 'q',
#           'width': 320},
#          {'height': 340,
#           'url': 'https://sun9-57.userapi.com/c841427/v841427299/49e5d/el87-uGHdRM.jpg',
#           'type': 'r',
#           'width': 510},
#          {'height': 50,
#           'url': 'https://sun9-65.userapi.com/c841427/v841427299/49e54/RFh2HdaZ-c0.jpg',
#           'type': 's',
#           'width': 75},
#          {'height': 1023,
#           'url': 'https://sun9-68.userapi.com/c841427/v841427299/49e59/d3TSz4Ej5RQ.jpg',
#           'type': 'w',
#           'width': 1536},
#          {'height': 402,
#           'url': 'https://sun9-29.userapi.com/c841427/v841427299/49e56/OB5UEvb8_v0.jpg',
#           'type': 'x',
#           'width': 604},
#          {'height': 537,
#           'url': 'https://sun9-26.userapi.com/c841427/v841427299/49e57/8TRGIjyMtS4.jpg',
#           'type': 'y',
#           'width': 807},
#          {'height': 852,
#           'url': 'https://sun9-58.userapi.com/c841427/v841427299/49e58/N-Q-dK3xQ04.jpg',
#           'type': 'z',
#           'width': 1280}],
#         'text': '',
#         'user_id': 100},
#        'button': {'title': 'Read',
#         'action': {'type': 'open_url',
#          'url': 'https://m.vk.com/@zaminuz-rss-1728873584-84088496'}}}}],
#     'comments': {'count': 0},
#     'likes': {'count': 0},
#     'reposts': {'count': 0},
#     'views': {'count': 15}},
#    {'id': 82216,
#     'date': 1601634602,
#     'owner_id': -133242605,
#     'from_id': -133242605,
#     'post_type': 'post',
#     'text': '💭 #ВопросДня@nastiarizik\n\n— Москва с 5 октября уходит\n на дистанционное обучение из-за короновируса 🧬\n\nКак обстоят дела с короной у вас? \nЕсть кто уходит на дистанционку?',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': 254950692,
#        'date': 1587042129,
#        'id': 457253544,
#        'owner_id': -133242605,
#        'has_tags': False,
#        'access_key': 'c5126441fd8ec0283c',
#        'sizes': [{'height': 130,
#          'url': 'https://sun9-63.userapi.com/tOcts_7wvMcOeskEVv5WaeZcWQObnegbcd_IcA/Rq3hzoUwuYI.jpg',
#          'type': 'm',
#          'width': 105},
#         {'height': 162,
#          'url': 'https://sun9-28.userapi.com/pagpz0Oz_MDv3UoWzhAmmlBf8nluuq0OZItOUA/H-E3OoNCVLw.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 249,
#          'url': 'https://sun9-7.userapi.com/wYS8gn8iItn0wnPP8wS5ggo1_xB4AZ3TAlbznQ/Gc6QabdwbaU.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 398,
#          'url': 'https://sun9-44.userapi.com/wBHO0bYC__C-ugOv6-B2LYo7HXHgJabldS7fBg/G5buROFAxCo.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 634,
#          'url': 'https://sun9-42.userapi.com/XW3ZOR1nZM5RmDDBpA8IS4LQubFRTT8eICNuNw/Q0cjbLKFnEI.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 75,
#          'url': 'https://sun9-12.userapi.com/MjGSIAaMpzUzhyMmI3-tng5-UzxCXPD6_nGxng/9MFEoah6y1w.jpg',
#          'type': 's',
#          'width': 61},
#         {'height': 604,
#          'url': 'https://sun9-68.userapi.com/t7YAx38QSgvpUhgAjlRVn9MgQlG--rEmwvUiPw/r-vtfT7K4Ro.jpg',
#          'type': 'x',
#          'width': 486},
#         {'height': 807,
#          'url': 'https://sun9-40.userapi.com/LuIdIead10w0DdNvxAoRi23SArr2eyvv-6ZKCA/L0qpeBQ-Wek.jpg',
#          'type': 'y',
#          'width': 649},
#         {'height': 1080,
#          'url': 'https://sun9-49.userapi.com/EOsTF-xh6mphZZm9r7WYfb8GpHL44Wgxlbxhkg/IJv1XyUVnEg.jpg',
#          'type': 'z',
#          'width': 869}],
#        'text': '',
#        'user_id': 100}}],
#     'comments': {'count': 4},
#     'likes': {'count': 120},
#     'reposts': {'count': 0},
#     'views': {'count': 1117}},
#    {'id': 4126,
#     'date': 1601632810,
#     'owner_id': -171261988,
#     'from_id': -171261988,
#     'post_type': 'post',
#     'text': 'В связи с неблагоприятной ситуацией, связанной с короновирусом, профилактические мероприятия с предпринимателями, предусмотренные Планом - графиком профилактических мероприятий с хозяйствующими субъектами Управления Роспотребнадзора по Краснодарскому краю на октябрь 2020 года, будут осуществляться 13 октября 2020 года территориальным отделом Управления Роспотребнадзора по Краснодарскому краю в Лабинском, Курганинском и Мостовском районах в телефонном режиме.\nЗаявленная тема: Соблюдение хозяйствующими субъектами требований технических регламентов таможенного союза при реализации (обороте) промышленных товаров ТР ТС 017/2011 «О безопасности продукции легкой промышленности».\nОбращаться с вопросами по заявленной теме могут по телефонам «горячей линии» в территориальный отдел Управления Роспотребнадзора в Лабинском, Курганинском и Мостовском районах по телефонам 8(86169)7-44-30, 7-44-96.\n\n#Мостовской #Роспотребнадзор #семинар',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601628964,
#        'id': 457249766,
#        'owner_id': -171261988,
#        'has_tags': False,
#        'access_key': 'b721a1777a9a1f0691',
#        'post_id': 4126,
#        'sizes': [{'height': 87,
#          'url': 'https://sun9-37.userapi.com/yJ-mSQ79UJFzGJykMYTc0-eFtJHNlUf_zRgccA/uhHYW7cUowo.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 87,
#          'url': 'https://sun9-37.userapi.com/yJ-mSQ79UJFzGJykMYTc0-eFtJHNlUf_zRgccA/uhHYW7cUowo.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 133,
#          'url': 'https://sun9-57.userapi.com/FDtRu-NREnIl247-tU_XKZi_OTsA7e1ZH7AG5g/VeXYtsDGuw0.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 213,
#          'url': 'https://sun9-50.userapi.com/4x37fXrQMu4eAm_NtKJ2PC2CQJD3F8goEReNSg/8vMqoWj-Wmw.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 340,
#          'url': 'https://sun9-40.userapi.com/mo9ZwSGed-j-HZ6eez6_-fmsBE1kVWKfWmd60w/MhygH6R_NMo.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 50,
#          'url': 'https://sun9-39.userapi.com/JsgUxMa079i30X4blxoybdH_vf1llPyeNK2aKw/1Gj5gISyapA.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 403,
#          'url': 'https://sun9-73.userapi.com/htvqnQxmAMHozwpg8TNxSkq6e5zyDJiHhKzL5Q/rWWUzkvXWPg.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 538,
#          'url': 'https://sun9-64.userapi.com/yd_VJHtGaueLBDFsKceBo9Qfu7iP2UU9QHi_dQ/tSgARo6u7qM.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 555,
#          'url': 'https://sun9-13.userapi.com/koA0GguzOfhwcWas7P14q20ZxpUuvbLJRl3TiA/_YNxnioDszs.jpg',
#          'type': 'z',
#          'width': 833}],
#        'text': '',
#        'user_id': 100}}],
#     'comments': {'count': 0},
#     'likes': {'count': 0},
#     'reposts': {'count': 0},
#     'views': {'count': 60}},
#    {'id': 1793645,
#     'date': 1601627408,
#     'owner_id': -23482909,
#     'from_id': -23482909,
#     'post_type': 'post',
#     'text': 'Индексы Мосбиржи и РТС упали на фоне короновируса у Трампа.\n\nРынок акций России открылся снижением основных индексов на 2%. Индекс Мосбиржи на 10:40 опустился на 1,94%, до 2 833,72 пункта. РТС снижается на 2,67%, до 1 143,11 (2,67).\n\nhttp://amp.gs/LPE9',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601627408,
#        'id': 457348533,
#        'owner_id': -23482909,
#        'has_tags': False,
#        'access_key': '28f61b00d21d189b83',
#        'post_id': 1793645,
#        'sizes': [{'height': 130,
#          'url': 'https://sun9-34.userapi.com/8VgJduTqqqSnDTKjwDEQxRV9dTXq8lIcpLn3aA/UI17ysBhRw0.jpg',
#          'type': 'm',
#          'width': 106},
#         {'height': 160,
#          'url': 'https://sun9-42.userapi.com/Bn6al_zphOABsCQwfsevQq-CMt0zx-6FGKvv0Q/CSwGPG44N20.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 246,
#          'url': 'https://sun9-25.userapi.com/Yk9gGnS_EgkXYBF7FFt4_FthLyY7PtBBuS45lQ/rC5zwspBUfQ.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 392,
#          'url': 'https://sun9-35.userapi.com/ZfcMhLXffQ89EUsA3E_mBMeEwLxM5P3pUorUug/NBxJvajx77c.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 625,
#          'url': 'https://sun9-67.userapi.com/LhYSxWb4SYLKW7-QXmtM5-HyiYziM7npx0F2Dw/Q6r6xtRcqbs.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 75,
#          'url': 'https://sun9-45.userapi.com/04zSvWtM-ZmWassLCFbXqffhiTZEAtsT-6z8-w/Lo2qDj4ZrsU.jpg',
#          'type': 's',
#          'width': 61},
#         {'height': 1200,
#          'url': 'https://sun9-24.userapi.com/5a_Xy4AA60YvuiS4ybxRcLUHGFICunx2tLh4sw/I9dQsUZU2K8.jpg',
#          'type': 'w',
#          'width': 979},
#         {'height': 604,
#          'url': 'https://sun9-48.userapi.com/awh35PNfiqnrMCvSWjrjKnHXLEa9QGkCW6pblw/OYhYkS2Q4Os.jpg',
#          'type': 'x',
#          'width': 492},
#         {'height': 807,
#          'url': 'https://sun9-47.userapi.com/bKJdt7s2sbioO0SA1d4jfn56Xj_jsMIqsCbZ3g/UU_2fsAIEpQ.jpg',
#          'type': 'y',
#          'width': 658},
#         {'height': 1080,
#          'url': 'https://sun9-9.userapi.com/3K2d59vaWH4E7WCeQZ3S3-61xiAak__IaTtBEQ/Omdo1vVlQJ4.jpg',
#          'type': 'z',
#          'width': 881}],
#        'text': 'Индексы Мосбиржи и РТС упали на фоне короновируса у Трампа.\n\nРынок акций России открылся снижением основных индексов на 2%. Индекс Мосбиржи на 10:40 опустился на 1,94%, до 2 833,72 пункта. РТС снижается на 2,67%, до 1 143,11 (2,67).\n\nhttp://amp.gs/LPE9',
#        'user_id': 100}}],
#     'comments': {'count': 12},
#     'likes': {'count': 4},
#     'reposts': {'count': 0},
#     'views': {'count': 3106}},
#    {'id': 999950,
#     'date': 1601624422,
#     'owner_id': -29725575,
#     'from_id': -29725575,
#     'post_type': 'post',
#     'text': 'До сих пор многие воспринимают COVID-19 как выдумку. Увы, это далеко не так. Жительница Тюмени летом заразилась COVID-19. Вирус она поборола, но с последствиями болезни не может справиться до сих пор. Почитайте колонку Оксаны Ширвановой о том, как она перенесла ковид и с чем столкнулась.',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://72.ru/text/health/69490305/?utm_source=vk&utm_medium=social&utm_campaign=72',
#        'title': 'Туман в голове, боли до тошноты и светобоязнь. Откровения тюменки, которая переболела короновирусом',
#        'caption': '72.ru',
#        'description': 'Девушка лежала в больнице с пневмонией. После лечения у нее появилась куча осложнений по здоровью',
#        'photo': {'album_id': -26,
#         'date': 1601624422,
#         'id': 457309483,
#         'owner_id': 2000042321,
#         'has_tags': False,
#         'sizes': [{'height': 480,
#           'url': 'https://sun9-70.userapi.com/S_xleNrtSlx-Hy4sVFzUzUbynCCgeKlKmAAQEQ/4K37bjjwzlw.jpg',
#           'type': 'k',
#           'width': 1074},
#          {'height': 240,
#           'url': 'https://sun9-48.userapi.com/4SfoXd6DZ30JYfg913VLS1VUAsptgcW9NSZIrQ/n9V8oh1z67c.jpg',
#           'type': 'l',
#           'width': 537},
#          {'height': 70,
#           'url': 'https://sun9-73.userapi.com/yo8B8sDc6C4xlaNJsX5QMNQ5U8dWayI2rolBrA/8GHVqxBCfWU.jpg',
#           'type': 'm',
#           'width': 130},
#          {'height': 140,
#           'url': 'https://sun9-27.userapi.com/WbjUcD9LHpx67-ppady0_NuZZGdH2fTRIj9SGA/XQ-KeYMTVn0.jpg',
#           'type': 'p',
#           'width': 260},
#          {'height': 39,
#           'url': 'https://sun9-19.userapi.com/c83wQ1Sy0ljYgEnOkOlEicgLWBO5TTKZ7PM-xQ/BnQ1qmJ70Xk.jpg',
#           'type': 's',
#           'width': 75},
#          {'height': 80,
#           'url': 'https://sun9-72.userapi.com/AF9Bp4bRcXHyra-vywokLLMfXALbD0C7h3xDBQ/A6aGOz7xtvM.jpg',
#           'type': 'x',
#           'width': 150}],
#         'text': '',
#         'user_id': 100}}}],
#     'comments': {'count': 16},
#     'likes': {'count': 17},
#     'reposts': {'count': 3},
#     'views': {'count': 5848}},
#    {'id': 550209,
#     'date': 1601623703,
#     'owner_id': -55611432,
#     'from_id': -55611432,
#     'post_type': 'post',
#     'text': 'Мутации короновируса нового типа делают его способным трансформироваться в 10 различных форм для упрощения проникновения в организм, так считают британские ученые из Института Фрэнсиса Крика, передает Fox News',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://nsn.fm/zdorovie/uchenye-vyyasnili-chto-covid-19-stal-esche-opasnee',
#        'title': 'Ученые выяснили, что COVID-19 стал еще опаснее',
#        'caption': 'nsn.fm',
#        'description': 'Мутации короновируса нового типа делают его способным трансформироваться в 10 различных форм для упрощения проникновения в организм, так считают британские ученые из Института Фрэнсиса Крика, передает Fox News',
#        'photo': {'album_id': -25,
#         'date': 1601623713,
#         'id': 457311968,
#         'owner_id': 2000042105,
#         'has_tags': False,
#         'sizes': [{'height': 480,
#           'url': 'https://sun9-40.userapi.com/c857332/v857332292/1864c2/J3dquTEmIKQ.jpg',
#           'type': 'k',
#           'width': 1074},
#          {'height': 240,
#           'url': 'https://sun9-13.userapi.com/c857332/v857332292/1864c1/RK4fO4ifR1Q.jpg',
#           'type': 'l',
#           'width': 537},
#          {'height': 70,
#           'url': 'https://sun9-65.userapi.com/c857332/v857332292/1864be/kk_7juOIGS4.jpg',
#           'type': 'm',
#           'width': 130},
#          {'height': 140,
#           'url': 'https://sun9-51.userapi.com/c857332/v857332292/1864c0/mAITPeugdYg.jpg',
#           'type': 'p',
#           'width': 260},
#          {'height': 39,
#           'url': 'https://sun9-75.userapi.com/c857332/v857332292/1864bd/TVuaBZy_sOM.jpg',
#           'type': 's',
#           'width': 75},
#          {'height': 80,
#           'url': 'https://sun9-18.userapi.com/c857332/v857332292/1864bf/JfCfz26kfrU.jpg',
#           'type': 'x',
#           'width': 150}],
#         'text': '',
#         'user_id': 100}}}],
#     'comments': {'count': 1},
#     'likes': {'count': 3},
#     'reposts': {'count': 1},
#     'views': {'count': 588}},
#    {'id': 941,
#     'date': 1601617964,
#     'owner_id': -186140010,
#     'from_id': -186140010,
#     'post_type': 'post',
#     'text': 'Заместитель главного врача по лечебным вопросам Кузбасской клинической инфекционной больницы Бондаренко Татьяна. "Короновирус. Детская заболеваемость"',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'video',
#       'video': {'access_key': '51ccccaa0dbb4c11dd',
#        'can_comment': 0,
#        'can_like': 1,
#        'can_repost': 1,
#        'can_subscribe': 1,
#        'can_add_to_faves': 1,
#        'can_add': 1,
#        'comments': 0,
#        'date': 1601617945,
#        'description': '',
#        'duration': 34,
#        'image': [{'height': 96,
#          'url': 'https://sun9-55.userapi.com/vj3uok9yYi_lw7e-_9NvRx0DBrad8WVm5CxNsA/w5JUrKWfBTs.jpg',
#          'width': 130,
#          'with_padding': 1},
#         {'height': 120,
#          'url': 'https://sun9-74.userapi.com/6fyD6lTPs9J-yjZuS9QVEduo1WpQsgdHVQgCXQ/qwy08VQXWaY.jpg',
#          'width': 160,
#          'with_padding': 1},
#         {'height': 240,
#          'url': 'https://sun9-59.userapi.com/Iux93H2xurQO6a3fIQoHcnqp5db2ev-B0tyBgg/VtsUj7X3ih0.jpg',
#          'width': 320,
#          'with_padding': 1},
#         {'height': 450,
#          'url': 'https://sun9-38.userapi.com/gE0VsYHO5qKHSd_PLsHj3Wur9bhsCJDOxhUD1w/x7hFIBbZ0qo.jpg',
#          'width': 800,
#          'with_padding': 1},
#         {'height': 720,
#          'url': 'https://sun9-74.userapi.com/bZ_ejSJfo-gBj_6lf_SGkM5sCJ7sRSBZURYdQQ/gaFXXT_tHWE.jpg',
#          'width': 576},
#         {'height': 400,
#          'url': 'https://sun9-76.userapi.com/SoLvjYEmElTElqBZrq4ZaB6-twxWLb7hPmOyqg/EQxPgyezO08.jpg',
#          'width': 320},
#         {'height': 900,
#          'url': 'https://sun9-3.userapi.com/hlsCo8UHdtS2wcXx_WzxcrNUSE6AjvM7m613kQ/Ttjqf2yJCK0.jpg',
#          'width': 720},
#         {'height': 1280,
#          'url': 'https://sun9-43.userapi.com/LK3E2cc_7vzGHtm_u27FkaOHW6sUVplA5HF16g/6Xc_F1aehiE.jpg',
#          'width': 1024},
#         {'height': 4096,
#          'url': 'https://sun9-19.userapi.com/0ofdOl4Al0XlwIXfOUS88hklSp4BGOHWwHx2nA/flZ5S3yVIv4.jpg',
#          'width': 3277}],
#        'first_frame': [{'height': 400,
#          'url': 'https://sun9-61.userapi.com/VptVSjlIaa3tK9QeeDSQdn0LR2Q7OPgQZLIhPQ/vxPDpuwZSzA.jpg',
#          'width': 320},
#         {'height': 200,
#          'url': 'https://sun9-66.userapi.com/fBTRpDmMM_dg1OYYWfTuIx3CBWnWBlkTho6hTw/pm3TTaMt4l0.jpg',
#          'width': 160},
#         {'height': 5120,
#          'url': 'https://sun9-52.userapi.com/Ut4TPxTgM0ifwJ0sgqY2Sww19hh4KbFFF8xqVg/t0Xh6zko_B0.jpg',
#          'width': 4096},
#         {'height': 163,
#          'url': 'https://sun9-64.userapi.com/9aM39ZgChSlCFgQ1h3DRNy-X69ggjG6dLeEeSQ/OdMuN1sPSic.jpg',
#          'width': 130},
#         {'height': 400,
#          'url': 'https://sun9-61.userapi.com/VptVSjlIaa3tK9QeeDSQdn0LR2Q7OPgQZLIhPQ/vxPDpuwZSzA.jpg',
#          'width': 320},
#         {'height': 900,
#          'url': 'https://sun9-18.userapi.com/0RYbuBWvXKlssUuhwypctKBiMP0cVp1w0dzR2w/W_rt_5pfzfk.jpg',
#          'width': 720},
#         {'height': 1280,
#          'url': 'https://sun9-49.userapi.com/PsFcWXAqFhNNKvTfPwGowQO-ielzyRVsHwFdag/O6noW70jvoE.jpg',
#          'width': 1024},
#         {'height': 1600,
#          'url': 'https://sun9-37.userapi.com/ICDCgMf3RxD9mDVfJTjWkwyCbIIBstoOtvieCw/2pHaT_4VY_0.jpg',
#          'width': 1280},
#         {'height': 1000,
#          'url': 'https://sun9-64.userapi.com/3298Hsr8RuuhvIZ1EUUWpJJSFYe4sr_i3xBErw/HDr3Hs7k0uE.jpg',
#          'width': 800}],
#        'width': 864,
#        'height': 1080,
#        'id': 456239220,
#        'owner_id': -186140010,
#        'title': 'Untitled',
#        'track_code': 'video_7dec200au5Dtfj8guXL7JEJ-_h9HBMxkllbJIkIh7Hc25RGE7iyIvPZ-Mya4d_tLSnqQK3Iy_levZPsSRVSCHA',
#        'type': 'video',
#        'views': 24}}],
#     'comments': {'count': 0},
#     'likes': {'count': 2},
#     'reposts': {'count': 0},
#     'views': {'count': 37}},
#    {'id': 31759,
#     'date': 1601555536,
#     'owner_id': -80790060,
#     'from_id': -80790060,
#     'post_type': 'post',
#     'text': 'Соғлиқни сақлаш вазирлиги Жамоатчилик билан алоқалар бўлими тиббиёт фанлари доктори, профессор Шавкат Омонов билан суҳбат уюштирди. – Куз-қиш фасли томоқ, бурун ва қулоқда шикоятлар кўпаядиган мавсум ҳисобланади. Коронавирус хавфи боис кўпчилик томоқ оғриғини ҳам коронавирус аломати, деб шубҳа қилишмоқда. Одатдаги томоқ оғриғи билан коронавирус ўртасида қандай фарқли белгилар бор? – Албатта, куз ва қиш фасллари ЛОР хасталикларининг ўткир ривожланиши ёки сурункали шаклларининг хуруж қилиш даври ҳисобланади. Маълумки, короновирус инфекциясининг асосий кириш дарвозаси сифатида юқори нафас йўллари қаралмоқда. Шу боис буруннинг ачишиши, томоқдаги нохушлик ҳисси, ҳид билишнинг пасайиши кузатилганда одамлар коронавирусга шубҳа қилишмоқда. Маълум бир жиҳатдан бунда асос бор. Чунки, эпидемиологик вазият шуни тақoзо қилмоқда. Беморларда учрайдиган ўткир респиратор шамоллаш, фарингит, ангина ва ринитлар ҳам шунга ўхшаш намоён бўлади. Бироқ қиёсий ажратувчи белгиларни синчиклаб фарқлаш мумкин. Ўткир вирусли инфекциялар, ангиналар ва фарингитлар, одатда, юқори тана ҳарорати билан бошланади. Ангина ва фарингитларда томоқда оғриқ, кўрилганда эса кучли қизариш аломатлари бўлади, коронавирусда эса бироз нохушлик ва енгил қирилиш бўлади, яллиғланишнинг аломатлари кам намоён бўлади. Вирусли ўткир тумовларда бурундан нафас олиш қийинлашади, ажралма келади ва бироз ҳид билиш пасаяди (гипосмия), короновирусда эса бурун йўлларида ажралма бўлмасдан туриб ҳид билиш йўқолади (аносмия). Бироқ ЛОР аъзолари касалликлари билан коронавируснинг биргаликда келиш эҳтимоли мавжудлигини унутмаслик керак. – Айтингчи, гайморит аслида қандай сабаблар оқибатида юзага келади. Дастлабки белгилари, даволаш усуллари ва олдини олиш борасида ўз тавсияларингизни берсангиз. – Гайморит – бурун ёндош бўшлиқлари касалликлари орасида энг кўп учрайди. Гайморитнинг ривожланишига бир нечта омиллар сабаб бўлади. Инсоннинг маҳаллий ёки умумий совқотиши, иммунитетнинг пасайиши, буруннинг ички ўзгаришлари, гаймор бўшлиғининг тишлар билан боғлиқлиги ва унинг табиий тешигининг яхши фаолият кўрсатмаслиги каби ҳолатлар шулар жумласидан. Гайморит ўткир ёки сурункали, бир ёки икки томонлама бўлиши мумкин. Гайморитнинг ўткир ва сурункали турларини, айниқса, болаларда фарқлаш қийин ҳисобланади. Чунки бола, кўпинча, ўз хасталигини яширади ва шикоят қилмайди. Нурли текширишларда гаймор бўшлиғида киста, полип ёки одонтоген ҳосилалар кўринса, бу ҳолат сурункали ҳисобланади. Одатда, яллиғланган бўшлиқ соҳасида маҳаллий оғриқ, бурундан нафас олиш қийинлиги, бош оғриши, ҳарорат кўтарилиши кузатилади. Асоратланмаган ўткир ва сурункали гайморитлар дори воситалари ва муолажалар (антибиотиклар, яллиғланишга карши дорилар, бурунни ювиш, бўшлиқни пункция қилиш, физиотерапевтик муолажалар) билан даволанади. Гайморитларнинг профилактикаси иммун ҳолатни кўтариш, организмни чиниқтириш, тишлар кариесини ўз вақтида даволаш, бурун ичи патологиясини ўз вақтида бартараф этишни ўз ичига олади. – Гайморит касаллигининг қайси босқичида жарроҳлик билан даволанади? – Гайморитларнинг асоратланган, полипли, кистали, холестеатомали, одонтоген турларида жарроҳлик ўтқазилади. Жарроҳлик амалиёти гаймор ёки юқори жағ бўшлиғини тозалаш ва унинг табиий тешиги фаолиятини яхшилашга қаратилади. Операциядан кейинги даврда бемор ўзини эҳтиёт қилмаса, шифокорнинг тавсияларини тўлиқ бажармаса, мазкур касаллик қайта ривожланиши мумкин.',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://m.vk.com/@zaminuz-rss-1728873584-1386966844',
#        'title': 'Нафас йўллари касалликлари билан коронавирус аломатларини қандай фарқласа бўлади? — Бизга қўшилинг: 👉 https://t.me/joinchat/AAAAADwt0NGCRoONT4f1_Q',
#        'caption': 'm.vk.com',
#        'description': 'Article',
#        'photo': {'album_id': 235125454,
#         'date': 1513935113,
#         'id': 456239031,
#         'owner_id': -127435785,
#         'has_tags': False,
#         'sizes': [{'height': 87,
#           'url': 'https://sun9-30.userapi.com/c841427/v841427299/49e55/USKUtzVeLqk.jpg',
#           'type': 'm',
#           'width': 130},
#          {'height': 87,
#           'url': 'https://sun9-60.userapi.com/c841427/v841427299/49e5a/l0Nhn9YSCJA.jpg',
#           'type': 'o',
#           'width': 130},
#          {'height': 133,
#           'url': 'https://sun9-13.userapi.com/c841427/v841427299/49e5b/58tmE5x4N54.jpg',
#           'type': 'p',
#           'width': 200},
#          {'height': 213,
#           'url': 'https://sun9-55.userapi.com/c841427/v841427299/49e5c/tKZlTDmDA1k.jpg',
#           'type': 'q',
#           'width': 320},
#          {'height': 340,
#           'url': 'https://sun9-57.userapi.com/c841427/v841427299/49e5d/el87-uGHdRM.jpg',
#           'type': 'r',
#           'width': 510},
#          {'height': 50,
#           'url': 'https://sun9-65.userapi.com/c841427/v841427299/49e54/RFh2HdaZ-c0.jpg',
#           'type': 's',
#           'width': 75},
#          {'height': 1023,
#           'url': 'https://sun9-68.userapi.com/c841427/v841427299/49e59/d3TSz4Ej5RQ.jpg',
#           'type': 'w',
#           'width': 1536},
#          {'height': 402,
#           'url': 'https://sun9-29.userapi.com/c841427/v841427299/49e56/OB5UEvb8_v0.jpg',
#           'type': 'x',
#           'width': 604},
#          {'height': 537,
#           'url': 'https://sun9-26.userapi.com/c841427/v841427299/49e57/8TRGIjyMtS4.jpg',
#           'type': 'y',
#           'width': 807},
#          {'height': 852,
#           'url': 'https://sun9-58.userapi.com/c841427/v841427299/49e58/N-Q-dK3xQ04.jpg',
#           'type': 'z',
#           'width': 1280}],
#         'text': '',
#         'user_id': 100},
#        'button': {'title': 'Read',
#         'action': {'type': 'open_url',
#          'url': 'https://m.vk.com/@zaminuz-rss-1728873584-1386966844'}}}}],
#     'comments': {'count': 0},
#     'likes': {'count': 0},
#     'reposts': {'count': 0},
#     'views': {'count': 33}},
#    {'id': 1139,
#     'date': 1601555080,
#     'owner_id': -89795477,
#     'from_id': -89795477,
#     'post_type': 'post',
#     'text': 'Уважаемые Шимчане! \n \nНа сегодняшний день в Новгородской области увеличилось количество заболевших короновирусом, и чтобы не подвергать риску заболевания себя и других людей, просьба соблюдать все меры по борьбе с коронавирусом, в том числе масочный режим при нахождении в транспорте общего пользования, на вокзалах, автостанциях и остановках.\n \nБерегите свое здоровье и здоровье своих близких! При первых признаках заболевания обращайтесь в медицинские учреждения!',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601555080,
#        'id': 457240462,
#        'owner_id': -89795477,
#        'has_tags': False,
#        'access_key': 'c705e3c5c928b98be9',
#        'post_id': 1139,
#        'sizes': [{'height': 73,
#          'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=130x73&quality=90&sign=693377526f1a9c26fbd8a165201add93&c_uniq_tag=HSWwLGbKD8cTSSsvEhTg_E0GFDyUSX3rzjCknLuVpC4',
#          'type': 'm',
#          'width': 130},
#         {'height': 87,
#          'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=130x87&quality=90&crop=64,0,672,450&sign=5d73d4ac75645dad49a86a31ca02898c&c_uniq_tag=Z7GOCKBRIAYCTIcKH636xFK_ca1DUobAagdEC2qvsBo',
#          'type': 'o',
#          'width': 130},
#         {'height': 133,
#          'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=200x133&quality=90&crop=61,0,677,450&sign=56dfd3bd7fafa788a420542a69a51dff&c_uniq_tag=wZUEPaZKSmn8zbLid2M3acYRMtWF0xXC55sJGBvZBWY',
#          'type': 'p',
#          'width': 200},
#         {'height': 213,
#          'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=320x213&quality=90&crop=62,0,676,450&sign=f5833f5680c2e9a61062a4de55ee0803&c_uniq_tag=WG7p3F5xLzOKmGkrhbf9DCEWmYEfgxtgvrfOfidst6I',
#          'type': 'q',
#          'width': 320},
#         {'height': 340,
#          'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=510x340&quality=90&crop=62,0,675,450&sign=e9fe28a940262678556d131953548a63&c_uniq_tag=6V8ilHHZFhZWIcwLEp2WlV2dpMtg7fG6ftgm6sZZVpw',
#          'type': 'r',
#          'width': 510},
#         {'height': 42,
#          'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=75x42&quality=90&sign=6f8059b539f0e935067c5e8ab87aec93&c_uniq_tag=RObXwa12_eKalXMM3Bzy6aOtaMU9_KPBt7jXmryNjtY',
#          'type': 's',
#          'width': 75},
#         {'height': 340,
#          'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=604x340&quality=90&sign=a642b4d2479625c97bdbb96444f48c40&c_uniq_tag=8mMdnzYo9CbTpScVD_16332jFlcg1RfG5DRMKVYFFiw',
#          'type': 'x',
#          'width': 604},
#         {'height': 450,
#          'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=800x450&quality=90&proxy=1&sign=395fd343ba3d12623d31b3f93b1590d4&c_uniq_tag=Rxx29z0Y9pwRH_ll3PthkvcZP_7dhePNOE79FY2qOMA',
#          'type': 'y',
#          'width': 800}],
#        'text': '',
#        'user_id': 100}}],
#     'comments': {'count': 0},
#     'likes': {'count': 5},
#     'reposts': {'count': 0},
#     'views': {'count': 237}},
#    {'id': 634994,
#     'date': 1601548980,
#     'owner_id': -51966513,
#     'from_id': -51966513,
#     'post_type': 'post',
#     'text': 'В Раде предложили закупить вакцину от COVID-19 в России \n \nКогда речь идет о защите и выживании украинцев, власти следует сосредоточиться не на строительстве дорог, а на покупке вакцины от COVID-19, которая уже разработана и применяется в России. \n\nТакое заявление на брифинге сегодня, 1 октября, сделал депутат Верховной рады, глава политсовета партии «Оппозиционная платформа — За жизнь» (вторая по величине фракция парламента) Виктор Медведчук, передает корреспондент ИА REGNUM. \n \nПолитик проинформировал, что бюджетный запрос министерства здравоохранения Украины предусматривал выделение 15,08 млрд грн на закупку вакцины от COVID-19 в 2021 году. Министерство, продолжил Медведчук, якобы ведет переговоры с восемью компаниями-производителями о закупке вакцины от коронавируса после завершения испытаний. \n \n«Так сообщил министр здравоохранения Максим Степанов. Он отметил, что, по данным Всемирной организации здравоохранения, на завершающей стадии клинических испытаний находятся вакцины восьми компаний. «Со всеми ними мы ведем переговоры относительно заключения контракта», — прокомментировал Степанов. Правда, в госбюджет на эти цели заложили только 2,6 млрд грн, в 5,8 раза меньше ранее предусмотренного», — сообщил парламентарий. \n \nУ западных компаний, отметил депутат оппозиции, названия которых хорошо известны украинцам в связи с рекламой гигиенических средств и косметики, вакцина от коронавируса пока только в стадии разработки. \n \n«Единственная страна, справившаяся с этой задачей на настоящий момент, — это Российская Федерация, которая уже выпустила и зарегистрировала свою вакцину «Спутник V», разработанную Национальным исследовательским центром эпидемиологии и микробиологии имени Н. Ф. Гамалеи, и начала вакцинацию населения совместно с Российским фондом прямых инвестиций. Россия уже получила заявки из 50 стран СНГ, Европы, Азии, Ближнего Востока и Латинской Америки на более чем 1,2 млрд доз своей вакцины на текущий и следующий год», — отметил лидер ОПЗЖ. \n \nИменно с производителями этой вакцины, убежден Медведчук, надо вести переговоры, если украинская власть собирается спасать граждан страны, «а не кормить грантоедов, осуществляющих закупки лекарственных препаратов за бюджетные средства». Депутат подчеркнул, что с учетом текущей ситуации по коронавирусу делать это надо незамедлительно. \n \n«Однако вместо реальных действий по вакцинированию населения власть строит воздушные замки, ведет переговоры о закупках несуществующей вакцины западных компаний и тратит деньги из коронавирусного фонда на строительство дорог. Во власти действительно считают, что строительство дорог в период разгара эпидемии и при растущем количестве заболевших — это настолько насущный вопрос? Учитывается ли то, что дорожное строительство — одна из наиболее коррумпированных отраслей экономики и что выделяемые на нее средства, по экспертным оценкам, на 30% и больше банально разворовываются? И что нормальных дорог нет даже в Киеве и областных центрах?» — возмущен политик. \n \nМожет, все-таки сосредоточиться на покупке вакцины от COVID-19, которая уже разработана и применяется в России, задался риторическим вопросом депутат. \n \n«Когда речь идет о защите и выживании украинских граждан, уже не до политических игр. Иначе украинская власть доиграется до того, что по новым дорогам, если они, конечно, будут построены, некому будет ездить. Хотя, может быть, в этом и заключается ее главная миссия?» — резюмировал Медведчук. \n \nИА REGNUM напоминает, что сегодня на Украине зафиксирован очередной антирекорд заболеваемости коронавирусом — за последние сутки болезнь подтвердили у 4069 человек. \n \n30 сентября главный санитарный врач страны Виктор Ляшко заявил также об антирекорде по госпитализации людей с подтвержденным коронавирусом. \n \nДо этого президент Владимир Зеленский признал, что в настоящий момент Украина в принципе не может самостоятельно изготовить вакцину от короновируса.',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601543309,
#        'id': 457285966,
#        'owner_id': -51966513,
#        'has_tags': False,
#        'access_key': 'f6fc18a6fc3d6439a9',
#        'post_id': 634994,
#        'sizes': [{'height': 87,
#          'url': 'https://sun9-31.userapi.com/DmnJW5pDmQ6Aug0mujeh9HhwNPgmHeddVWrguw/czujFg_wPGY.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 87,
#          'url': 'https://sun9-31.userapi.com/DmnJW5pDmQ6Aug0mujeh9HhwNPgmHeddVWrguw/czujFg_wPGY.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 133,
#          'url': 'https://sun9-56.userapi.com/2PjilzflVf28gVZ8Mhvdralb2aM7nDHisy7ZKA/eZBAV1HFZfc.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 213,
#          'url': 'https://sun9-71.userapi.com/GEwgpwgXdAnyyod7xrRa-mZ_VrPGxbbO9rZD5A/31OtpMjSqJo.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 340,
#          'url': 'https://sun9-39.userapi.com/jqiZMOrKNffWgahNWnIJrtHE4I5GVaJK_MZrjg/FIf0tYlAIAI.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 50,
#          'url': 'https://sun9-71.userapi.com/ucbyILeuG9NJrDZPS-_av_9UFyfkMCu36w7hCQ/HjYdgapl1ho.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 403,
#          'url': 'https://sun9-27.userapi.com/-rHzUUHv-L09q2nebqXs2nQ3hTCWOG2iNtXQqw/vur_AeSZT1w.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 538,
#          'url': 'https://sun9-49.userapi.com/wXhehphw-yL4tvmatL4OZRpl7nuXgn8B1_mxfg/ain2arPFj28.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 683,
#          'url': 'https://sun9-33.userapi.com/OqMBt7UgIqTCxizbkG4imjd0shzaZsYv9AAL7w/P1_lYRJEVpI.jpg',
#          'type': 'z',
#          'width': 1024}],
#        'text': '',
#        'user_id': 100}}],
#     'comments': {'count': 5},
#     'likes': {'count': 11},
#     'reposts': {'count': 1},
#     'views': {'count': 1074}},
#    {'id': 3736,
#     'date': 1601538986,
#     'owner_id': -161491660,
#     'from_id': -161491660,
#     'post_type': 'post',
#     'text': 'Дорогие ветераны! \n Сердечно поздравляю вас с Днём старшего поколения. \n Москва всегда широко отмечала этот замечательный праздник, наполненный заботой о бабушках и дедушках, матерях и отцах. Но в этом году пандемия короновируса нарушила многие планы, вынуждая свернуть и мероприятия по случаю самых разных праздничных дат. \nПожилые граждане наиболее уязвимы для нового вируса. Поэтому в эти осенние дни я ещё раз прошу вас поберечь себя и оставаться дома. И помните, что мы вас любим и очень хотим радоваться общению с вами ещё многие-многие годы. \n Пандемия пройдёт, жизнь вернется в обычное русло. И День старшего поколения вновь станет одной из самых главных дат в праздничном календаре столицы. \n Желаю вам, дорогие ветераны, доброго здоровья, бодрости духа, сердечного тепла и благополучия.',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1601538986,
#        'id': 457253122,
#        'owner_id': -161491660,
#        'has_tags': False,
#        'access_key': 'ebaefe3e757b6404fd',
#        'post_id': 3736,
#        'sizes': [{'height': 87,
#          'url': 'https://sun9-66.userapi.com/mT2Ni5t9HZUOOBmnxUZwIxx68gOIV2aEtrneWg/ruVOszteTa4.jpg',
#          'type': 'm',
#          'width': 130},
#         {'height': 87,
#          'url': 'https://sun9-66.userapi.com/mT2Ni5t9HZUOOBmnxUZwIxx68gOIV2aEtrneWg/ruVOszteTa4.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 134,
#          'url': 'https://sun9-56.userapi.com/udiMpZii-n-rW8dg1iZlMJ_g_6Oxm6MUl-Fr-A/d7fjGhtFJvA.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 215,
#          'url': 'https://sun9-2.userapi.com/BKjOkCyFWa0-wBrEdjtgTjxtitQcjEtK-Q-4oQ/7jfCa9HFtNE.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 342,
#          'url': 'https://sun9-63.userapi.com/Vrn076w4SVXTwzFbwLEjzlSNpb6gqyMuya63eQ/dUNfAJq-574.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 50,
#          'url': 'https://sun9-60.userapi.com/GGwFSaQ8LfiM5NVPnycEhnDECqGUGDlRMESndA/iVfC7UQjtLI.jpg',
#          'type': 's',
#          'width': 75},
#         {'height': 1717,
#          'url': 'https://sun9-39.userapi.com/2MgmYMbIQz_8xezuAQjUiYHnjCXcqpLvpkwgXQ/W_lh3hfskOE.jpg',
#          'type': 'w',
#          'width': 2560},
#         {'height': 405,
#          'url': 'https://sun9-22.userapi.com/eK-ofW7W5MIum0dYE_d1hqPql7gQpShrrbwhLg/6irCizomm5E.jpg',
#          'type': 'x',
#          'width': 604},
#         {'height': 541,
#          'url': 'https://sun9-45.userapi.com/Xn8jUQl0o-b5Chh95lmByyc-I165FAafNMYMWw/4iEVEf9LvtQ.jpg',
#          'type': 'y',
#          'width': 807},
#         {'height': 858,
#          'url': 'https://sun9-29.userapi.com/UTAzbdumXKVWehee0GzLnvNAfT0y9vNEXFGT1g/JxW40ONmENE.jpg',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}}],
#     'comments': {'count': 0},
#     'likes': {'count': 72},
#     'reposts': {'count': 20},
#     'views': {'count': 286}},
#    {'id': 142331,
#     'date': 1601525220,
#     'owner_id': -62298989,
#     'from_id': -62298989,
#     'post_id': 142322,
#     'post_type': 'reply',
#     'text': '[id18189966|Евгений], здравствуйте! На этой неделе погода солнечная и сухая, но в начале сентября была холодная. Понижение температуры наружного воздуха влечет аналогичное понижение внутри помещений, что отрицательно сказывается на здоровье в период сезонного роста заболеваемости населения ОРВ, тем более в условиях пандемии короновируса. Отопительный сезон в Уфе в этом году стартовал немного раньше и в два этапа. В первую очередь, 15 сентября, тепло подали в школах, садиках и больницах, с 17 сентября отопление начали подключать в жилых домах. 21 сентября отопление было подано на всех объектах социальной сферы и жилого фонда. К сожалению, отключение отопления на несколько дней после начала отопительного сезона при кратковременном потеплении, является крайне затруднительно в связи с тем, что создает сложности при повторном пуске тепла. Снижение температуры теплоносителя, подаваемого от котельных на температуру ниже 75 градусов повлечет за собой снижение нормативного уровня горячей воды. Наряду с этим, по поручению и. о. первого заместителя главы администрации городского округа город Уфа Радмила Муслимова от 29 сентября 2020 года, Управление по обеспечению жизнедеятельности города администрации Уфы ведет работу с управляющими компаниями по обеспечению понижения при необходимости температуры теплоносителя в домах в зависимости от внешней температуры воздуха. С целью создания комфортной температуры в жилых помещениях жителям необходимо обратиться в свою управляющую организацию. Обращаем внимание, что понижение температуры теплоносителя осуществляется в каждом доме индивидуально с учетом его технических особенностей. С уважением, Марсель Байдавлетов, начальник информационно-аналитического управления - пресс-службы администрации Уфы',
#     'marked_as_ads': 0,
#     'comments': {'count': 0},
#     'likes': {'count': 0},
#     'reposts': {'count': 0}},
#    {'id': 34693,
#     'date': 1601472970,
#     'owner_id': -59796939,
#     'from_id': -59796939,
#     'post_type': 'post',
#     'text': 'В Петербурге готовятся к очередному эпидемиологическому сезону. Готовятся с тревогой и опасениями – короновирус внес свои коррективы во всю нашу жизнь. И сезонный всплеск заболеваний ОРВИ и гриппом уже воспринимается не как рядовое событие, а как новая опасность. И к ней стоит подготовиться заранее, чтобы избежать последствий. 18 процентов петербуржцев, которые уже успели сделать прививки, могут быть спокойны. Для всех остальных расскажем, зачем нужны вакцины.\n\n#Репортажи@avtoradiospb #грипп',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://m.vk.com/@avtoradiospb-zaschita-ot-virusa',
#        'title': 'Защита от вируса',
#        'caption': 'm.vk.com',
#        'description': 'Article',
#        'photo': {'album_id': -66,
#         'date': 1601472958,
#         'id': 457259329,
#         'owner_id': -59796939,
#         'has_tags': False,
#         'sizes': [{'height': 97,
#           'url': 'https://sun9-27.userapi.com/trTS2Ygy4c64bPNydPaHiHDzRw8K9a_zSAM0hA/L7IIdMRydLs.jpg',
#           'type': 'm',
#           'width': 130},
#          {'height': 98,
#           'url': 'https://sun9-35.userapi.com/XQwd_mc1NPqrNB6F5L1vV8uTIA9CH0-WDRW-9Q/cOGKNmbfxTU.jpg',
#           'type': 'o',
#           'width': 130},
#          {'height': 150,
#           'url': 'https://sun9-13.userapi.com/060wPIvMOrf3yIJcJ6e3yPlsDUjJvtjzEZz7aA/SCsBhU88ez4.jpg',
#           'type': 'p',
#           'width': 200},
#          {'height': 240,
#           'url': 'https://sun9-72.userapi.com/PxR-94oYf1DgVpSL3XFI3MvsxVe-yFHgDHe3Ag/kV4tyEoHJyY.jpg',
#           'type': 'q',
#           'width': 320},
#          {'height': 383,
#           'url': 'https://sun9-70.userapi.com/PE-xviXZ8Yx8u-Kh25hh9Yhtl2wMVk6eHvi5fw/5fLOlXWVs9Y.jpg',
#           'type': 'r',
#           'width': 510},
#          {'height': 56,
#           'url': 'https://sun9-34.userapi.com/msek0JlbPDn_ukc1fvf997DfUopLM1nhFbXDjA/y6sYsLq5EVs.jpg',
# ...
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://smolgazeta.ru/daylynews/78217-.html',
#        'title': 'Ещё 74 жителя Смоленской области победили COVID-19',
#        'caption': 'smolgazeta.ru',
#        'description': 'Портал стопкоронавирус.рф обновил данные о ситуации с новой коронавирусной инфекцией...',
#        'photo': {'album_id': -28,
#         'date': 1596527006,
#         'id': 457300569,
#         'owner_id': 2000013236,
#         'has_tags': False,
#         'sizes': [{'height': 90,
#           'url': 'https://sun9-33.userapi.com/9LkLnn0f1tmQNxmgyUCXM3RSMBgvpih991csuQ/l__LgFR0ef8.jpg',
#           'type': 'a',
#           'width': 200},
#          {'height': 180,
#           'url': 'https://sun9-63.userapi.com/o0K_aQG9WNhE_NjrTMXHpYV3vqSdFPNQ0Bmi5w/r6WXjL0uYJk.jpg',
#           'type': 'b',
#           'width': 400},
#          {'height': 200,
#           'url': 'https://sun9-49.userapi.com/dSro1avXXEqo3lXz4mzcSiSjd1xXR-JYl1Bc5A/EwppLEiU9uQ.jpg',
#           'type': 'c',
#           'width': 200},
#          {'height': 100,
#           'url': 'https://sun9-69.userapi.com/WMGhDi0gmgocL2Sfd6O9xYo9HCLCDK7YBKW4gQ/i8CHJQY2Y4A.jpg',
#           'type': 'd',
#           'width': 100},
#          {'height': 50,
#           'url': 'https://sun9-3.userapi.com/FrBJZhGU1lZgdsRLKTqFxZOadbgQEBHMeG0DBA/CenQEHWTHKM.jpg',
#           'type': 'e',
#           'width': 50},
#          {'height': 480,
#           'url': 'https://sun9-73.userapi.com/WW8hQl47h_tIVV0mylIKbAUto_qzKyVVTnZBXg/XclmVHcKaDc.jpg',
#           'type': 'k',
#           'width': 1069},
#          {'height': 240,
#           'url': 'https://sun9-35.userapi.com/Og6CfeHWg9tq2rX5gDaJE3PFgdFm7Daoq9NHLA/UxPc3iyfVFs.jpg',
#           'type': 'l',
#           'width': 537},
#          {'height': 537,
#           'url': 'https://sun9-54.userapi.com/Hf4uTXbGpDChunBNv6DIVFl71ElccopQWexJTQ/FZv4lfZ3GFw.jpg',
#           'type': 'o',
#           'width': 1196}],
#         'text': '',
#         'user_id': 100}}}],
#     'comments': {'count': 0},
#     'likes': {'count': 1},
#     'reposts': {'count': 0},
#     'views': {'count': 109}},
#    {'id': 80821,
#     'date': 1596454467,
#     'owner_id': -84566848,
#     'from_id': -84566848,
#     'post_type': 'post',
#     'text': 'Основатель «Тинькофф Банка» Олег Тиньков выписан из больницы после пересадки костного мозга. На своей странице в Instagram бизнесмен уже делился тем как справляется с заболеванием, а также рассказывал о ранее перенесенном короновирусе. В последний день июля предприниматель сообщил своим подписчикам, что наконец-то вернулся домой после сложной операции. «Home, sweet home. В больнице хорошо, а дома лучше. Теперь нужно продержаться 6 месяцев! Те встретить Рождество вместе с вами. Господи спаси и сохрани…», — написал бизнесмен. Ранее Олег выкладывал видео, на котором благодарил всех за помощь и поддержку, а также рассказывал об открытии благотворительного фонда «Фонд семьи Тиньковых». К слову, заниматься работой фонда будет его жена Рина: «Моя жена Рина, будет непосредственно этим заниматься. Мы хотим пожертвовать часть своего состояния на решение проблем рака крови и развития института донорства в нашей стране…». Напомним, в начале марта предприниматель и владелец одноименного банка Олег Тиньков сообщил, что у него диагностирована острая форма лейкемии. Об этом говорилось в заявлении, поступившем в издание «Медуза». По словам Тинькова, заболевание было диагностировано еще в конце октября, и именно благодаря своевременному четкому диагностированию заболевания врачам удалось быстро добиться ремиссии. «Мне поставили диагноз в октябре, я прошел уже несколько курсов химиотерапии. Мне приходилось в жизни бороться за себя и за свое дело, но сейчас я буду бороться за главное — за саму жизнь. Это самый сложный этап в моей непростой жизни, но я надеюсь на Бога, свое тело, друзей и вашу поддержку», — говорилось в сообщении.',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://trts.io/21cwp',
#        'title': '«Теперь нужно продержаться 6 месяцев»: Олег Тиньков выписан из больницы',
#        'caption': 'peopletalk.ru',
#        'description': 'Основатель «Тинькофф Банка» Олег Тиньков выписан из больницы после пересадки костного мозга. На своей странице в Instagram бизнесмен уже делился тем как справляется с заболеванием, а также рассказывал о ранее перенесенном короновирусе. В последний день июля предприниматель сообщил своим подписчикам, что наконец-то вернулся домой после сложной операции. «Home, sweet home. В больнице хорошо, а дома',
#        'photo': {'album_id': -28,
#         'date': 1596454473,
#         'id': 457303620,
#         'owner_id': 2000012292,
#         'has_tags': False,
#         'sizes': [{'height': 480,
#           'url': 'https://sun9-27.userapi.com/c858032/v858032618/2310e1/H1n4l8sjDXQ.jpg',
#           'type': 'k',
#           'width': 1074},
#          {'height': 240,
#           'url': 'https://sun9-27.userapi.com/c858032/v858032618/2310e0/OYm_mFapuA8.jpg',
#           'type': 'l',
#           'width': 537},
#          {'height': 93,
#           'url': 'https://sun9-56.userapi.com/c858032/v858032618/2310dd/wkv7zaLL5b0.jpg',
#           'type': 'm',
#           'width': 130},
#          {'height': 186,
#           'url': 'https://sun9-33.userapi.com/c858032/v858032618/2310df/gF7ADrKRE3Y.jpg',
#           'type': 'p',
#           'width': 260},
#          {'height': 54,
#           'url': 'https://sun9-51.userapi.com/c858032/v858032618/2310dc/F3iT8ryGOuQ.jpg',
#           'type': 's',
#           'width': 75},
#          {'height': 107,
#           'url': 'https://sun9-39.userapi.com/c858032/v858032618/2310de/hs-XRg-hwX8.jpg',
#           'type': 'x',
#           'width': 150}],
#         'text': '',
#         'user_id': 100}}}],
#     'comments': {'count': 0},
#     'likes': {'count': 0},
#     'reposts': {'count': 0},
#     'views': {'count': 269}},
#    {'id': 29636,
#     'date': 1596454402,
#     'owner_id': -80790060,
#     'from_id': -80790060,
#     'post_type': 'post',
#     'text': 'Бугун АОКАда Коронавирусга қарши кураш штаби аъзоси Севара Убайдуллаева иштирокида брифинг бўлиб ўтди. Брифингдан айрим муҳим савол-жавобларни қуйида келтирамиз. - COVID-19 ўпка ҳажмига таъсир кўрсатадими? - Ҳа таъсир қилади. Яъни, агар беморда МСКТ (мультисписал компьютер томография)сида ўпкада маълум фоизда жароҳатланиш кузатилса, бу меъёрий ҳажмда ўпканинг шунча соҳаси фаолияти орқада қолаётганини билдиради. Бу эса, ўпканинг шунча қисми нафас фаолиятида фаол иштирок этмаслигини билдиради. Инсон организми қайта тикланишга мойил. Доимий енгил жисмоний фаоллик билан шуғулланиш ва нафас машқларини бажариш билан ўпкани жароҳатланишидан асрашга ёки жароҳатланган соҳаларни тиклашга, ўзингизга ўзингиз ёрдам беришингиз мумкин. - Короновирус касаллиги кимларга юқмаслиги ҳақида маълумотлар мавжудми? - ЖССТ томонидан бу касалликка ҳамма чалиниши мумкинлиги тўғрисида маълумот берилган. Бугунги кундаги ҳолатга тўхталадиган бўлсак, ниқоб тақиб юриш ва ижтимоий масофа сақлаш ҳамда имкон қадар ўзини алоҳидалаганларга юқиш эҳтимоли пасаяди ёки вирус организмга тушиши камаяди. Одамлар билан мулоқотни чеклаган инсонларга юқмаслиги мумкин. Лекин вақт ўтиб, ҳар бир инсон ҳаёти давомида бу инфекция билан барибир тўқнашади ва шу даврда короновируснинг касаллик чақириш қобилияти камайган бўлса енгил кечиради. - Ҳавонинг зарарланиши пневмония билан касалланган беморлар соғайишига қанчалик ҳалақит қилади? - Бемор алоҳида ётган хона ҳавосини тез-тез шамоллатиб туриш зарур, кун давомида 5-6 марта; - ҳар куни хонани намли тозалаш мақсадга мувофиқ; - беморга тинчлик, хотиржамлик, тоза ҳаволи шароитни яратиб бериш лозим; - овқатланиш рациони тўлақонли бўлиши керак. Булар ўз навбатида касалликдан тезроқ тузалишга имкон беради. - Ингаляция ёрдам берадими? - Ингаляция турли йўтал шаклларида балғамни юмшатиш ва дренажлашлашда ёки бронхоспазмларда спазмни йўқотишда турли дори-дармонларни қўллаш билан тавсия этилади. Коронавирус билан касалланишда балғамсиз, қуруқ йўтал кузатилади. Бундай ҳолатда ингаляция қилиш яллиғланишга ёки йўтал кучайишига олиб келиши мумкин. Шундай экан, касаллик босқичини ҳисобга олган ҳолда, ингаляцияни қўллаш қатъий шифокор тавсияси ва назорати остида тавсия этилади.',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'link',
#       'link': {'url': 'https://m.vk.com/@zaminuz-rss-1728873584-2007143616',
#        'title': 'Коронавируснинг ўпкага таъсирини камайтириш йўллари маълум қилинди — Бизга қўшилинг: 👉 https://t.me/joinchat/AAAAADwt0NGCRoONT4f1_Q',
#        'caption': 'm.vk.com',
#        'description': 'Article',
#        'photo': {'album_id': 235125454,
#         'date': 1513935113,
#         'id': 456239031,
#         'owner_id': -127435785,
#         'has_tags': False,
#         'sizes': [{'height': 87,
#           'url': 'https://sun9-30.userapi.com/c841427/v841427299/49e55/USKUtzVeLqk.jpg',
#           'type': 'm',
#           'width': 130},
#          {'height': 87,
#           'url': 'https://sun9-60.userapi.com/c841427/v841427299/49e5a/l0Nhn9YSCJA.jpg',
#           'type': 'o',
#           'width': 130},
#          {'height': 133,
#           'url': 'https://sun9-13.userapi.com/c841427/v841427299/49e5b/58tmE5x4N54.jpg',
#           'type': 'p',
#           'width': 200},
#          {'height': 213,
#           'url': 'https://sun9-55.userapi.com/c841427/v841427299/49e5c/tKZlTDmDA1k.jpg',
#           'type': 'q',
#           'width': 320},
#          {'height': 340,
#           'url': 'https://sun9-57.userapi.com/c841427/v841427299/49e5d/el87-uGHdRM.jpg',
#           'type': 'r',
#           'width': 510},
#          {'height': 50,
#           'url': 'https://sun9-65.userapi.com/c841427/v841427299/49e54/RFh2HdaZ-c0.jpg',
#           'type': 's',
#           'width': 75},
#          {'height': 1023,
#           'url': 'https://sun9-68.userapi.com/c841427/v841427299/49e59/d3TSz4Ej5RQ.jpg',
#           'type': 'w',
#           'width': 1536},
#          {'height': 402,
#           'url': 'https://sun9-29.userapi.com/c841427/v841427299/49e56/OB5UEvb8_v0.jpg',
#           'type': 'x',
#           'width': 604},
#          {'height': 537,
#           'url': 'https://sun9-26.userapi.com/c841427/v841427299/49e57/8TRGIjyMtS4.jpg',
#           'type': 'y',
#           'width': 807},
#          {'height': 852,
#           'url': 'https://sun9-58.userapi.com/c841427/v841427299/49e58/N-Q-dK3xQ04.jpg',
#           'type': 'z',
#           'width': 1280}],
#         'text': '',
#         'user_id': 100},
#        'button': {'title': 'Read',
#         'action': {'type': 'open_url',
#          'url': 'https://m.vk.com/@zaminuz-rss-1728873584-2007143616'}}}}],
#     'comments': {'count': 0},
#     'likes': {'count': 0},
#     'reposts': {'count': 0},
#     'views': {'count': 75}},
#    {'id': 1616,
#     'date': 1596422490,
#     'owner_id': -144080984,
#     'from_id': -144080984,
#     'post_type': 'post',
#     'text': 'Чтобы спасти дочь, мама преодолела всё. Сомнения родни, ошибки диагностики лечения, огромное расстояние, коронавирусные преграды и административные препоны. Остался последний шаг, самый трудный. И этот шаг – деньги. У Миланы четвертая стадия нейробластомы, и помогать ей надо очень срочно https://fond.predanie.ru/blago/340953/?utm_medium=vk&utm_source=vk&utm_campaign=isa_3082020_dereberya\n\nМилана с мамой живут в городе со звучным названием Экибастуз. Это не Россия, это Казахстан. А значит, никакой помощи от российского государства ждать Милане не стоит – даже если ты маленькая страдающая девочка, цвет твоего паспорта имеет значение. \n \nИз письма мамы: \n \n"Миланочка росла веселым, отзывчивым и очень добрым ребенком. Ходила в детский сад, пошла в первый лицейный класс, училась на отлично, занималась в художественной школе. Но весной 2019г. у нее сильно заболела спина, она таяла на глазах, что мы только не делали, прошли пять УЗИ, сдали всевозможные анализы, пролечились месяц в детской больнице, но боли не проходили, а только усилились, обезболивающие сиропы не помогали, мы перешли на уколы. Когда Миланочка совсем ослабла и не могла вставать, ей делали рентген, ее легкие были заполнены жидкостью, пошли метастазы, а опухоль, которую увидели на КТ и МРТ, выросла и сдавила легкие. Нас перевели в детскую онкологию, где после биопсии образования сообщили страшный диагноз «Забрюшинная нейробластома с метастазами в л/узлах 4 стадия, крыло высокого риска», так как этим заболеванием болеют дети до года, учитывая возраст Милы (9 лет) прогноз был неблагоприятный. Мы начали сложное лечение. \n \nЗа год Милана прошла 23 наркоза, сбор стволовых клеток, 2 операции, 15 взятий пункций костного мозга, 18 рентгенографий, 6 высокодозных химиотерапий, лучевую терапию, несколько переливаний крови, несчетное количество сборов крови и прочих сопроводительных терапий. \n \nУ Миланы остаточная неоперабельная опухоль больших размеров вдоль позвоночника". \n \nЧтобы продолжить лечение маме с Миланой пришлось прорываться через кордоны, поставленные пандемией. Это было очень трудно, и они много раз теряли надежду. Но теперь это позади. \n \nПятого июля Милана прилетела в Москву, чтобы узнать, что опухоль возвращается. И что снвоа нужно очень много денег. И снова впереди двенадцать курсов химиотерапии, которые ещё надо как-то оплатить. \n \nИ надежда у мамы и Миланы на нас. Больше, кажется, почти никого не осталось. \n \nИз письма: \n \n"Я смогла привезти ребенка из Казахстана в Москву на лечение! Все преграды, связанные с короновирусом удалось преодолеть, кроме одной. В связи с экономической ситуацией помощь фондов резко сократилась! Денег на лечение ребёнка просто нет! \n \nМы уже в больнице и нам нужно срочно пройти курс химиотерапии, но мы не можем его оплатить. У ребенка рецидив! Помогите пожалуйста!"\n\nСобранные средства пойдут на оплату лечения в НМИЦ им. Н.Н. Блохина.\n\nПомочь Милане можно здесь https://fond.predanie.ru/blago/340953/?utm_medium=vk&utm_source=vk&utm_campaign=isa_3082020_dereberya',
#     'marked_as_ads': 0,
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1596422490,
#        'id': 457239568,
#        'owner_id': -144080984,
#        'has_tags': False,
#        'access_key': '94e840c96d80f3781a',
#        'post_id': 1616,
#        'sizes': [{'height': 130,
#          'url': 'https://sun9-35.userapi.com/sGb8qVkb24yRljV8UKAijPqtjn7dik88rHJOhg/RRAFfAOKVXI.jpg',
#          'type': 'm',
#          'width': 124},
#         {'height': 137,
#          'url': 'https://sun9-3.userapi.com/4W11TeK0zfOsOJxJvabcV5I7o_mrRkRu5EzRMQ/hblJ34QbALQ.jpg',
#          'type': 'o',
#          'width': 130},
#         {'height': 210,
#          'url': 'https://sun9-2.userapi.com/_-ZVYL22nGfNC8TWTA4sIDMOG3o6m9FxbnTuOQ/_lngk8NZszI.jpg',
#          'type': 'p',
#          'width': 200},
#         {'height': 337,
#          'url': 'https://sun9-34.userapi.com/9qnkFSJH5PgB2HKnuHZsl1mvC5zR5ieKT9G9Vg/SXKR51FPGPg.jpg',
#          'type': 'q',
#          'width': 320},
#         {'height': 537,
#          'url': 'https://sun9-28.userapi.com/d_rc-OXPyNSqniXqdAT44Bs5TwUMYykoBHyDvA/2UPy10iLJRc.jpg',
#          'type': 'r',
#          'width': 510},
#         {'height': 75,
#          'url': 'https://sun9-55.userapi.com/6kg6m30kmYLwoqT7uEzZTyoxuDeVa4uQcwSDIA/L_zAhMxHjAk.jpg',
#          'type': 's',
#          'width': 72},
#         {'height': 604,
#          'url': 'https://sun9-19.userapi.com/irFqQ0NJiRZffBvccsOE4GZcbK4O9UJCNJCGow/5MsvdqHZt0s.jpg',
#          'type': 'x',
#          'width': 574},
#         {'height': 695,
#          'url': 'https://sun9-22.userapi.com/2l6KwpOYYGrdvTcSGW3pqAx5EUjdk2SK0B0FyA/0KQARap1EtE.jpg',
#          'type': 'y',
#          'width': 660}],
#        'text': '',
#        'user_id': 100}}],
#     'comments': {'count': 1},
#     'likes': {'count': 44},
#     'reposts': {'count': 9},
#     'views': {'count': 2917}},
#    {'id': 10033,
#     'date': 1596380084,
#     'owner_id': 17555747,
#     'from_id': 17555747,
#     'post_id': 10030,
#     'post_type': 'reply',
#     'text': '[id9578010|Дмитрий], так точно ))) Короновирус планы немного подпортил, потому пока что по России путешествую))',
#     'comments': {'count': 0},
#     'likes': {'count': 0},
#     'reposts': {'count': 0}}],
#   'next_from': '200/17555747_10033',
#   'count': 1000,
#   'total_count': 2600}}

# %%
res.json()['response']['items']
# Out:
# [{'id': 136506,
#   'date': 1601653502,
#   'owner_id': -13984605,
#   'from_id': -13984605,
#   'post_type': 'post',
#   'text': '🚩Почему так резко выросло число заразившихся короновирусом? Кто заменит учителей в возрасте на их посту во время пандемии? Зачем МЧС будет проводить гражданские учения? Во сколько обойдется информбезопасность России? Эти темы в подкасте "Слышали новость?". \n\nСвоим мнением поделился журналист, специальный корреспондент Аркадий Мамонтов. \n\n– В интернете сейчас слишком много мнений и информации о коронавирусе, из-за этого происходит неразбериха, люди запуганы. Нужно доверять только официальной информации.',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'podcast',
#     'podcast': {'artist': 'Радио Sputnik',
#      'id': 456239939,
#      'owner_id': -13984605,
#      'title': 'Аркадий Мамонтов: пандемия - это война',
#      'duration': 1525,
#      'is_explicit': False,
#      'is_focus_track': False,
#      'track_code': 'e076f1fce668o4u0BneLyvZK2b4hQmaG',
#      'url': 'https://cs9-12v4.vkuseraudio.net/p5/b8a5ca7b964708.mp3?extra=Yniu9-KTmeKVIc6G7Cj-Y9FQTbcT_hiVx3C2ym-Txc9m_mPGp_F6Hsj-AP9RHN5iVK0fIhQmgQOpuYUBQ-61jMlboLQVRuxrms0uEoi4W1Ia2-Sd40A4Blr_dVKstkIhzjF-7wXBQHX6Tek&long_chunk=1',
#      'date': 1601653415,
#      'lyrics_id': 449858001,
#      'no_search': 1,
#      'podcast_info': {'cover': {'sizes': [{'height': 640,
#          'url': 'https://sun9-51.userapi.com/P1eqEqRmG5iY1xsIWjGxc2eVV6dEeChll7GSVw/9QibAQowIRw.jpg',
#          'type': 'a',
#          'width': 640},
#         {'height': 320,
#          'url': 'https://sun9-62.userapi.com/2g1tN9Kh5zABu36GBLmryG-GfgB9otWGQYgrfA/OK-ZeaL5w0E.jpg',
#          'type': 'c',
#          'width': 320},
#         {'height': 160,
#          'url': 'https://sun9-71.userapi.com/Z-rL-zoAehdLgfyTdIl34sGcEgDG1ciHHR8gVQ/4UhABUHGxTI.jpg',
#          'type': 'e',
#          'width': 160},
#         {'height': 240,
#          'url': 'https://sun9-76.userapi.com/ppUVn-di3Xi6w10z6p1slR8H8qsnLfUZUccRgQ/kPg2W6gmuPg.jpg',
#          'type': 'b',
#          'width': 240},
#         {'height': 120,
#          'url': 'https://sun9-72.userapi.com/6kaCk7ONotWg8ptxtAzV18eGLx1axY9IKESXCA/KkISwuXWOmI.jpg',
#          'type': 'd',
#          'width': 120},
#         {'height': 100,
#          'url': 'https://sun9-18.userapi.com/fb3d-APaWR6YxFh2GCr2RfRRB7kQpo-v1ZfSgA/CMs6aybfyCA.jpg',
#          'type': 'f',
#          'width': 100},
#         {'height': 50,
#          'url': 'https://sun9-3.userapi.com/4GdGvZon7fW2uZSgXK-yEc-vHwvQhVqRqxKUmw/U-ejEFo1xTE.jpg',
#          'type': 'h',
#          'width': 50},
#         {'height': 1400,
#          'url': 'https://sun9-19.userapi.com/HQwrPtG0Ym1f0xj-OYQj50kzVSePLW5UQ4k2ZQ/AGRGvmxwlFc.jpg',
#          'type': 'x',
#          'width': 1400}]},
#       'description': 'Почему так резко выросло число заразившихся короновирусом? Кто заменит учителей в возрасте на их посту во время пандемии? Зачем МЧС будет проводить гражданские учения? Во сколько обойдется информбезопасность России? Эти темы в подкасте "Слышали новость?".\nСвоим мнением поделился журналист, специальный корреспондент Аркадий Мамонтов.\n– В интернете сейчас слишком много мнений и информации о коронавирусе, из-за этого происходит неразбериха, люди запуганы. Нужно доверять только официальной информации.',
#       'is_favorite': False,
#       'plays': 11},
#      'short_videos_allowed': False,
#      'stories_allowed': False,
#      'stories_cover_allowed': False}}],
#   'comments': {'count': 4},
#   'likes': {'count': 8},
#   'reposts': {'count': 3},
#   'views': {'count': 313}},
#  {'id': 31792,
#   'date': 1601642160,
#   'owner_id': -80790060,
#   'from_id': -80790060,
#   'post_type': 'post',
#   'text': 'АОКА залида Коронавирусга қарши курашиш штаби аъзоси Барно Абдусаматова аҳолидан тушган айрим саволларга жавоб берди. - Хазонрезги мавсумининг бошланиши, ҳаво ҳарорати совиб бориши билан айрим касалликлар юзага чиқади. Ушбу даврда организм иммунитетини қандай ошириш мумкин? - Инсон иммунитети кўп омилларга боғлиқ. Авваламбор бу — инсоннинг жисмоний ва руҳий саломатлиги, яшаш тарзи, яшаётган муҳитига ҳам боғлиқ. Хусусан, иммунитетнинг сусайишига: интоксикация, турли заҳарланишлар, ҳаддан ташқари чарчаш, оч қолиш, нотўғри овқатланиш, стресс ҳолатлари, касал юқишидан хавотирга тушиш ва қўрқиш, аввалдан кўп ва тез-тез турли касалликларга чалиниш, зарарли одатлар олиб келиши мумкин. Қондаги оқ таначалар ёки лимфоцитларнинг кескин камайиб кетиши — инсон иммун тизимининг сусайганини кўрсатади. Иммунитетни кўтариш учун соғлом турмуш тарзига риоя қилиш, зарарли одатлардан воз кечиш, ўз вақтида ва тўғри овқатланиш, маҳсулотлар орасида етарли даражада оқсил, углевод, витамин ва минералларнинг бўлиши муҳим. - Турмуш ўртоғим короновирус билан касалланиб, шифокор назорати остида уйда даволанмоқда. Коронавирусга чалинган беморлар қандай озиқ-овқат маҳсулотларини истеъмол қилиши керак? - COVID-19 билан касалланганлар учун таомлар енгил ҳазм бўладиган, витамин, микроэлемент ва оқсилга бой бўлиши керак. Таомларни кичик ҳажмда барра салат ва кўкатлар билан бирга истеъмол қилиш тавсия этилади. Булар — қайнатма шўрвалар, қийма гўштларидан тайёрланган котлетлар, тефтеллар, фрикаделкалар, балиқ гўшти, творог, сувда қайнатиб чала пиширилган тухум, дуккаклилардан тайёрланган суюқ таомлар, арпа бўтқалари. Шунингдек, кўп миқдорда суюқлик ичилиши мақсадга мувофиқ. Турли мева шарбатлари, компотлар, кўк чой, лимон, смородина, занжабил, асал ва малина чойлари шулар жумласидан. - Коронавирусни юқтириб олган инсонлар жисмоний фаоллик билан шуғулланишлари тавсия этиладими ёки кўпроқ дам олишлари керакми? - Ҳаммаси меъёрида бўлиши керак. Касаллиги аломатсиз ёки енгил шаклда кечаётган беморлар нафас тизими функционал ҳолатини ва жисмоний фаолликни унутмасликлари керак, яъни ҳар кунги эрталабги қиздирувчи 10-15 минутлик бадантарбия машқлари жуда муҳим. Нафас гимнастикаларини кун давомида 3 марта, имкон қадар 5-10 минутдан амалга ошириш керак. Чуқур нафас олиш 6 секунд давомида ва секин нафас чиқариш 4-5 мартагача. Бу машқлар вируснинг ўпка тўқимасига мойиллиги борлиги учун ҳам яхши шамоллатилган хонада бажарилиши керак. Нафас гимнастикасининг жуда хилма-хил турлари мавжуд: Бурденко усули, Йога, Тибет усуллари. Сиз ўз шифокорингиз билан бу усуллар хақида маслаҳатлашишингиз мумкин ёки уларни ҳар бир киши мустақил равишда ижтимоий тармоқлардан топиб, ҳар ким ўзи учун мосини танлаб, ўзлаштириши мумкин.',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://m.vk.com/@zaminuz-rss-1728873584-84088496',
#      'title': 'Хазонрезги мавсумидаги касалликларга қарши иммунитетни қандай ошириш мумкин? — Бизга қўшилинг: 👉 https://t.me/joinchat/AAAAADwt0NGCRoONT4f1_Q',
#      'caption': 'm.vk.com',
#      'description': 'Article',
#      'photo': {'album_id': 235125454,
#       'date': 1513935113,
#       'id': 456239031,
#       'owner_id': -127435785,
#       'has_tags': False,
#       'sizes': [{'height': 87,
#         'url': 'https://sun9-30.userapi.com/c841427/v841427299/49e55/USKUtzVeLqk.jpg',
#         'type': 'm',
#         'width': 130},
#        {'height': 87,
#         'url': 'https://sun9-60.userapi.com/c841427/v841427299/49e5a/l0Nhn9YSCJA.jpg',
#         'type': 'o',
#         'width': 130},
#        {'height': 133,
#         'url': 'https://sun9-13.userapi.com/c841427/v841427299/49e5b/58tmE5x4N54.jpg',
#         'type': 'p',
#         'width': 200},
#        {'height': 213,
#         'url': 'https://sun9-55.userapi.com/c841427/v841427299/49e5c/tKZlTDmDA1k.jpg',
#         'type': 'q',
#         'width': 320},
#        {'height': 340,
#         'url': 'https://sun9-57.userapi.com/c841427/v841427299/49e5d/el87-uGHdRM.jpg',
#         'type': 'r',
#         'width': 510},
#        {'height': 50,
#         'url': 'https://sun9-65.userapi.com/c841427/v841427299/49e54/RFh2HdaZ-c0.jpg',
#         'type': 's',
#         'width': 75},
#        {'height': 1023,
#         'url': 'https://sun9-68.userapi.com/c841427/v841427299/49e59/d3TSz4Ej5RQ.jpg',
#         'type': 'w',
#         'width': 1536},
#        {'height': 402,
#         'url': 'https://sun9-29.userapi.com/c841427/v841427299/49e56/OB5UEvb8_v0.jpg',
#         'type': 'x',
#         'width': 604},
#        {'height': 537,
#         'url': 'https://sun9-26.userapi.com/c841427/v841427299/49e57/8TRGIjyMtS4.jpg',
#         'type': 'y',
#         'width': 807},
#        {'height': 852,
#         'url': 'https://sun9-58.userapi.com/c841427/v841427299/49e58/N-Q-dK3xQ04.jpg',
#         'type': 'z',
#         'width': 1280}],
#       'text': '',
#       'user_id': 100},
#      'button': {'title': 'Read',
#       'action': {'type': 'open_url',
#        'url': 'https://m.vk.com/@zaminuz-rss-1728873584-84088496'}}}}],
#   'comments': {'count': 0},
#   'likes': {'count': 0},
#   'reposts': {'count': 0},
#   'views': {'count': 15}},
#  {'id': 82216,
#   'date': 1601634602,
#   'owner_id': -133242605,
#   'from_id': -133242605,
#   'post_type': 'post',
#   'text': '💭 #ВопросДня@nastiarizik\n\n— Москва с 5 октября уходит\n на дистанционное обучение из-за короновируса 🧬\n\nКак обстоят дела с короной у вас? \nЕсть кто уходит на дистанционку?',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'photo',
#     'photo': {'album_id': 254950692,
#      'date': 1587042129,
#      'id': 457253544,
#      'owner_id': -133242605,
#      'has_tags': False,
#      'access_key': 'c5126441fd8ec0283c',
#      'sizes': [{'height': 130,
#        'url': 'https://sun9-63.userapi.com/tOcts_7wvMcOeskEVv5WaeZcWQObnegbcd_IcA/Rq3hzoUwuYI.jpg',
#        'type': 'm',
#        'width': 105},
#       {'height': 162,
#        'url': 'https://sun9-28.userapi.com/pagpz0Oz_MDv3UoWzhAmmlBf8nluuq0OZItOUA/H-E3OoNCVLw.jpg',
#        'type': 'o',
#        'width': 130},
#       {'height': 249,
#        'url': 'https://sun9-7.userapi.com/wYS8gn8iItn0wnPP8wS5ggo1_xB4AZ3TAlbznQ/Gc6QabdwbaU.jpg',
#        'type': 'p',
#        'width': 200},
#       {'height': 398,
#        'url': 'https://sun9-44.userapi.com/wBHO0bYC__C-ugOv6-B2LYo7HXHgJabldS7fBg/G5buROFAxCo.jpg',
#        'type': 'q',
#        'width': 320},
#       {'height': 634,
#        'url': 'https://sun9-42.userapi.com/XW3ZOR1nZM5RmDDBpA8IS4LQubFRTT8eICNuNw/Q0cjbLKFnEI.jpg',
#        'type': 'r',
#        'width': 510},
#       {'height': 75,
#        'url': 'https://sun9-12.userapi.com/MjGSIAaMpzUzhyMmI3-tng5-UzxCXPD6_nGxng/9MFEoah6y1w.jpg',
#        'type': 's',
#        'width': 61},
#       {'height': 604,
#        'url': 'https://sun9-68.userapi.com/t7YAx38QSgvpUhgAjlRVn9MgQlG--rEmwvUiPw/r-vtfT7K4Ro.jpg',
#        'type': 'x',
#        'width': 486},
#       {'height': 807,
#        'url': 'https://sun9-40.userapi.com/LuIdIead10w0DdNvxAoRi23SArr2eyvv-6ZKCA/L0qpeBQ-Wek.jpg',
#        'type': 'y',
#        'width': 649},
#       {'height': 1080,
#        'url': 'https://sun9-49.userapi.com/EOsTF-xh6mphZZm9r7WYfb8GpHL44Wgxlbxhkg/IJv1XyUVnEg.jpg',
#        'type': 'z',
#        'width': 869}],
#      'text': '',
#      'user_id': 100}}],
#   'comments': {'count': 4},
#   'likes': {'count': 120},
#   'reposts': {'count': 0},
#   'views': {'count': 1117}},
#  {'id': 4126,
#   'date': 1601632810,
#   'owner_id': -171261988,
#   'from_id': -171261988,
#   'post_type': 'post',
#   'text': 'В связи с неблагоприятной ситуацией, связанной с короновирусом, профилактические мероприятия с предпринимателями, предусмотренные Планом - графиком профилактических мероприятий с хозяйствующими субъектами Управления Роспотребнадзора по Краснодарскому краю на октябрь 2020 года, будут осуществляться 13 октября 2020 года территориальным отделом Управления Роспотребнадзора по Краснодарскому краю в Лабинском, Курганинском и Мостовском районах в телефонном режиме.\nЗаявленная тема: Соблюдение хозяйствующими субъектами требований технических регламентов таможенного союза при реализации (обороте) промышленных товаров ТР ТС 017/2011 «О безопасности продукции легкой промышленности».\nОбращаться с вопросами по заявленной теме могут по телефонам «горячей линии» в территориальный отдел Управления Роспотребнадзора в Лабинском, Курганинском и Мостовском районах по телефонам 8(86169)7-44-30, 7-44-96.\n\n#Мостовской #Роспотребнадзор #семинар',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'photo',
#     'photo': {'album_id': -7,
#      'date': 1601628964,
#      'id': 457249766,
#      'owner_id': -171261988,
#      'has_tags': False,
#      'access_key': 'b721a1777a9a1f0691',
#      'post_id': 4126,
#      'sizes': [{'height': 87,
#        'url': 'https://sun9-37.userapi.com/yJ-mSQ79UJFzGJykMYTc0-eFtJHNlUf_zRgccA/uhHYW7cUowo.jpg',
#        'type': 'm',
#        'width': 130},
#       {'height': 87,
#        'url': 'https://sun9-37.userapi.com/yJ-mSQ79UJFzGJykMYTc0-eFtJHNlUf_zRgccA/uhHYW7cUowo.jpg',
#        'type': 'o',
#        'width': 130},
#       {'height': 133,
#        'url': 'https://sun9-57.userapi.com/FDtRu-NREnIl247-tU_XKZi_OTsA7e1ZH7AG5g/VeXYtsDGuw0.jpg',
#        'type': 'p',
#        'width': 200},
#       {'height': 213,
#        'url': 'https://sun9-50.userapi.com/4x37fXrQMu4eAm_NtKJ2PC2CQJD3F8goEReNSg/8vMqoWj-Wmw.jpg',
#        'type': 'q',
#        'width': 320},
#       {'height': 340,
#        'url': 'https://sun9-40.userapi.com/mo9ZwSGed-j-HZ6eez6_-fmsBE1kVWKfWmd60w/MhygH6R_NMo.jpg',
#        'type': 'r',
#        'width': 510},
#       {'height': 50,
#        'url': 'https://sun9-39.userapi.com/JsgUxMa079i30X4blxoybdH_vf1llPyeNK2aKw/1Gj5gISyapA.jpg',
#        'type': 's',
#        'width': 75},
#       {'height': 403,
#        'url': 'https://sun9-73.userapi.com/htvqnQxmAMHozwpg8TNxSkq6e5zyDJiHhKzL5Q/rWWUzkvXWPg.jpg',
#        'type': 'x',
#        'width': 604},
#       {'height': 538,
#        'url': 'https://sun9-64.userapi.com/yd_VJHtGaueLBDFsKceBo9Qfu7iP2UU9QHi_dQ/tSgARo6u7qM.jpg',
#        'type': 'y',
#        'width': 807},
#       {'height': 555,
#        'url': 'https://sun9-13.userapi.com/koA0GguzOfhwcWas7P14q20ZxpUuvbLJRl3TiA/_YNxnioDszs.jpg',
#        'type': 'z',
#        'width': 833}],
#      'text': '',
#      'user_id': 100}}],
#   'comments': {'count': 0},
#   'likes': {'count': 0},
#   'reposts': {'count': 0},
#   'views': {'count': 60}},
#  {'id': 1793645,
#   'date': 1601627408,
#   'owner_id': -23482909,
#   'from_id': -23482909,
#   'post_type': 'post',
#   'text': 'Индексы Мосбиржи и РТС упали на фоне короновируса у Трампа.\n\nРынок акций России открылся снижением основных индексов на 2%. Индекс Мосбиржи на 10:40 опустился на 1,94%, до 2 833,72 пункта. РТС снижается на 2,67%, до 1 143,11 (2,67).\n\nhttp://amp.gs/LPE9',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'photo',
#     'photo': {'album_id': -7,
#      'date': 1601627408,
#      'id': 457348533,
#      'owner_id': -23482909,
#      'has_tags': False,
#      'access_key': '28f61b00d21d189b83',
#      'post_id': 1793645,
#      'sizes': [{'height': 130,
#        'url': 'https://sun9-34.userapi.com/8VgJduTqqqSnDTKjwDEQxRV9dTXq8lIcpLn3aA/UI17ysBhRw0.jpg',
#        'type': 'm',
#        'width': 106},
#       {'height': 160,
#        'url': 'https://sun9-42.userapi.com/Bn6al_zphOABsCQwfsevQq-CMt0zx-6FGKvv0Q/CSwGPG44N20.jpg',
#        'type': 'o',
#        'width': 130},
#       {'height': 246,
#        'url': 'https://sun9-25.userapi.com/Yk9gGnS_EgkXYBF7FFt4_FthLyY7PtBBuS45lQ/rC5zwspBUfQ.jpg',
#        'type': 'p',
#        'width': 200},
#       {'height': 392,
#        'url': 'https://sun9-35.userapi.com/ZfcMhLXffQ89EUsA3E_mBMeEwLxM5P3pUorUug/NBxJvajx77c.jpg',
#        'type': 'q',
#        'width': 320},
#       {'height': 625,
#        'url': 'https://sun9-67.userapi.com/LhYSxWb4SYLKW7-QXmtM5-HyiYziM7npx0F2Dw/Q6r6xtRcqbs.jpg',
#        'type': 'r',
#        'width': 510},
#       {'height': 75,
#        'url': 'https://sun9-45.userapi.com/04zSvWtM-ZmWassLCFbXqffhiTZEAtsT-6z8-w/Lo2qDj4ZrsU.jpg',
#        'type': 's',
#        'width': 61},
#       {'height': 1200,
#        'url': 'https://sun9-24.userapi.com/5a_Xy4AA60YvuiS4ybxRcLUHGFICunx2tLh4sw/I9dQsUZU2K8.jpg',
#        'type': 'w',
#        'width': 979},
#       {'height': 604,
#        'url': 'https://sun9-48.userapi.com/awh35PNfiqnrMCvSWjrjKnHXLEa9QGkCW6pblw/OYhYkS2Q4Os.jpg',
#        'type': 'x',
#        'width': 492},
#       {'height': 807,
#        'url': 'https://sun9-47.userapi.com/bKJdt7s2sbioO0SA1d4jfn56Xj_jsMIqsCbZ3g/UU_2fsAIEpQ.jpg',
#        'type': 'y',
#        'width': 658},
#       {'height': 1080,
#        'url': 'https://sun9-9.userapi.com/3K2d59vaWH4E7WCeQZ3S3-61xiAak__IaTtBEQ/Omdo1vVlQJ4.jpg',
#        'type': 'z',
#        'width': 881}],
#      'text': 'Индексы Мосбиржи и РТС упали на фоне короновируса у Трампа.\n\nРынок акций России открылся снижением основных индексов на 2%. Индекс Мосбиржи на 10:40 опустился на 1,94%, до 2 833,72 пункта. РТС снижается на 2,67%, до 1 143,11 (2,67).\n\nhttp://amp.gs/LPE9',
#      'user_id': 100}}],
#   'comments': {'count': 12},
#   'likes': {'count': 4},
#   'reposts': {'count': 0},
#   'views': {'count': 3106}},
#  {'id': 999950,
#   'date': 1601624422,
#   'owner_id': -29725575,
#   'from_id': -29725575,
#   'post_type': 'post',
#   'text': 'До сих пор многие воспринимают COVID-19 как выдумку. Увы, это далеко не так. Жительница Тюмени летом заразилась COVID-19. Вирус она поборола, но с последствиями болезни не может справиться до сих пор. Почитайте колонку Оксаны Ширвановой о том, как она перенесла ковид и с чем столкнулась.',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://72.ru/text/health/69490305/?utm_source=vk&utm_medium=social&utm_campaign=72',
#      'title': 'Туман в голове, боли до тошноты и светобоязнь. Откровения тюменки, которая переболела короновирусом',
#      'caption': '72.ru',
#      'description': 'Девушка лежала в больнице с пневмонией. После лечения у нее появилась куча осложнений по здоровью',
#      'photo': {'album_id': -26,
#       'date': 1601624422,
#       'id': 457309483,
#       'owner_id': 2000042321,
#       'has_tags': False,
#       'sizes': [{'height': 480,
#         'url': 'https://sun9-70.userapi.com/S_xleNrtSlx-Hy4sVFzUzUbynCCgeKlKmAAQEQ/4K37bjjwzlw.jpg',
#         'type': 'k',
#         'width': 1074},
#        {'height': 240,
#         'url': 'https://sun9-48.userapi.com/4SfoXd6DZ30JYfg913VLS1VUAsptgcW9NSZIrQ/n9V8oh1z67c.jpg',
#         'type': 'l',
#         'width': 537},
#        {'height': 70,
#         'url': 'https://sun9-73.userapi.com/yo8B8sDc6C4xlaNJsX5QMNQ5U8dWayI2rolBrA/8GHVqxBCfWU.jpg',
#         'type': 'm',
#         'width': 130},
#        {'height': 140,
#         'url': 'https://sun9-27.userapi.com/WbjUcD9LHpx67-ppady0_NuZZGdH2fTRIj9SGA/XQ-KeYMTVn0.jpg',
#         'type': 'p',
#         'width': 260},
#        {'height': 39,
#         'url': 'https://sun9-19.userapi.com/c83wQ1Sy0ljYgEnOkOlEicgLWBO5TTKZ7PM-xQ/BnQ1qmJ70Xk.jpg',
#         'type': 's',
#         'width': 75},
#        {'height': 80,
#         'url': 'https://sun9-72.userapi.com/AF9Bp4bRcXHyra-vywokLLMfXALbD0C7h3xDBQ/A6aGOz7xtvM.jpg',
#         'type': 'x',
#         'width': 150}],
#       'text': '',
#       'user_id': 100}}}],
#   'comments': {'count': 16},
#   'likes': {'count': 17},
#   'reposts': {'count': 3},
#   'views': {'count': 5848}},
#  {'id': 550209,
#   'date': 1601623703,
#   'owner_id': -55611432,
#   'from_id': -55611432,
#   'post_type': 'post',
#   'text': 'Мутации короновируса нового типа делают его способным трансформироваться в 10 различных форм для упрощения проникновения в организм, так считают британские ученые из Института Фрэнсиса Крика, передает Fox News',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://nsn.fm/zdorovie/uchenye-vyyasnili-chto-covid-19-stal-esche-opasnee',
#      'title': 'Ученые выяснили, что COVID-19 стал еще опаснее',
#      'caption': 'nsn.fm',
#      'description': 'Мутации короновируса нового типа делают его способным трансформироваться в 10 различных форм для упрощения проникновения в организм, так считают британские ученые из Института Фрэнсиса Крика, передает Fox News',
#      'photo': {'album_id': -25,
#       'date': 1601623713,
#       'id': 457311968,
#       'owner_id': 2000042105,
#       'has_tags': False,
#       'sizes': [{'height': 480,
#         'url': 'https://sun9-40.userapi.com/c857332/v857332292/1864c2/J3dquTEmIKQ.jpg',
#         'type': 'k',
#         'width': 1074},
#        {'height': 240,
#         'url': 'https://sun9-13.userapi.com/c857332/v857332292/1864c1/RK4fO4ifR1Q.jpg',
#         'type': 'l',
#         'width': 537},
#        {'height': 70,
#         'url': 'https://sun9-65.userapi.com/c857332/v857332292/1864be/kk_7juOIGS4.jpg',
#         'type': 'm',
#         'width': 130},
#        {'height': 140,
#         'url': 'https://sun9-51.userapi.com/c857332/v857332292/1864c0/mAITPeugdYg.jpg',
#         'type': 'p',
#         'width': 260},
#        {'height': 39,
#         'url': 'https://sun9-75.userapi.com/c857332/v857332292/1864bd/TVuaBZy_sOM.jpg',
#         'type': 's',
#         'width': 75},
#        {'height': 80,
#         'url': 'https://sun9-18.userapi.com/c857332/v857332292/1864bf/JfCfz26kfrU.jpg',
#         'type': 'x',
#         'width': 150}],
#       'text': '',
#       'user_id': 100}}}],
#   'comments': {'count': 1},
#   'likes': {'count': 3},
#   'reposts': {'count': 1},
#   'views': {'count': 588}},
#  {'id': 941,
#   'date': 1601617964,
#   'owner_id': -186140010,
#   'from_id': -186140010,
#   'post_type': 'post',
#   'text': 'Заместитель главного врача по лечебным вопросам Кузбасской клинической инфекционной больницы Бондаренко Татьяна. "Короновирус. Детская заболеваемость"',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'video',
#     'video': {'access_key': '51ccccaa0dbb4c11dd',
#      'can_comment': 0,
#      'can_like': 1,
#      'can_repost': 1,
#      'can_subscribe': 1,
#      'can_add_to_faves': 1,
#      'can_add': 1,
#      'comments': 0,
#      'date': 1601617945,
#      'description': '',
#      'duration': 34,
#      'image': [{'height': 96,
#        'url': 'https://sun9-55.userapi.com/vj3uok9yYi_lw7e-_9NvRx0DBrad8WVm5CxNsA/w5JUrKWfBTs.jpg',
#        'width': 130,
#        'with_padding': 1},
#       {'height': 120,
#        'url': 'https://sun9-74.userapi.com/6fyD6lTPs9J-yjZuS9QVEduo1WpQsgdHVQgCXQ/qwy08VQXWaY.jpg',
#        'width': 160,
#        'with_padding': 1},
#       {'height': 240,
#        'url': 'https://sun9-59.userapi.com/Iux93H2xurQO6a3fIQoHcnqp5db2ev-B0tyBgg/VtsUj7X3ih0.jpg',
#        'width': 320,
#        'with_padding': 1},
#       {'height': 450,
#        'url': 'https://sun9-38.userapi.com/gE0VsYHO5qKHSd_PLsHj3Wur9bhsCJDOxhUD1w/x7hFIBbZ0qo.jpg',
#        'width': 800,
#        'with_padding': 1},
#       {'height': 720,
#        'url': 'https://sun9-74.userapi.com/bZ_ejSJfo-gBj_6lf_SGkM5sCJ7sRSBZURYdQQ/gaFXXT_tHWE.jpg',
#        'width': 576},
#       {'height': 400,
#        'url': 'https://sun9-76.userapi.com/SoLvjYEmElTElqBZrq4ZaB6-twxWLb7hPmOyqg/EQxPgyezO08.jpg',
#        'width': 320},
#       {'height': 900,
#        'url': 'https://sun9-3.userapi.com/hlsCo8UHdtS2wcXx_WzxcrNUSE6AjvM7m613kQ/Ttjqf2yJCK0.jpg',
#        'width': 720},
#       {'height': 1280,
#        'url': 'https://sun9-43.userapi.com/LK3E2cc_7vzGHtm_u27FkaOHW6sUVplA5HF16g/6Xc_F1aehiE.jpg',
#        'width': 1024},
#       {'height': 4096,
#        'url': 'https://sun9-19.userapi.com/0ofdOl4Al0XlwIXfOUS88hklSp4BGOHWwHx2nA/flZ5S3yVIv4.jpg',
#        'width': 3277}],
#      'first_frame': [{'height': 400,
#        'url': 'https://sun9-61.userapi.com/VptVSjlIaa3tK9QeeDSQdn0LR2Q7OPgQZLIhPQ/vxPDpuwZSzA.jpg',
#        'width': 320},
#       {'height': 200,
#        'url': 'https://sun9-66.userapi.com/fBTRpDmMM_dg1OYYWfTuIx3CBWnWBlkTho6hTw/pm3TTaMt4l0.jpg',
#        'width': 160},
#       {'height': 5120,
#        'url': 'https://sun9-52.userapi.com/Ut4TPxTgM0ifwJ0sgqY2Sww19hh4KbFFF8xqVg/t0Xh6zko_B0.jpg',
#        'width': 4096},
#       {'height': 163,
#        'url': 'https://sun9-64.userapi.com/9aM39ZgChSlCFgQ1h3DRNy-X69ggjG6dLeEeSQ/OdMuN1sPSic.jpg',
#        'width': 130},
#       {'height': 400,
#        'url': 'https://sun9-61.userapi.com/VptVSjlIaa3tK9QeeDSQdn0LR2Q7OPgQZLIhPQ/vxPDpuwZSzA.jpg',
#        'width': 320},
#       {'height': 900,
#        'url': 'https://sun9-18.userapi.com/0RYbuBWvXKlssUuhwypctKBiMP0cVp1w0dzR2w/W_rt_5pfzfk.jpg',
#        'width': 720},
#       {'height': 1280,
#        'url': 'https://sun9-49.userapi.com/PsFcWXAqFhNNKvTfPwGowQO-ielzyRVsHwFdag/O6noW70jvoE.jpg',
#        'width': 1024},
#       {'height': 1600,
#        'url': 'https://sun9-37.userapi.com/ICDCgMf3RxD9mDVfJTjWkwyCbIIBstoOtvieCw/2pHaT_4VY_0.jpg',
#        'width': 1280},
#       {'height': 1000,
#        'url': 'https://sun9-64.userapi.com/3298Hsr8RuuhvIZ1EUUWpJJSFYe4sr_i3xBErw/HDr3Hs7k0uE.jpg',
#        'width': 800}],
#      'width': 864,
#      'height': 1080,
#      'id': 456239220,
#      'owner_id': -186140010,
#      'title': 'Untitled',
#      'track_code': 'video_7dec200au5Dtfj8guXL7JEJ-_h9HBMxkllbJIkIh7Hc25RGE7iyIvPZ-Mya4d_tLSnqQK3Iy_levZPsSRVSCHA',
#      'type': 'video',
#      'views': 24}}],
#   'comments': {'count': 0},
#   'likes': {'count': 2},
#   'reposts': {'count': 0},
#   'views': {'count': 37}},
#  {'id': 31759,
#   'date': 1601555536,
#   'owner_id': -80790060,
#   'from_id': -80790060,
#   'post_type': 'post',
#   'text': 'Соғлиқни сақлаш вазирлиги Жамоатчилик билан алоқалар бўлими тиббиёт фанлари доктори, профессор Шавкат Омонов билан суҳбат уюштирди. – Куз-қиш фасли томоқ, бурун ва қулоқда шикоятлар кўпаядиган мавсум ҳисобланади. Коронавирус хавфи боис кўпчилик томоқ оғриғини ҳам коронавирус аломати, деб шубҳа қилишмоқда. Одатдаги томоқ оғриғи билан коронавирус ўртасида қандай фарқли белгилар бор? – Албатта, куз ва қиш фасллари ЛОР хасталикларининг ўткир ривожланиши ёки сурункали шаклларининг хуруж қилиш даври ҳисобланади. Маълумки, короновирус инфекциясининг асосий кириш дарвозаси сифатида юқори нафас йўллари қаралмоқда. Шу боис буруннинг ачишиши, томоқдаги нохушлик ҳисси, ҳид билишнинг пасайиши кузатилганда одамлар коронавирусга шубҳа қилишмоқда. Маълум бир жиҳатдан бунда асос бор. Чунки, эпидемиологик вазият шуни тақoзо қилмоқда. Беморларда учрайдиган ўткир респиратор шамоллаш, фарингит, ангина ва ринитлар ҳам шунга ўхшаш намоён бўлади. Бироқ қиёсий ажратувчи белгиларни синчиклаб фарқлаш мумкин. Ўткир вирусли инфекциялар, ангиналар ва фарингитлар, одатда, юқори тана ҳарорати билан бошланади. Ангина ва фарингитларда томоқда оғриқ, кўрилганда эса кучли қизариш аломатлари бўлади, коронавирусда эса бироз нохушлик ва енгил қирилиш бўлади, яллиғланишнинг аломатлари кам намоён бўлади. Вирусли ўткир тумовларда бурундан нафас олиш қийинлашади, ажралма келади ва бироз ҳид билиш пасаяди (гипосмия), короновирусда эса бурун йўлларида ажралма бўлмасдан туриб ҳид билиш йўқолади (аносмия). Бироқ ЛОР аъзолари касалликлари билан коронавируснинг биргаликда келиш эҳтимоли мавжудлигини унутмаслик керак. – Айтингчи, гайморит аслида қандай сабаблар оқибатида юзага келади. Дастлабки белгилари, даволаш усуллари ва олдини олиш борасида ўз тавсияларингизни берсангиз. – Гайморит – бурун ёндош бўшлиқлари касалликлари орасида энг кўп учрайди. Гайморитнинг ривожланишига бир нечта омиллар сабаб бўлади. Инсоннинг маҳаллий ёки умумий совқотиши, иммунитетнинг пасайиши, буруннинг ички ўзгаришлари, гаймор бўшлиғининг тишлар билан боғлиқлиги ва унинг табиий тешигининг яхши фаолият кўрсатмаслиги каби ҳолатлар шулар жумласидан. Гайморит ўткир ёки сурункали, бир ёки икки томонлама бўлиши мумкин. Гайморитнинг ўткир ва сурункали турларини, айниқса, болаларда фарқлаш қийин ҳисобланади. Чунки бола, кўпинча, ўз хасталигини яширади ва шикоят қилмайди. Нурли текширишларда гаймор бўшлиғида киста, полип ёки одонтоген ҳосилалар кўринса, бу ҳолат сурункали ҳисобланади. Одатда, яллиғланган бўшлиқ соҳасида маҳаллий оғриқ, бурундан нафас олиш қийинлиги, бош оғриши, ҳарорат кўтарилиши кузатилади. Асоратланмаган ўткир ва сурункали гайморитлар дори воситалари ва муолажалар (антибиотиклар, яллиғланишга карши дорилар, бурунни ювиш, бўшлиқни пункция қилиш, физиотерапевтик муолажалар) билан даволанади. Гайморитларнинг профилактикаси иммун ҳолатни кўтариш, организмни чиниқтириш, тишлар кариесини ўз вақтида даволаш, бурун ичи патологиясини ўз вақтида бартараф этишни ўз ичига олади. – Гайморит касаллигининг қайси босқичида жарроҳлик билан даволанади? – Гайморитларнинг асоратланган, полипли, кистали, холестеатомали, одонтоген турларида жарроҳлик ўтқазилади. Жарроҳлик амалиёти гаймор ёки юқори жағ бўшлиғини тозалаш ва унинг табиий тешиги фаолиятини яхшилашга қаратилади. Операциядан кейинги даврда бемор ўзини эҳтиёт қилмаса, шифокорнинг тавсияларини тўлиқ бажармаса, мазкур касаллик қайта ривожланиши мумкин.',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://m.vk.com/@zaminuz-rss-1728873584-1386966844',
#      'title': 'Нафас йўллари касалликлари билан коронавирус аломатларини қандай фарқласа бўлади? — Бизга қўшилинг: 👉 https://t.me/joinchat/AAAAADwt0NGCRoONT4f1_Q',
#      'caption': 'm.vk.com',
#      'description': 'Article',
#      'photo': {'album_id': 235125454,
#       'date': 1513935113,
#       'id': 456239031,
#       'owner_id': -127435785,
#       'has_tags': False,
#       'sizes': [{'height': 87,
#         'url': 'https://sun9-30.userapi.com/c841427/v841427299/49e55/USKUtzVeLqk.jpg',
#         'type': 'm',
#         'width': 130},
#        {'height': 87,
#         'url': 'https://sun9-60.userapi.com/c841427/v841427299/49e5a/l0Nhn9YSCJA.jpg',
#         'type': 'o',
#         'width': 130},
#        {'height': 133,
#         'url': 'https://sun9-13.userapi.com/c841427/v841427299/49e5b/58tmE5x4N54.jpg',
#         'type': 'p',
#         'width': 200},
#        {'height': 213,
#         'url': 'https://sun9-55.userapi.com/c841427/v841427299/49e5c/tKZlTDmDA1k.jpg',
#         'type': 'q',
#         'width': 320},
#        {'height': 340,
#         'url': 'https://sun9-57.userapi.com/c841427/v841427299/49e5d/el87-uGHdRM.jpg',
#         'type': 'r',
#         'width': 510},
#        {'height': 50,
#         'url': 'https://sun9-65.userapi.com/c841427/v841427299/49e54/RFh2HdaZ-c0.jpg',
#         'type': 's',
#         'width': 75},
#        {'height': 1023,
#         'url': 'https://sun9-68.userapi.com/c841427/v841427299/49e59/d3TSz4Ej5RQ.jpg',
#         'type': 'w',
#         'width': 1536},
#        {'height': 402,
#         'url': 'https://sun9-29.userapi.com/c841427/v841427299/49e56/OB5UEvb8_v0.jpg',
#         'type': 'x',
#         'width': 604},
#        {'height': 537,
#         'url': 'https://sun9-26.userapi.com/c841427/v841427299/49e57/8TRGIjyMtS4.jpg',
#         'type': 'y',
#         'width': 807},
#        {'height': 852,
#         'url': 'https://sun9-58.userapi.com/c841427/v841427299/49e58/N-Q-dK3xQ04.jpg',
#         'type': 'z',
#         'width': 1280}],
#       'text': '',
#       'user_id': 100},
#      'button': {'title': 'Read',
#       'action': {'type': 'open_url',
#        'url': 'https://m.vk.com/@zaminuz-rss-1728873584-1386966844'}}}}],
#   'comments': {'count': 0},
#   'likes': {'count': 0},
#   'reposts': {'count': 0},
#   'views': {'count': 33}},
#  {'id': 1139,
#   'date': 1601555080,
#   'owner_id': -89795477,
#   'from_id': -89795477,
#   'post_type': 'post',
#   'text': 'Уважаемые Шимчане! \n \nНа сегодняшний день в Новгородской области увеличилось количество заболевших короновирусом, и чтобы не подвергать риску заболевания себя и других людей, просьба соблюдать все меры по борьбе с коронавирусом, в том числе масочный режим при нахождении в транспорте общего пользования, на вокзалах, автостанциях и остановках.\n \nБерегите свое здоровье и здоровье своих близких! При первых признаках заболевания обращайтесь в медицинские учреждения!',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'photo',
#     'photo': {'album_id': -7,
#      'date': 1601555080,
#      'id': 457240462,
#      'owner_id': -89795477,
#      'has_tags': False,
#      'access_key': 'c705e3c5c928b98be9',
#      'post_id': 1139,
#      'sizes': [{'height': 73,
#        'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=130x73&quality=90&sign=693377526f1a9c26fbd8a165201add93&c_uniq_tag=HSWwLGbKD8cTSSsvEhTg_E0GFDyUSX3rzjCknLuVpC4',
#        'type': 'm',
#        'width': 130},
#       {'height': 87,
#        'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=130x87&quality=90&crop=64,0,672,450&sign=5d73d4ac75645dad49a86a31ca02898c&c_uniq_tag=Z7GOCKBRIAYCTIcKH636xFK_ca1DUobAagdEC2qvsBo',
#        'type': 'o',
#        'width': 130},
#       {'height': 133,
#        'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=200x133&quality=90&crop=61,0,677,450&sign=56dfd3bd7fafa788a420542a69a51dff&c_uniq_tag=wZUEPaZKSmn8zbLid2M3acYRMtWF0xXC55sJGBvZBWY',
#        'type': 'p',
#        'width': 200},
#       {'height': 213,
#        'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=320x213&quality=90&crop=62,0,676,450&sign=f5833f5680c2e9a61062a4de55ee0803&c_uniq_tag=WG7p3F5xLzOKmGkrhbf9DCEWmYEfgxtgvrfOfidst6I',
#        'type': 'q',
#        'width': 320},
#       {'height': 340,
#        'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=510x340&quality=90&crop=62,0,675,450&sign=e9fe28a940262678556d131953548a63&c_uniq_tag=6V8ilHHZFhZWIcwLEp2WlV2dpMtg7fG6ftgm6sZZVpw',
#        'type': 'r',
#        'width': 510},
#       {'height': 42,
#        'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=75x42&quality=90&sign=6f8059b539f0e935067c5e8ab87aec93&c_uniq_tag=RObXwa12_eKalXMM3Bzy6aOtaMU9_KPBt7jXmryNjtY',
#        'type': 's',
#        'width': 75},
#       {'height': 340,
#        'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=604x340&quality=90&sign=a642b4d2479625c97bdbb96444f48c40&c_uniq_tag=8mMdnzYo9CbTpScVD_16332jFlcg1RfG5DRMKVYFFiw',
#        'type': 'x',
#        'width': 604},
#       {'height': 450,
#        'url': 'https://sun9-76.userapi.com/impg/bq0S0pgNL7BXwaJhW6i-QFFcMDxo5xhxWSlpog/Qr7YpzLVYv4.jpg?size=800x450&quality=90&proxy=1&sign=395fd343ba3d12623d31b3f93b1590d4&c_uniq_tag=Rxx29z0Y9pwRH_ll3PthkvcZP_7dhePNOE79FY2qOMA',
#        'type': 'y',
#        'width': 800}],
#      'text': '',
#      'user_id': 100}}],
#   'comments': {'count': 0},
#   'likes': {'count': 5},
#   'reposts': {'count': 0},
#   'views': {'count': 237}},
#  {'id': 634994,
#   'date': 1601548980,
#   'owner_id': -51966513,
#   'from_id': -51966513,
#   'post_type': 'post',
#   'text': 'В Раде предложили закупить вакцину от COVID-19 в России \n \nКогда речь идет о защите и выживании украинцев, власти следует сосредоточиться не на строительстве дорог, а на покупке вакцины от COVID-19, которая уже разработана и применяется в России. \n\nТакое заявление на брифинге сегодня, 1 октября, сделал депутат Верховной рады, глава политсовета партии «Оппозиционная платформа — За жизнь» (вторая по величине фракция парламента) Виктор Медведчук, передает корреспондент ИА REGNUM. \n \nПолитик проинформировал, что бюджетный запрос министерства здравоохранения Украины предусматривал выделение 15,08 млрд грн на закупку вакцины от COVID-19 в 2021 году. Министерство, продолжил Медведчук, якобы ведет переговоры с восемью компаниями-производителями о закупке вакцины от коронавируса после завершения испытаний. \n \n«Так сообщил министр здравоохранения Максим Степанов. Он отметил, что, по данным Всемирной организации здравоохранения, на завершающей стадии клинических испытаний находятся вакцины восьми компаний. «Со всеми ними мы ведем переговоры относительно заключения контракта», — прокомментировал Степанов. Правда, в госбюджет на эти цели заложили только 2,6 млрд грн, в 5,8 раза меньше ранее предусмотренного», — сообщил парламентарий. \n \nУ западных компаний, отметил депутат оппозиции, названия которых хорошо известны украинцам в связи с рекламой гигиенических средств и косметики, вакцина от коронавируса пока только в стадии разработки. \n \n«Единственная страна, справившаяся с этой задачей на настоящий момент, — это Российская Федерация, которая уже выпустила и зарегистрировала свою вакцину «Спутник V», разработанную Национальным исследовательским центром эпидемиологии и микробиологии имени Н. Ф. Гамалеи, и начала вакцинацию населения совместно с Российским фондом прямых инвестиций. Россия уже получила заявки из 50 стран СНГ, Европы, Азии, Ближнего Востока и Латинской Америки на более чем 1,2 млрд доз своей вакцины на текущий и следующий год», — отметил лидер ОПЗЖ. \n \nИменно с производителями этой вакцины, убежден Медведчук, надо вести переговоры, если украинская власть собирается спасать граждан страны, «а не кормить грантоедов, осуществляющих закупки лекарственных препаратов за бюджетные средства». Депутат подчеркнул, что с учетом текущей ситуации по коронавирусу делать это надо незамедлительно. \n \n«Однако вместо реальных действий по вакцинированию населения власть строит воздушные замки, ведет переговоры о закупках несуществующей вакцины западных компаний и тратит деньги из коронавирусного фонда на строительство дорог. Во власти действительно считают, что строительство дорог в период разгара эпидемии и при растущем количестве заболевших — это настолько насущный вопрос? Учитывается ли то, что дорожное строительство — одна из наиболее коррумпированных отраслей экономики и что выделяемые на нее средства, по экспертным оценкам, на 30% и больше банально разворовываются? И что нормальных дорог нет даже в Киеве и областных центрах?» — возмущен политик. \n \nМожет, все-таки сосредоточиться на покупке вакцины от COVID-19, которая уже разработана и применяется в России, задался риторическим вопросом депутат. \n \n«Когда речь идет о защите и выживании украинских граждан, уже не до политических игр. Иначе украинская власть доиграется до того, что по новым дорогам, если они, конечно, будут построены, некому будет ездить. Хотя, может быть, в этом и заключается ее главная миссия?» — резюмировал Медведчук. \n \nИА REGNUM напоминает, что сегодня на Украине зафиксирован очередной антирекорд заболеваемости коронавирусом — за последние сутки болезнь подтвердили у 4069 человек. \n \n30 сентября главный санитарный врач страны Виктор Ляшко заявил также об антирекорде по госпитализации людей с подтвержденным коронавирусом. \n \nДо этого президент Владимир Зеленский признал, что в настоящий момент Украина в принципе не может самостоятельно изготовить вакцину от короновируса.',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'photo',
#     'photo': {'album_id': -7,
#      'date': 1601543309,
#      'id': 457285966,
#      'owner_id': -51966513,
#      'has_tags': False,
#      'access_key': 'f6fc18a6fc3d6439a9',
#      'post_id': 634994,
#      'sizes': [{'height': 87,
#        'url': 'https://sun9-31.userapi.com/DmnJW5pDmQ6Aug0mujeh9HhwNPgmHeddVWrguw/czujFg_wPGY.jpg',
#        'type': 'm',
#        'width': 130},
#       {'height': 87,
#        'url': 'https://sun9-31.userapi.com/DmnJW5pDmQ6Aug0mujeh9HhwNPgmHeddVWrguw/czujFg_wPGY.jpg',
#        'type': 'o',
#        'width': 130},
#       {'height': 133,
#        'url': 'https://sun9-56.userapi.com/2PjilzflVf28gVZ8Mhvdralb2aM7nDHisy7ZKA/eZBAV1HFZfc.jpg',
#        'type': 'p',
#        'width': 200},
#       {'height': 213,
#        'url': 'https://sun9-71.userapi.com/GEwgpwgXdAnyyod7xrRa-mZ_VrPGxbbO9rZD5A/31OtpMjSqJo.jpg',
#        'type': 'q',
#        'width': 320},
#       {'height': 340,
#        'url': 'https://sun9-39.userapi.com/jqiZMOrKNffWgahNWnIJrtHE4I5GVaJK_MZrjg/FIf0tYlAIAI.jpg',
#        'type': 'r',
#        'width': 510},
#       {'height': 50,
#        'url': 'https://sun9-71.userapi.com/ucbyILeuG9NJrDZPS-_av_9UFyfkMCu36w7hCQ/HjYdgapl1ho.jpg',
#        'type': 's',
#        'width': 75},
#       {'height': 403,
#        'url': 'https://sun9-27.userapi.com/-rHzUUHv-L09q2nebqXs2nQ3hTCWOG2iNtXQqw/vur_AeSZT1w.jpg',
#        'type': 'x',
#        'width': 604},
#       {'height': 538,
#        'url': 'https://sun9-49.userapi.com/wXhehphw-yL4tvmatL4OZRpl7nuXgn8B1_mxfg/ain2arPFj28.jpg',
#        'type': 'y',
#        'width': 807},
#       {'height': 683,
#        'url': 'https://sun9-33.userapi.com/OqMBt7UgIqTCxizbkG4imjd0shzaZsYv9AAL7w/P1_lYRJEVpI.jpg',
#        'type': 'z',
#        'width': 1024}],
#      'text': '',
#      'user_id': 100}}],
#   'comments': {'count': 5},
#   'likes': {'count': 11},
#   'reposts': {'count': 1},
#   'views': {'count': 1074}},
#  {'id': 3736,
#   'date': 1601538986,
#   'owner_id': -161491660,
#   'from_id': -161491660,
#   'post_type': 'post',
#   'text': 'Дорогие ветераны! \n Сердечно поздравляю вас с Днём старшего поколения. \n Москва всегда широко отмечала этот замечательный праздник, наполненный заботой о бабушках и дедушках, матерях и отцах. Но в этом году пандемия короновируса нарушила многие планы, вынуждая свернуть и мероприятия по случаю самых разных праздничных дат. \nПожилые граждане наиболее уязвимы для нового вируса. Поэтому в эти осенние дни я ещё раз прошу вас поберечь себя и оставаться дома. И помните, что мы вас любим и очень хотим радоваться общению с вами ещё многие-многие годы. \n Пандемия пройдёт, жизнь вернется в обычное русло. И День старшего поколения вновь станет одной из самых главных дат в праздничном календаре столицы. \n Желаю вам, дорогие ветераны, доброго здоровья, бодрости духа, сердечного тепла и благополучия.',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'photo',
#     'photo': {'album_id': -7,
#      'date': 1601538986,
#      'id': 457253122,
#      'owner_id': -161491660,
#      'has_tags': False,
#      'access_key': 'ebaefe3e757b6404fd',
#      'post_id': 3736,
#      'sizes': [{'height': 87,
#        'url': 'https://sun9-66.userapi.com/mT2Ni5t9HZUOOBmnxUZwIxx68gOIV2aEtrneWg/ruVOszteTa4.jpg',
#        'type': 'm',
#        'width': 130},
#       {'height': 87,
#        'url': 'https://sun9-66.userapi.com/mT2Ni5t9HZUOOBmnxUZwIxx68gOIV2aEtrneWg/ruVOszteTa4.jpg',
#        'type': 'o',
#        'width': 130},
#       {'height': 134,
#        'url': 'https://sun9-56.userapi.com/udiMpZii-n-rW8dg1iZlMJ_g_6Oxm6MUl-Fr-A/d7fjGhtFJvA.jpg',
#        'type': 'p',
#        'width': 200},
#       {'height': 215,
#        'url': 'https://sun9-2.userapi.com/BKjOkCyFWa0-wBrEdjtgTjxtitQcjEtK-Q-4oQ/7jfCa9HFtNE.jpg',
#        'type': 'q',
#        'width': 320},
#       {'height': 342,
#        'url': 'https://sun9-63.userapi.com/Vrn076w4SVXTwzFbwLEjzlSNpb6gqyMuya63eQ/dUNfAJq-574.jpg',
#        'type': 'r',
#        'width': 510},
#       {'height': 50,
#        'url': 'https://sun9-60.userapi.com/GGwFSaQ8LfiM5NVPnycEhnDECqGUGDlRMESndA/iVfC7UQjtLI.jpg',
#        'type': 's',
#        'width': 75},
#       {'height': 1717,
#        'url': 'https://sun9-39.userapi.com/2MgmYMbIQz_8xezuAQjUiYHnjCXcqpLvpkwgXQ/W_lh3hfskOE.jpg',
#        'type': 'w',
#        'width': 2560},
#       {'height': 405,
#        'url': 'https://sun9-22.userapi.com/eK-ofW7W5MIum0dYE_d1hqPql7gQpShrrbwhLg/6irCizomm5E.jpg',
#        'type': 'x',
#        'width': 604},
#       {'height': 541,
#        'url': 'https://sun9-45.userapi.com/Xn8jUQl0o-b5Chh95lmByyc-I165FAafNMYMWw/4iEVEf9LvtQ.jpg',
#        'type': 'y',
#        'width': 807},
#       {'height': 858,
#        'url': 'https://sun9-29.userapi.com/UTAzbdumXKVWehee0GzLnvNAfT0y9vNEXFGT1g/JxW40ONmENE.jpg',
#        'type': 'z',
#        'width': 1280}],
#      'text': '',
#      'user_id': 100}}],
#   'comments': {'count': 0},
#   'likes': {'count': 72},
#   'reposts': {'count': 20},
#   'views': {'count': 286}},
#  {'id': 142331,
#   'date': 1601525220,
#   'owner_id': -62298989,
#   'from_id': -62298989,
#   'post_id': 142322,
#   'post_type': 'reply',
#   'text': '[id18189966|Евгений], здравствуйте! На этой неделе погода солнечная и сухая, но в начале сентября была холодная. Понижение температуры наружного воздуха влечет аналогичное понижение внутри помещений, что отрицательно сказывается на здоровье в период сезонного роста заболеваемости населения ОРВ, тем более в условиях пандемии короновируса. Отопительный сезон в Уфе в этом году стартовал немного раньше и в два этапа. В первую очередь, 15 сентября, тепло подали в школах, садиках и больницах, с 17 сентября отопление начали подключать в жилых домах. 21 сентября отопление было подано на всех объектах социальной сферы и жилого фонда. К сожалению, отключение отопления на несколько дней после начала отопительного сезона при кратковременном потеплении, является крайне затруднительно в связи с тем, что создает сложности при повторном пуске тепла. Снижение температуры теплоносителя, подаваемого от котельных на температуру ниже 75 градусов повлечет за собой снижение нормативного уровня горячей воды. Наряду с этим, по поручению и. о. первого заместителя главы администрации городского округа город Уфа Радмила Муслимова от 29 сентября 2020 года, Управление по обеспечению жизнедеятельности города администрации Уфы ведет работу с управляющими компаниями по обеспечению понижения при необходимости температуры теплоносителя в домах в зависимости от внешней температуры воздуха. С целью создания комфортной температуры в жилых помещениях жителям необходимо обратиться в свою управляющую организацию. Обращаем внимание, что понижение температуры теплоносителя осуществляется в каждом доме индивидуально с учетом его технических особенностей. С уважением, Марсель Байдавлетов, начальник информационно-аналитического управления - пресс-службы администрации Уфы',
#   'marked_as_ads': 0,
#   'comments': {'count': 0},
#   'likes': {'count': 0},
#   'reposts': {'count': 0}},
#  {'id': 34693,
#   'date': 1601472970,
#   'owner_id': -59796939,
#   'from_id': -59796939,
#   'post_type': 'post',
#   'text': 'В Петербурге готовятся к очередному эпидемиологическому сезону. Готовятся с тревогой и опасениями – короновирус внес свои коррективы во всю нашу жизнь. И сезонный всплеск заболеваний ОРВИ и гриппом уже воспринимается не как рядовое событие, а как новая опасность. И к ней стоит подготовиться заранее, чтобы избежать последствий. 18 процентов петербуржцев, которые уже успели сделать прививки, могут быть спокойны. Для всех остальных расскажем, зачем нужны вакцины.\n\n#Репортажи@avtoradiospb #грипп',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://m.vk.com/@avtoradiospb-zaschita-ot-virusa',
#      'title': 'Защита от вируса',
#      'caption': 'm.vk.com',
#      'description': 'Article',
#      'photo': {'album_id': -66,
#       'date': 1601472958,
#       'id': 457259329,
#       'owner_id': -59796939,
#       'has_tags': False,
#       'sizes': [{'height': 97,
#         'url': 'https://sun9-27.userapi.com/trTS2Ygy4c64bPNydPaHiHDzRw8K9a_zSAM0hA/L7IIdMRydLs.jpg',
#         'type': 'm',
#         'width': 130},
#        {'height': 98,
#         'url': 'https://sun9-35.userapi.com/XQwd_mc1NPqrNB6F5L1vV8uTIA9CH0-WDRW-9Q/cOGKNmbfxTU.jpg',
#         'type': 'o',
#         'width': 130},
#        {'height': 150,
#         'url': 'https://sun9-13.userapi.com/060wPIvMOrf3yIJcJ6e3yPlsDUjJvtjzEZz7aA/SCsBhU88ez4.jpg',
#         'type': 'p',
#         'width': 200},
#        {'height': 240,
#         'url': 'https://sun9-72.userapi.com/PxR-94oYf1DgVpSL3XFI3MvsxVe-yFHgDHe3Ag/kV4tyEoHJyY.jpg',
#         'type': 'q',
#         'width': 320},
#        {'height': 383,
#         'url': 'https://sun9-70.userapi.com/PE-xviXZ8Yx8u-Kh25hh9Yhtl2wMVk6eHvi5fw/5fLOlXWVs9Y.jpg',
#         'type': 'r',
#         'width': 510},
#        {'height': 56,
#         'url': 'https://sun9-34.userapi.com/msek0JlbPDn_ukc1fvf997DfUopLM1nhFbXDjA/y6sYsLq5EVs.jpg',
#         'type': 's',
#         'width': 75},
#        {'height': 453,
#         'url': 'https://sun9-62.userapi.com/-o1Re5fUgoxWVYWJavGt5o-khmTkeOyR81yj3g/NytmPl4dR38.jpg',
#         'type': 'x',
#         'width': 604},
#        {'height': 605,
#         'url': 'https://sun9-6.userapi.com/8dHa8I4Vjf4_K0YgM-p4jF3D_AbWxmynAfq9oA/mGgpRoA1M2U.jpg',
#         'type': 'y',
#         'width': 807},
#        {'height': 750,
#         'url': 'https://sun9-19.userapi.com/0ivDGkZ_Ty52CquqZuzTRpfkmYIoIontx8Xnhg/XXbHH4HINA0.jpg',
#         'type': 'z',
#         'width': 1000}],
#       'text': '',
#       'user_id': 100},
#      'button': {'title': 'Read',
#       'action': {'type': 'open_url',
#        'url': 'https://m.vk.com/@avtoradiospb-zaschita-ot-virusa'}}}}],
#   'comments': {'count': 0},
#   'likes': {'count': 12},
#   'reposts': {'count': 2},
#   'views': {'count': 354}},
#  {'id': 18673,
#   'date': 1601464147,
#   'owner_id': -42160511,
#   'from_id': -42160511,
#   'post_type': 'post',
#   'text': 'Программа «Автотехнологии» \n \nПандемия короновируса в 2020 году фактически ликвидировала все массовые мероприятия, к которым, конечно, относились и международные автовыставки. И вот неожиданность: китайцы, оправившись от напасти, первыми вернули автомобильный праздник — в столице Поднебесной открыл двери Пекинский международный автосалон. Подробнее - в программе «Автотехнологии». \n \n#BFM_Autotech \n \nДругие выпуски программы можно прослушать на сайте:https://bfmspb.ru/programmy/avtotexnologii',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'link',
# ...
#      'track_code': 'video_7b593f06auidrq-_C6vEumvnkhexAnzENrZkMuIksJOcoO75On9YzIaor7sLxsG6ZIyTIocwSPAPg1c1l0rb_Q',
#      'type': 'video',
#      'views': 519}}],
#   'comments': {'count': 0},
#   'likes': {'count': 5},
#   'reposts': {'count': 0},
#   'views': {'count': 630}},
#  {'id': 41842,
#   'date': 1596526802,
#   'owner_id': -41862289,
#   'from_id': -41862289,
#   'post_type': 'post',
#   'text': '74 человека справились с короновирусом в Смоленской области за последние сутки\n\n#Смоленск #коронавирус #стопвирус #второй_этап #выходим_из_пандемии',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://smolgazeta.ru/daylynews/78217-.html',
#      'title': 'Ещё 74 жителя Смоленской области победили COVID-19',
#      'caption': 'smolgazeta.ru',
#      'description': 'Портал стопкоронавирус.рф обновил данные о ситуации с новой коронавирусной инфекцией...',
#      'photo': {'album_id': -28,
#       'date': 1596527006,
#       'id': 457300569,
#       'owner_id': 2000013236,
#       'has_tags': False,
#       'sizes': [{'height': 90,
#         'url': 'https://sun9-33.userapi.com/9LkLnn0f1tmQNxmgyUCXM3RSMBgvpih991csuQ/l__LgFR0ef8.jpg',
#         'type': 'a',
#         'width': 200},
#        {'height': 180,
#         'url': 'https://sun9-63.userapi.com/o0K_aQG9WNhE_NjrTMXHpYV3vqSdFPNQ0Bmi5w/r6WXjL0uYJk.jpg',
#         'type': 'b',
#         'width': 400},
#        {'height': 200,
#         'url': 'https://sun9-49.userapi.com/dSro1avXXEqo3lXz4mzcSiSjd1xXR-JYl1Bc5A/EwppLEiU9uQ.jpg',
#         'type': 'c',
#         'width': 200},
#        {'height': 100,
#         'url': 'https://sun9-69.userapi.com/WMGhDi0gmgocL2Sfd6O9xYo9HCLCDK7YBKW4gQ/i8CHJQY2Y4A.jpg',
#         'type': 'd',
#         'width': 100},
#        {'height': 50,
#         'url': 'https://sun9-3.userapi.com/FrBJZhGU1lZgdsRLKTqFxZOadbgQEBHMeG0DBA/CenQEHWTHKM.jpg',
#         'type': 'e',
#         'width': 50},
#        {'height': 480,
#         'url': 'https://sun9-73.userapi.com/WW8hQl47h_tIVV0mylIKbAUto_qzKyVVTnZBXg/XclmVHcKaDc.jpg',
#         'type': 'k',
#         'width': 1069},
#        {'height': 240,
#         'url': 'https://sun9-35.userapi.com/Og6CfeHWg9tq2rX5gDaJE3PFgdFm7Daoq9NHLA/UxPc3iyfVFs.jpg',
#         'type': 'l',
#         'width': 537},
#        {'height': 537,
#         'url': 'https://sun9-54.userapi.com/Hf4uTXbGpDChunBNv6DIVFl71ElccopQWexJTQ/FZv4lfZ3GFw.jpg',
#         'type': 'o',
#         'width': 1196}],
#       'text': '',
#       'user_id': 100}}}],
#   'comments': {'count': 0},
#   'likes': {'count': 1},
#   'reposts': {'count': 0},
#   'views': {'count': 109}},
#  {'id': 80821,
#   'date': 1596454467,
#   'owner_id': -84566848,
#   'from_id': -84566848,
#   'post_type': 'post',
#   'text': 'Основатель «Тинькофф Банка» Олег Тиньков выписан из больницы после пересадки костного мозга. На своей странице в Instagram бизнесмен уже делился тем как справляется с заболеванием, а также рассказывал о ранее перенесенном короновирусе. В последний день июля предприниматель сообщил своим подписчикам, что наконец-то вернулся домой после сложной операции. «Home, sweet home. В больнице хорошо, а дома лучше. Теперь нужно продержаться 6 месяцев! Те встретить Рождество вместе с вами. Господи спаси и сохрани…», — написал бизнесмен. Ранее Олег выкладывал видео, на котором благодарил всех за помощь и поддержку, а также рассказывал об открытии благотворительного фонда «Фонд семьи Тиньковых». К слову, заниматься работой фонда будет его жена Рина: «Моя жена Рина, будет непосредственно этим заниматься. Мы хотим пожертвовать часть своего состояния на решение проблем рака крови и развития института донорства в нашей стране…». Напомним, в начале марта предприниматель и владелец одноименного банка Олег Тиньков сообщил, что у него диагностирована острая форма лейкемии. Об этом говорилось в заявлении, поступившем в издание «Медуза». По словам Тинькова, заболевание было диагностировано еще в конце октября, и именно благодаря своевременному четкому диагностированию заболевания врачам удалось быстро добиться ремиссии. «Мне поставили диагноз в октябре, я прошел уже несколько курсов химиотерапии. Мне приходилось в жизни бороться за себя и за свое дело, но сейчас я буду бороться за главное — за саму жизнь. Это самый сложный этап в моей непростой жизни, но я надеюсь на Бога, свое тело, друзей и вашу поддержку», — говорилось в сообщении.',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://trts.io/21cwp',
#      'title': '«Теперь нужно продержаться 6 месяцев»: Олег Тиньков выписан из больницы',
#      'caption': 'peopletalk.ru',
#      'description': 'Основатель «Тинькофф Банка» Олег Тиньков выписан из больницы после пересадки костного мозга. На своей странице в Instagram бизнесмен уже делился тем как справляется с заболеванием, а также рассказывал о ранее перенесенном короновирусе. В последний день июля предприниматель сообщил своим подписчикам, что наконец-то вернулся домой после сложной операции. «Home, sweet home. В больнице хорошо, а дома',
#      'photo': {'album_id': -28,
#       'date': 1596454473,
#       'id': 457303620,
#       'owner_id': 2000012292,
#       'has_tags': False,
#       'sizes': [{'height': 480,
#         'url': 'https://sun9-27.userapi.com/c858032/v858032618/2310e1/H1n4l8sjDXQ.jpg',
#         'type': 'k',
#         'width': 1074},
#        {'height': 240,
#         'url': 'https://sun9-27.userapi.com/c858032/v858032618/2310e0/OYm_mFapuA8.jpg',
#         'type': 'l',
#         'width': 537},
#        {'height': 93,
#         'url': 'https://sun9-56.userapi.com/c858032/v858032618/2310dd/wkv7zaLL5b0.jpg',
#         'type': 'm',
#         'width': 130},
#        {'height': 186,
#         'url': 'https://sun9-33.userapi.com/c858032/v858032618/2310df/gF7ADrKRE3Y.jpg',
#         'type': 'p',
#         'width': 260},
#        {'height': 54,
#         'url': 'https://sun9-51.userapi.com/c858032/v858032618/2310dc/F3iT8ryGOuQ.jpg',
#         'type': 's',
#         'width': 75},
#        {'height': 107,
#         'url': 'https://sun9-39.userapi.com/c858032/v858032618/2310de/hs-XRg-hwX8.jpg',
#         'type': 'x',
#         'width': 150}],
#       'text': '',
#       'user_id': 100}}}],
#   'comments': {'count': 0},
#   'likes': {'count': 0},
#   'reposts': {'count': 0},
#   'views': {'count': 269}},
#  {'id': 29636,
#   'date': 1596454402,
#   'owner_id': -80790060,
#   'from_id': -80790060,
#   'post_type': 'post',
#   'text': 'Бугун АОКАда Коронавирусга қарши кураш штаби аъзоси Севара Убайдуллаева иштирокида брифинг бўлиб ўтди. Брифингдан айрим муҳим савол-жавобларни қуйида келтирамиз. - COVID-19 ўпка ҳажмига таъсир кўрсатадими? - Ҳа таъсир қилади. Яъни, агар беморда МСКТ (мультисписал компьютер томография)сида ўпкада маълум фоизда жароҳатланиш кузатилса, бу меъёрий ҳажмда ўпканинг шунча соҳаси фаолияти орқада қолаётганини билдиради. Бу эса, ўпканинг шунча қисми нафас фаолиятида фаол иштирок этмаслигини билдиради. Инсон организми қайта тикланишга мойил. Доимий енгил жисмоний фаоллик билан шуғулланиш ва нафас машқларини бажариш билан ўпкани жароҳатланишидан асрашга ёки жароҳатланган соҳаларни тиклашга, ўзингизга ўзингиз ёрдам беришингиз мумкин. - Короновирус касаллиги кимларга юқмаслиги ҳақида маълумотлар мавжудми? - ЖССТ томонидан бу касалликка ҳамма чалиниши мумкинлиги тўғрисида маълумот берилган. Бугунги кундаги ҳолатга тўхталадиган бўлсак, ниқоб тақиб юриш ва ижтимоий масофа сақлаш ҳамда имкон қадар ўзини алоҳидалаганларга юқиш эҳтимоли пасаяди ёки вирус организмга тушиши камаяди. Одамлар билан мулоқотни чеклаган инсонларга юқмаслиги мумкин. Лекин вақт ўтиб, ҳар бир инсон ҳаёти давомида бу инфекция билан барибир тўқнашади ва шу даврда короновируснинг касаллик чақириш қобилияти камайган бўлса енгил кечиради. - Ҳавонинг зарарланиши пневмония билан касалланган беморлар соғайишига қанчалик ҳалақит қилади? - Бемор алоҳида ётган хона ҳавосини тез-тез шамоллатиб туриш зарур, кун давомида 5-6 марта; - ҳар куни хонани намли тозалаш мақсадга мувофиқ; - беморга тинчлик, хотиржамлик, тоза ҳаволи шароитни яратиб бериш лозим; - овқатланиш рациони тўлақонли бўлиши керак. Булар ўз навбатида касалликдан тезроқ тузалишга имкон беради. - Ингаляция ёрдам берадими? - Ингаляция турли йўтал шаклларида балғамни юмшатиш ва дренажлашлашда ёки бронхоспазмларда спазмни йўқотишда турли дори-дармонларни қўллаш билан тавсия этилади. Коронавирус билан касалланишда балғамсиз, қуруқ йўтал кузатилади. Бундай ҳолатда ингаляция қилиш яллиғланишга ёки йўтал кучайишига олиб келиши мумкин. Шундай экан, касаллик босқичини ҳисобга олган ҳолда, ингаляцияни қўллаш қатъий шифокор тавсияси ва назорати остида тавсия этилади.',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'link',
#     'link': {'url': 'https://m.vk.com/@zaminuz-rss-1728873584-2007143616',
#      'title': 'Коронавируснинг ўпкага таъсирини камайтириш йўллари маълум қилинди — Бизга қўшилинг: 👉 https://t.me/joinchat/AAAAADwt0NGCRoONT4f1_Q',
#      'caption': 'm.vk.com',
#      'description': 'Article',
#      'photo': {'album_id': 235125454,
#       'date': 1513935113,
#       'id': 456239031,
#       'owner_id': -127435785,
#       'has_tags': False,
#       'sizes': [{'height': 87,
#         'url': 'https://sun9-30.userapi.com/c841427/v841427299/49e55/USKUtzVeLqk.jpg',
#         'type': 'm',
#         'width': 130},
#        {'height': 87,
#         'url': 'https://sun9-60.userapi.com/c841427/v841427299/49e5a/l0Nhn9YSCJA.jpg',
#         'type': 'o',
#         'width': 130},
#        {'height': 133,
#         'url': 'https://sun9-13.userapi.com/c841427/v841427299/49e5b/58tmE5x4N54.jpg',
#         'type': 'p',
#         'width': 200},
#        {'height': 213,
#         'url': 'https://sun9-55.userapi.com/c841427/v841427299/49e5c/tKZlTDmDA1k.jpg',
#         'type': 'q',
#         'width': 320},
#        {'height': 340,
#         'url': 'https://sun9-57.userapi.com/c841427/v841427299/49e5d/el87-uGHdRM.jpg',
#         'type': 'r',
#         'width': 510},
#        {'height': 50,
#         'url': 'https://sun9-65.userapi.com/c841427/v841427299/49e54/RFh2HdaZ-c0.jpg',
#         'type': 's',
#         'width': 75},
#        {'height': 1023,
#         'url': 'https://sun9-68.userapi.com/c841427/v841427299/49e59/d3TSz4Ej5RQ.jpg',
#         'type': 'w',
#         'width': 1536},
#        {'height': 402,
#         'url': 'https://sun9-29.userapi.com/c841427/v841427299/49e56/OB5UEvb8_v0.jpg',
#         'type': 'x',
#         'width': 604},
#        {'height': 537,
#         'url': 'https://sun9-26.userapi.com/c841427/v841427299/49e57/8TRGIjyMtS4.jpg',
#         'type': 'y',
#         'width': 807},
#        {'height': 852,
#         'url': 'https://sun9-58.userapi.com/c841427/v841427299/49e58/N-Q-dK3xQ04.jpg',
#         'type': 'z',
#         'width': 1280}],
#       'text': '',
#       'user_id': 100},
#      'button': {'title': 'Read',
#       'action': {'type': 'open_url',
#        'url': 'https://m.vk.com/@zaminuz-rss-1728873584-2007143616'}}}}],
#   'comments': {'count': 0},
#   'likes': {'count': 0},
#   'reposts': {'count': 0},
#   'views': {'count': 75}},
#  {'id': 1616,
#   'date': 1596422490,
#   'owner_id': -144080984,
#   'from_id': -144080984,
#   'post_type': 'post',
#   'text': 'Чтобы спасти дочь, мама преодолела всё. Сомнения родни, ошибки диагностики лечения, огромное расстояние, коронавирусные преграды и административные препоны. Остался последний шаг, самый трудный. И этот шаг – деньги. У Миланы четвертая стадия нейробластомы, и помогать ей надо очень срочно https://fond.predanie.ru/blago/340953/?utm_medium=vk&utm_source=vk&utm_campaign=isa_3082020_dereberya\n\nМилана с мамой живут в городе со звучным названием Экибастуз. Это не Россия, это Казахстан. А значит, никакой помощи от российского государства ждать Милане не стоит – даже если ты маленькая страдающая девочка, цвет твоего паспорта имеет значение. \n \nИз письма мамы: \n \n"Миланочка росла веселым, отзывчивым и очень добрым ребенком. Ходила в детский сад, пошла в первый лицейный класс, училась на отлично, занималась в художественной школе. Но весной 2019г. у нее сильно заболела спина, она таяла на глазах, что мы только не делали, прошли пять УЗИ, сдали всевозможные анализы, пролечились месяц в детской больнице, но боли не проходили, а только усилились, обезболивающие сиропы не помогали, мы перешли на уколы. Когда Миланочка совсем ослабла и не могла вставать, ей делали рентген, ее легкие были заполнены жидкостью, пошли метастазы, а опухоль, которую увидели на КТ и МРТ, выросла и сдавила легкие. Нас перевели в детскую онкологию, где после биопсии образования сообщили страшный диагноз «Забрюшинная нейробластома с метастазами в л/узлах 4 стадия, крыло высокого риска», так как этим заболеванием болеют дети до года, учитывая возраст Милы (9 лет) прогноз был неблагоприятный. Мы начали сложное лечение. \n \nЗа год Милана прошла 23 наркоза, сбор стволовых клеток, 2 операции, 15 взятий пункций костного мозга, 18 рентгенографий, 6 высокодозных химиотерапий, лучевую терапию, несколько переливаний крови, несчетное количество сборов крови и прочих сопроводительных терапий. \n \nУ Миланы остаточная неоперабельная опухоль больших размеров вдоль позвоночника". \n \nЧтобы продолжить лечение маме с Миланой пришлось прорываться через кордоны, поставленные пандемией. Это было очень трудно, и они много раз теряли надежду. Но теперь это позади. \n \nПятого июля Милана прилетела в Москву, чтобы узнать, что опухоль возвращается. И что снвоа нужно очень много денег. И снова впереди двенадцать курсов химиотерапии, которые ещё надо как-то оплатить. \n \nИ надежда у мамы и Миланы на нас. Больше, кажется, почти никого не осталось. \n \nИз письма: \n \n"Я смогла привезти ребенка из Казахстана в Москву на лечение! Все преграды, связанные с короновирусом удалось преодолеть, кроме одной. В связи с экономической ситуацией помощь фондов резко сократилась! Денег на лечение ребёнка просто нет! \n \nМы уже в больнице и нам нужно срочно пройти курс химиотерапии, но мы не можем его оплатить. У ребенка рецидив! Помогите пожалуйста!"\n\nСобранные средства пойдут на оплату лечения в НМИЦ им. Н.Н. Блохина.\n\nПомочь Милане можно здесь https://fond.predanie.ru/blago/340953/?utm_medium=vk&utm_source=vk&utm_campaign=isa_3082020_dereberya',
#   'marked_as_ads': 0,
#   'attachments': [{'type': 'photo',
#     'photo': {'album_id': -7,
#      'date': 1596422490,
#      'id': 457239568,
#      'owner_id': -144080984,
#      'has_tags': False,
#      'access_key': '94e840c96d80f3781a',
#      'post_id': 1616,
#      'sizes': [{'height': 130,
#        'url': 'https://sun9-35.userapi.com/sGb8qVkb24yRljV8UKAijPqtjn7dik88rHJOhg/RRAFfAOKVXI.jpg',
#        'type': 'm',
#        'width': 124},
#       {'height': 137,
#        'url': 'https://sun9-3.userapi.com/4W11TeK0zfOsOJxJvabcV5I7o_mrRkRu5EzRMQ/hblJ34QbALQ.jpg',
#        'type': 'o',
#        'width': 130},
#       {'height': 210,
#        'url': 'https://sun9-2.userapi.com/_-ZVYL22nGfNC8TWTA4sIDMOG3o6m9FxbnTuOQ/_lngk8NZszI.jpg',
#        'type': 'p',
#        'width': 200},
#       {'height': 337,
#        'url': 'https://sun9-34.userapi.com/9qnkFSJH5PgB2HKnuHZsl1mvC5zR5ieKT9G9Vg/SXKR51FPGPg.jpg',
#        'type': 'q',
#        'width': 320},
#       {'height': 537,
#        'url': 'https://sun9-28.userapi.com/d_rc-OXPyNSqniXqdAT44Bs5TwUMYykoBHyDvA/2UPy10iLJRc.jpg',
#        'type': 'r',
#        'width': 510},
#       {'height': 75,
#        'url': 'https://sun9-55.userapi.com/6kg6m30kmYLwoqT7uEzZTyoxuDeVa4uQcwSDIA/L_zAhMxHjAk.jpg',
#        'type': 's',
#        'width': 72},
#       {'height': 604,
#        'url': 'https://sun9-19.userapi.com/irFqQ0NJiRZffBvccsOE4GZcbK4O9UJCNJCGow/5MsvdqHZt0s.jpg',
#        'type': 'x',
#        'width': 574},
#       {'height': 695,
#        'url': 'https://sun9-22.userapi.com/2l6KwpOYYGrdvTcSGW3pqAx5EUjdk2SK0B0FyA/0KQARap1EtE.jpg',
#        'type': 'y',
#        'width': 660}],
#      'text': '',
#      'user_id': 100}}],
#   'comments': {'count': 1},
#   'likes': {'count': 44},
#   'reposts': {'count': 9},
#   'views': {'count': 2917}},
#  {'id': 10033,
#   'date': 1596380084,
#   'owner_id': 17555747,
#   'from_id': 17555747,
#   'post_id': 10030,
#   'post_type': 'reply',
#   'text': '[id9578010|Дмитрий], так точно ))) Короновирус планы немного подпортил, потому пока что по России путешествую))',
#   'comments': {'count': 0},
#   'likes': {'count': 0},
#   'reposts': {'count': 0}}]

# %%
pd.DataFrame(res.json()['response']['items'])
# Out:
#           id        date   owner_id    from_id post_type  \
# 0     136506  1601653502  -13984605  -13984605      post
# 1      31792  1601642160  -80790060  -80790060      post
# 2      82216  1601634602 -133242605 -133242605      post
# 3       4126  1601632810 -171261988 -171261988      post
# 4    1793645  1601627408  -23482909  -23482909      post
# ..       ...         ...        ...        ...       ...
# 195    41842  1596526802  -41862289  -41862289      post
# 196    80821  1596454467  -84566848  -84566848      post
# 197    29636  1596454402  -80790060  -80790060      post
# 198     1616  1596422490 -144080984 -144080984      post
# 199    10033  1596380084   17555747   17555747     reply
#
#                                                   text  marked_as_ads  \
# 0    🚩Почему так резко выросло число заразившихся к...            0.0
# 1    АОКА залида Коронавирусга қарши курашиш штаби ...            0.0
# 2    💭 #ВопросДня@nastiarizik\n\n— Москва с 5 октяб...            0.0
# 3    В связи с неблагоприятной ситуацией, связанной...            0.0
# 4    Индексы Мосбиржи и РТС упали на фоне короновир...            0.0
# ..                                                 ...            ...
# 195  74 человека справились с короновирусом в Смоле...            0.0
# 196  Основатель «Тинькофф Банка» Олег Тиньков выпис...            0.0
# 197  Бугун АОКАда Коронавирусга қарши кураш штаби а...            0.0
# 198  Чтобы спасти дочь, мама преодолела всё. Сомнен...            0.0
# 199  [id9578010|Дмитрий], так точно ))) Короновирус...            NaN
#
#                                            attachments       comments  \
# 0    [{'type': 'podcast', 'podcast': {'artist': 'Ра...   {'count': 4}
# 1    [{'type': 'link', 'link': {'url': 'https://m.v...   {'count': 0}
# 2    [{'type': 'photo', 'photo': {'album_id': 25495...   {'count': 4}
# 3    [{'type': 'photo', 'photo': {'album_id': -7, '...   {'count': 0}
# 4    [{'type': 'photo', 'photo': {'album_id': -7, '...  {'count': 12}
# ..                                                 ...            ...
# 195  [{'type': 'link', 'link': {'url': 'https://smo...   {'count': 0}
# 196  [{'type': 'link', 'link': {'url': 'https://trt...   {'count': 0}
# 197  [{'type': 'link', 'link': {'url': 'https://m.v...   {'count': 0}
# 198  [{'type': 'photo', 'photo': {'album_id': -7, '...   {'count': 1}
# 199                                                NaN   {'count': 0}
#
#               likes       reposts            views  post_id  signer_id  \
# 0      {'count': 8}  {'count': 3}   {'count': 313}      NaN        NaN
# 1      {'count': 0}  {'count': 0}    {'count': 15}      NaN        NaN
# 2    {'count': 120}  {'count': 0}  {'count': 1117}      NaN        NaN
# 3      {'count': 0}  {'count': 0}    {'count': 60}      NaN        NaN
# 4      {'count': 4}  {'count': 0}  {'count': 3106}      NaN        NaN
# ..              ...           ...              ...      ...        ...
# 195    {'count': 1}  {'count': 0}   {'count': 109}      NaN        NaN
# 196    {'count': 0}  {'count': 0}   {'count': 269}      NaN        NaN
# 197    {'count': 0}  {'count': 0}    {'count': 75}      NaN        NaN
# 198   {'count': 44}  {'count': 9}  {'count': 2917}      NaN        NaN
# 199    {'count': 0}  {'count': 0}              NaN  10030.0        NaN
#
#     copy_history
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 195          NaN
# 196          NaN
# 197          NaN
# 198          NaN
# 199          NaN
#
# [200 rows x 15 columns]

# %%
# соберем все доступные сообщения по запросу
newsfeed_df = pd.DataFrame()
while True:
    result = requests.get(NEWSFEED_REQUEST, params)
    time.sleep(0.33)
    newsfeed_df = pd.concat([newsfeed_df, pd.DataFrame(result.json()['response']['items'])])
    if 'next_from' in result.json()['response'].keys():
        params['start_from'] = result.json()['response']['next_from']
    else:
        break
newsfeed_df
# Out:
#            id        date   owner_id    from_id post_type  \
# 0      136506  1601653502  -13984605  -13984605      post
# 1       31792  1601642160  -80790060  -80790060      post
# 2       82216  1601634602 -133242605 -133242605      post
# 3        4126  1601632810 -171261988 -171261988      post
# 4     1793645  1601627408  -23482909  -23482909      post
# ..        ...         ...        ...        ...       ...
# 185  10130440  1586966710  -46249401  -46249401      post
# 186     53053  1586966290     415771     415771      post
# 187    228978  1586962901  -55587293  -55587293      post
# 188     10738  1586961947 -143136493 -143136493      post
# 189  10129712  1586958469  -46249401  -46249401      post
#
#                                                   text  marked_as_ads  \
# 0    🚩Почему так резко выросло число заразившихся к...            0.0
# 1    АОКА залида Коронавирусга қарши курашиш штаби ...            0.0
# 2    💭 #ВопросДня@nastiarizik\n\n— Москва с 5 октяб...            0.0
# 3    В связи с неблагоприятной ситуацией, связанной...            0.0
# 4    Индексы Мосбиржи и РТС упали на фоне короновир...            0.0
# ..                                                 ...            ...
# 185  Я придумала лайфхак, как снизить вероятность з...            0.0
# 186  Всем добрейшего домашнего препровождения!🥳 \nЗ...            NaN
# 187  "Очень важно помнить и помогать людям, которые...            0.0
# 188  Росгвардия запускает уникальный онлайн-проект ...            0.0
# 189  Теперь я на самоизоляции, каждый день читаю и ...            0.0
#
#                                            attachments        comments  \
# 0    [{'type': 'podcast', 'podcast': {'artist': 'Ра...    {'count': 4}
# 1    [{'type': 'link', 'link': {'url': 'https://m.v...    {'count': 0}
# 2    [{'type': 'photo', 'photo': {'album_id': 25495...    {'count': 4}
# 3    [{'type': 'photo', 'photo': {'album_id': -7, '...    {'count': 0}
# 4    [{'type': 'photo', 'photo': {'album_id': -7, '...   {'count': 12}
# ..                                                 ...             ...
# 185                                                NaN  {'count': 103}
# 186  [{'type': 'video', 'video': {'access_key': 'ab...   {'count': 10}
# 187  [{'type': 'video', 'video': {'access_key': '55...    {'count': 1}
# 188  [{'type': 'video', 'video': {'access_key': 'a9...    {'count': 0}
# 189                                                NaN  {'count': 102}
#
#               likes        reposts             views  post_id    signer_id  \
# 0      {'count': 8}   {'count': 3}    {'count': 314}      NaN          NaN
# 1      {'count': 0}   {'count': 0}     {'count': 15}      NaN          NaN
# 2    {'count': 120}   {'count': 0}   {'count': 1123}      NaN          NaN
# 3      {'count': 0}   {'count': 0}     {'count': 60}      NaN          NaN
# 4      {'count': 4}   {'count': 0}   {'count': 3106}      NaN          NaN
# ..              ...            ...               ...      ...          ...
# 185  {'count': 149}   {'count': 2}  {'count': 48612}      NaN    6231819.0
# 186  {'count': 113}   {'count': 3}   {'count': 2516}      NaN          NaN
# 187   {'count': 12}   {'count': 0}   {'count': 4015}      NaN          NaN
# 188  {'count': 101}  {'count': 24}  {'count': 13677}      NaN          NaN
# 189   {'count': 49}   {'count': 1}  {'count': 35183}      NaN  514840517.0
#
#     copy_history copyright  geo
# 0            NaN       NaN  NaN
# 1            NaN       NaN  NaN
# 2            NaN       NaN  NaN
# 3            NaN       NaN  NaN
# 4            NaN       NaN  NaN
# ..           ...       ...  ...
# 185          NaN       NaN  NaN
# 186          NaN       NaN  NaN
# 187          NaN       NaN  NaN
# 188          NaN       NaN  NaN
# 189          NaN       NaN  NaN
#
# [990 rows x 17 columns]
